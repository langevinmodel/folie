# %% [markdown]
# # 1D Double Well estimation

# %%
import numpy as np
import matplotlib.pyplot as plt
import csv
from mpl_toolkits.mplot3d import Axes3D
from copy import deepcopy
import importlib
import folie as fl
import scipy
from simulation_estimation_and_plot import *
importlib.reload(fl)
np.set_printoptions(formatter={'float_kind': lambda x: f"{x:.{2}e}"})
dim_x=1

# %% [markdown]
# ### 1) The model

# %% [markdown]
# Here we model the double well potential as a quartic function $V(q)= \sum_{i=0}^4 c_iq^i$ and choose a constant diffusion coefficient $D(q)=q$ :
#
# The force parameter to pass to the simulator will then be : $F = - \frac{dV(q)}{dq}$

# %%
coeff=0.1*np.array([0,0,-4.5,0,0.1]) # coefficients of the free energy
free_energy = np.polynomial.Polynomial(coeff)
force_coeff=np.array([-coeff[1],-2*coeff[2],-3*coeff[3],-4*coeff[4]]) #coefficients of the free energy
force_function = fl.functions.Polynomial(deg=3,coefficients=force_coeff)
diff_function= fl.functions.Polynomial(deg=0,coefficients=np.asarray([0.5]))

# %%
# Plot of Free Energy and Force
x_values = np.linspace(-7, 7, 100)
fig, axs = plt.subplots(1, 2)
axs[0].plot(x_values,free_energy(x_values))
axs[1].plot(x_values,force_function(x_values.reshape(len(x_values),1)))
axs[0].set_title("Potential")
axs[0].set_xlabel("$x$")
axs[0].set_ylabel("$V(x)$")
axs[0].grid()
axs[1].set_title("Force") 
axs[1].set_xlabel("$x$")
axs[1].set_ylabel("$F(x)$") 
axs[1].grid()

# %% [markdown]
# ### 2') Underdamped Simulation

# %% [markdown]
# #### a) i) Parabolic diffusion, parabolic friction

# %%
coeff=0.1*np.array([0,0,-4.5,0,0.1]) # coefficients of the free energy
free_energy = np.polynomial.Polynomial(coeff)
force_coeff=np.array([-coeff[1],-2*coeff[2],-3*coeff[3],-4*coeff[4]]) #coefficients of the free energy
force_function = fl.functions.Polynomial(deg=3,coefficients=force_coeff)
diff_function= fl.functions.Polynomial(deg=2,coefficients=np.asarray([0.5, 0, .01]))
friction_function = fl.functions.Polynomial(deg=2,coefficients=np.asarray([1., 0, .01]))

# %%
# Define model to simulate and type of simulator to use
dt=1e-3
model_simu = fl.models.underdamped.Underdamped(force_function,friction_function, diffusion=diff_function)
simulator = fl.simulations.UnderdampedSimulator(fl.simulations.VECStepper(model_simu), dt)

# %%
ntrajs = 60
X0=np.asarray([[0., 0.1*(2*(k%2)-1)] for k in range(ntrajs)]).flatten()
X0 = np.zeros(2*ntrajs)
underdamped_data = simulator.run(15000, X0, 1)

# %%
# Plot the trajecories
fig, axs = plt.subplots(1,1)
for n, trj in enumerate(underdamped_data):
    axs.plot(trj["x"])
    axs.set_title("Trajectory")
    axs.set_xlabel("$timestep$")

# %%
keys = list(underdamped_data[20].keys())
for trj in underdamped_data:
    for key in keys:
        if key not in ("dt", "x"):
            del(trj[key])

# %%
underdamped_data[40]
# Out:
# {'x': array([[-4.42196630e-05],
#         [-7.54654033e-05],
#         [-7.52721417e-05],
#         ...,
#         [ 3.37930976e+00],
#         [ 3.38053602e+00],
#         [ 3.38175818e+00]]),
#  'dt': 0.001,
#  'v': array([[-0.035052  ],
#         [-0.01282896],
#         [ 0.00520257],
#         ...,
#         [ 1.20521828],
#         [ 1.22309369],
#         [ 1.25146686]])}

# %%
trainforce =fl.functions.Polynomial(deg=3,coefficients=np.asarray([1,1,1,1]))
deg_diff = 2
traindiff = fl.functions.Polynomial(deg=deg_diff,coefficients=np.ones(deg_diff+1)*.1)
deg_frict = 2
trainfriction = fl.functions.Polynomial(deg=deg_frict,coefficients=np.ones(deg_frict+1)*.1)
trainmodel = fl.models.Underdamped(trainforce, friction=trainfriction, diffusion=traindiff, has_bias=None)

VEC_estimator = fl.LikelihoodEstimator(fl.VECDensity(deepcopy(trainmodel),), n_jobs=10)

VEC_res = deepcopy(VEC_estimator.fit_fetch(underdamped_data,  minimize_kwargs={"method": "L-BFGS-B", "options":{"iprint":1}}))
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           10     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -1.33460D+01    |proj g|=  1.66691D-02
#  This problem is unconstrained.
# At iterate    1    f= -1.33460D+01    |proj g|=  3.94118D-02
#
# At iterate    2    f= -1.33460D+01    |proj g|=  2.45017D-02
#
# At iterate    3    f= -1.33460D+01    |proj g|=  7.64387D-03
#
# At iterate    4    f= -1.33460D+01    |proj g|=  1.20180D-02
#
# At iterate    5    f= -1.33460D+01    |proj g|=  3.07390D-02
#
# At iterate    6    f= -1.33461D+01    |proj g|=  6.70049D-02
#
# At iterate    7    f= -1.33461D+01    |proj g|=  9.50176D-02
#
# At iterate    8    f= -1.33462D+01    |proj g|=  8.86489D-02
#
# At iterate    9    f= -1.33462D+01    |proj g|=  4.81887D-02
#
# At iterate   10    f= -1.33462D+01    |proj g|=  2.88605D-02
#
# At iterate   11    f= -1.33462D+01    |proj g|=  1.69396D-03
#
# At iterate   12    f= -1.33462D+01    |proj g|=  2.15078D-03
#
# At iterate   13    f= -1.33462D+01    |proj g|=  2.56788D-03
#
# At iterate   14    f= -1.33462D+01    |proj g|=  8.77982D-03
#
# At iterate   15    f= -1.33462D+01    |proj g|=  8.25706D-03
#
# At iterate   16    f= -1.33462D+01    |proj g|=  4.58302D-03
#
# At iterate   17    f= -1.33462D+01    |proj g|=  1.88074D-03
#
# At iterate   18    f= -1.33462D+01    |proj g|=  5.40672D-04
#
# At iterate   19    f= -1.33462D+01    |proj g|=  2.45055D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    10     19     27      1     0     0   2.451D-04  -1.335D+01
#   F =  -13.346200469387366
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH

# %%
# KM_res.remove_bias()
xfa = np.linspace(-6,6,100)
fig, axs = plt.subplots(1,3, figsize=(12,5))
axs[0].plot(xfa, force_function(xfa.reshape(-1, 1)), label='Model' )
#axs[0].plot(xfa, KM_res.pos_drift(xfa.reshape(-1, 1)), label='KM', ls='--')
axs[0].plot(xfa, VEC_res.pos_drift(xfa.reshape(-1, 1)), label='VEC', ls='-.' )
#axs[0].plot(xfa, trainforce(xfa.reshape(-1, 1)), label='KM' )

axs[1].plot(xfa, diff_function(xfa.reshape(-1, 1)), label='Model')
#axs[1].plot(xfa, KM_res.diffusion(xfa.reshape(-1, 1)), label='KM',ls= '--')
axs[1].plot(xfa, VEC_res.diffusion(xfa.reshape(-1, 1)), label='VEC',ls= '-.')

axs[2].plot(xfa, friction_function(xfa.reshape(-1, 1)), label='Model')
#axs[2].plot(xfa, KM_res.friction(xfa.reshape(-1, 1)), label='KM',ls= '--')
axs[2].plot(xfa, VEC_res.friction(xfa.reshape(-1, 1)), label='VEC',ls= '-.')

axs[0].set_title('Force')
axs[1].set_title('Diffusion')
axs[2].set_title('Friction')
for ax in axs:
    ax.legend()

# %%
trainforce =fl.functions.Polynomial(deg=3,coefficients=np.asarray([1,1,1,1]))
deg_diff = 2
traindiff = fl.functions.Polynomial(deg=deg_diff,coefficients=np.ones(deg_diff+1)*.1)
deg_frict = 2
trainfriction = fl.functions.Polynomial(deg=deg_frict,coefficients=np.ones(deg_frict+1)*.1)
trainmodel = fl.models.Underdamped(trainforce, friction=trainfriction, diffusion=traindiff, has_bias=None)

KM_estimator = fl.estimation.direct_estimation.UnderdampedKramersMoyalEstimator(deepcopy(trainmodel))
VEC_estimator = fl.LikelihoodEstimator(fl.VECDensity(deepcopy(trainmodel),), n_jobs=10)

KM_res= deepcopy(KM_estimator.fit_fetch(underdamped_data))
VEC_res = deepcopy(VEC_estimator.fit_fetch(underdamped_data,  minimize_kwargs={"method": "L-BFGS-B", "options":{"iprint":1}}))
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           10     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -1.33214D+01    |proj g|=  3.76354D+00
#  This problem is unconstrained.
# At iterate    1    f= -1.33426D+01    |proj g|=  1.86616D+00
#
# At iterate    2    f= -1.33464D+01    |proj g|=  1.33294D-01
#
# At iterate    3    f= -1.33464D+01    |proj g|=  1.28033D-01
#
# At iterate    4    f= -1.33466D+01    |proj g|=  2.06692D-01
#
# At iterate    5    f= -1.33470D+01    |proj g|=  5.83514D-01
#
# At iterate    6    f= -1.33479D+01    |proj g|=  1.08609D+00
#
# At iterate    7    f= -1.33500D+01    |proj g|=  1.75365D+00
#
# At iterate    8    f= -1.33532D+01    |proj g|=  2.02053D+00
#
# At iterate    9    f= -1.33569D+01    |proj g|=  1.48222D+00
#
# At iterate   10    f= -1.33587D+01    |proj g|=  5.24293D-01
#
# At iterate   11    f= -1.33590D+01    |proj g|=  1.03180D-01
#
# At iterate   12    f= -1.33590D+01    |proj g|=  2.16825D-02
#
# At iterate   13    f= -1.33590D+01    |proj g|=  1.01487D-02
#
# At iterate   14    f= -1.33590D+01    |proj g|=  5.73071D-03
#
# At iterate   15    f= -1.33590D+01    |proj g|=  7.24375D-03
#
# At iterate   16    f= -1.33590D+01    |proj g|=  1.08368D-02
#
# At iterate   17    f= -1.33590D+01    |proj g|=  2.75194D-02
#
# At iterate   18    f= -1.33590D+01    |proj g|=  4.51712D-02
#
# At iterate   19    f= -1.33590D+01    |proj g|=  5.09270D-02
#
# At iterate   20    f= -1.33591D+01    |proj g|=  1.78281D-01
#
# At iterate   21    f= -1.33591D+01    |proj g|=  6.41354D-02
#
# At iterate   22    f= -1.33591D+01    |proj g|=  5.46928D-03
#
# At iterate   23    f= -1.33591D+01    |proj g|=  2.96636D-03
#
# At iterate   24    f= -1.33591D+01    |proj g|=  2.10254D-03
#
# At iterate   25    f= -1.33591D+01    |proj g|=  3.94122D-03
#
# At iterate   26    f= -1.33591D+01    |proj g|=  3.12404D-03
#
# At iterate   27    f= -1.33591D+01    |proj g|=  1.90094D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    10     27     48      1     0     0   1.901D-03  -1.336D+01
#   F =  -13.359094884862554
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH

# %%
# KM_res.remove_bias()
xfa = np.linspace(-6,6,100)
fig, axs = plt.subplots(1,3, figsize=(12,5))
axs[0].plot(xfa, force_function(xfa.reshape(-1, 1)), label='Model' )
axs[0].plot(xfa, KM_res.pos_drift(xfa.reshape(-1, 1)), label='KM', ls='--')
axs[0].plot(xfa, VEC_res.pos_drift(xfa.reshape(-1, 1)), label='VEC', ls='-.' )
#axs[0].plot(xfa, trainforce(xfa.reshape(-1, 1)), label='KM' )

axs[1].plot(xfa, diff_function(xfa.reshape(-1, 1)), label='Model')
axs[1].plot(xfa, KM_res.diffusion(xfa.reshape(-1, 1)), label='KM',ls= '--')
axs[1].plot(xfa, VEC_res.diffusion(xfa.reshape(-1, 1)), label='VEC',ls= '-.')

axs[2].plot(xfa, friction_function(xfa.reshape(-1, 1)), label='Model')
axs[2].plot(xfa, KM_res.friction(xfa.reshape(-1, 1)), label='KM',ls= '--')
axs[2].plot(xfa, VEC_res.friction(xfa.reshape(-1, 1)), label='VEC',ls= '-.')

axs[0].set_title('Force')
axs[1].set_title('Diffusion')
axs[2].set_title('Friction')
for ax in axs:
    ax.legend()

# %% [markdown]
# #### i 2) Minimizer : SLSQP

# %%
trainforce =fl.functions.Polynomial(deg=3,coefficients=np.asarray([1,1,1,1]))
deg_diff = 2
traindiff = fl.functions.Polynomial(deg=deg_diff,coefficients=np.ones(deg_diff+1)*.1)
deg_frict = 2
trainfriction = fl.functions.Polynomial(deg=deg_frict,coefficients=np.ones(deg_frict+1)*.1)
trainmodel = fl.models.Underdamped(trainforce, friction=trainfriction, diffusion=traindiff, has_bias=None)

KM_estimator = fl.estimation.direct_estimation.UnderdampedKramersMoyalEstimator(deepcopy(trainmodel))
VEC_estimator = fl.LikelihoodEstimator(fl.VECDensity(deepcopy(trainmodel),), n_jobs=10)

KM_res= deepcopy(KM_estimator.fit_fetch(underdamped_data))
VEC_res = deepcopy(VEC_estimator.fit_fetch(underdamped_data,  minimize_kwargs={"method": "CG"}))
# Out:
# KeyboardInterrupt

# %%
# KM_res.remove_bias()
xfa = np.linspace(-6,6,100)
fig, axs = plt.subplots(1,3, figsize=(12,5))
axs[0].plot(xfa, force_function(xfa.reshape(-1, 1)), label='Model' )
axs[0].plot(xfa, KM_res.pos_drift(xfa.reshape(-1, 1)), label='KM', ls='--')
axs[0].plot(xfa, VEC_res.pos_drift(xfa.reshape(-1, 1)), label='VEC', ls='-.' )
#axs[0].plot(xfa, trainforce(xfa.reshape(-1, 1)), label='KM' )

axs[1].plot(xfa, diff_function(xfa.reshape(-1, 1)), label='Model')
axs[1].plot(xfa, KM_res.diffusion(xfa.reshape(-1, 1)), label='KM',ls= '--')
axs[1].plot(xfa, VEC_res.diffusion(xfa.reshape(-1, 1)), label='VEC',ls= '-.')

axs[2].plot(xfa, friction_function(xfa.reshape(-1, 1)), label='Model')
axs[2].plot(xfa, KM_res.friction(xfa.reshape(-1, 1)), label='KM',ls= '--')
axs[2].plot(xfa, VEC_res.friction(xfa.reshape(-1, 1)), label='VEC',ls= '-.')

axs[0].set_title('Force')
axs[1].set_title('Diffusion')
axs[2].set_title('Friction')
for ax in axs:
    ax.legend()

# %% [markdown]
# #### ii) Iterating (running 60 trajs with the VEC-inferred model and doing inferrence again)

# %%
# Define model to simulate and type of simulator to use
dt=1e-3
simulator = fl.simulations.UnderdampedSimulator(fl.simulations.VECStepper(VEC_res), dt)

# %%
ntrajs = 60
X0 = np.zeros(2*ntrajs)
vec_res_simulation = simulator.run(15000, X0, 1)

# %%
# Plot the trajecories
fig, axs = plt.subplots(1,1)
for n, trj in enumerate(vec_res_simulation):
    axs.plot(trj["x"])
    axs.set_title("Trajectory")
    axs.set_xlabel("$timestep$")

# %%
trainforce =fl.functions.Polynomial(deg=3,coefficients=np.asarray([1,1,1,1]))
deg_diff = 2
traindiff = fl.functions.Polynomial(deg=deg_diff,coefficients=np.ones(deg_diff+1)*.1)
deg_frict = 2
trainfriction = fl.functions.Polynomial(deg=deg_frict,coefficients=np.ones(deg_frict+1)*.1)
trainmodel = fl.models.Underdamped(trainforce, friction=trainfriction, diffusion=traindiff, has_bias=None)

KM_estimator2 = fl.estimation.direct_estimation.UnderdampedKramersMoyalEstimator(deepcopy(trainmodel))
VEC_estimator2 = fl.LikelihoodEstimator(fl.VECDensity(deepcopy(trainmodel), use_jac=True),n_jobs=10)

KM_res2= deepcopy(KM_estimator2.fit_fetch(vec_res_simulation))
VEC_res2 = deepcopy(VEC_estimator2.fit_fetch(vec_res_simulation,  minimize_kwargs={"method": "L-BFGS-B", "options":{"iprint":1}}))
# Out:
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           10     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -1.33030D+01    |proj g|=  4.11591D+00
#
# At iterate    1    f= -1.33261D+01    |proj g|=  2.03453D+00
#
# At iterate    2    f= -1.33301D+01    |proj g|=  1.11396D-01
#
# At iterate    3    f= -1.33302D+01    |proj g|=  1.05744D-01
#
# At iterate    4    f= -1.33302D+01    |proj g|=  1.38183D-01
#
# At iterate    5    f= -1.33305D+01    |proj g|=  4.40459D-01
#
# At iterate    6    f= -1.33309D+01    |proj g|=  7.34749D-01
#
# At iterate    7    f= -1.33318D+01    |proj g|=  9.64833D-01
#
# At iterate    8    f= -1.33331D+01    |proj g|=  9.17001D-01
#
# At iterate    9    f= -1.33369D+01    |proj g|=  1.24146D+00
#
# At iterate   10    f= -1.33394D+01    |proj g|=  6.68041D-01
#
# At iterate   11    f= -1.33404D+01    |proj g|=  1.09660D-01
#
# At iterate   12    f= -1.33405D+01    |proj g|=  8.37686D-03
#
# At iterate   13    f= -1.33405D+01    |proj g|=  5.78023D-03
#
# At iterate   14    f= -1.33405D+01    |proj g|=  5.76628D-03
#
# At iterate   15    f= -1.33405D+01    |proj g|=  1.29809D-02
#
# At iterate   16    f= -1.33405D+01    |proj g|=  2.37975D-02
#
# At iterate   17    f= -1.33405D+01    |proj g|=  4.68101D-02
#
# At iterate   18    f= -1.33405D+01    |proj g|=  7.04732D-02
#
# At iterate   19    f= -1.33405D+01    |proj g|=  3.54445D-02
#
# At iterate   20    f= -1.33406D+01    |proj g|=  3.41426D-02
#
# At iterate   21    f= -1.33406D+01    |proj g|=  9.14647D-03
#
# At iterate   22    f= -1.33406D+01    |proj g|=  5.57230D-03
#
# At iterate   23    f= -1.33406D+01    |proj g|=  1.09749D-02
#
# At iterate   24    f= -1.33406D+01    |proj g|=  1.70423D-02
#
# At iterate   25    f= -1.33406D+01    |proj g|=  9.33920D-03
#
# At iterate   26    f= -1.33406D+01    |proj g|=  2.14262D-03
#
# At iterate   27    f= -1.33406D+01    |proj g|=  1.30444D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    10     27     48      1     0     0   1.304D-04  -1.334D+01
#   F =  -13.340568380097768
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH

# %%
# KM_res.remove_bias()
xfa = np.linspace(-6,6,100)
fig, axs = plt.subplots(1,3, figsize=(12,5))
axs[0].plot(xfa, VEC_res.pos_drift(xfa.reshape(-1, 1)), label='Model' )
axs[0].plot(xfa, KM_res2.pos_drift(xfa.reshape(-1, 1)), label='KM', ls='--')
axs[0].plot(xfa, VEC_res2.pos_drift(xfa.reshape(-1, 1)), label='VEC', ls='-.' )
#axs[0].plot(xfa, trainforce(xfa.reshape(-1, 1)), label='KM' )

axs[1].plot(xfa, VEC_res.diffusion(xfa.reshape(-1, 1)), label='Model')
axs[1].plot(xfa, KM_res2.diffusion(xfa.reshape(-1, 1)), label='KM',ls= '--')
axs[1].plot(xfa, VEC_res2.diffusion(xfa.reshape(-1, 1)), label='VEC',ls= '-.')

axs[2].plot(xfa, VEC_res.friction(xfa.reshape(-1, 1)), label='Model')
axs[2].plot(xfa, KM_res2.friction(xfa.reshape(-1, 1)), label='KM',ls= '--')
axs[2].plot(xfa, VEC_res2.friction(xfa.reshape(-1, 1)), label='VEC',ls= '-.')

for ax in axs:
    ax.legend()

# %% [markdown]
# #### iii) Initial guess : ground truth

# %%
trainforce = force_function
traindiff = diff_function
deg_frict = 2
trainfriction = friction_function
trainmodel = fl.models.Underdamped(trainforce, friction=trainfriction, diffusion=traindiff, has_bias=None)

KM_estimator = fl.estimation.direct_estimation.UnderdampedKramersMoyalEstimator(deepcopy(trainmodel))
VEC_estimator = fl.LikelihoodEstimator(fl.VECDensity(deepcopy(trainmodel)),n_jobs=10,)

KM_res= deepcopy(KM_estimator.fit_fetch(underdamped_data))
VEC_res = deepcopy(VEC_estimator.fit_fetch(underdamped_data, coefficients0=trainmodel.coefficients, minimize_kwargs={"method": "SLSQP", "options":{"iprint":1}}))

# %%
# KM_res.remove_bias()
xfa = np.linspace(-6,6,100)
fig, axs = plt.subplots(1,3, figsize=(12,5))
axs[0].plot(xfa, force_function(xfa.reshape(-1, 1)), label='Model' )
axs[0].plot(xfa, KM_res.pos_drift(xfa.reshape(-1, 1)), label='KM', ls='--')
axs[0].plot(xfa, VEC_res.pos_drift(xfa.reshape(-1, 1)), label='VEC', ls='-.' )
#axs[0].plot(xfa, trainforce(xfa.reshape(-1, 1)), label='KM' )

axs[1].plot(xfa, diff_function(xfa.reshape(-1, 1)), label='Model')
axs[1].plot(xfa, KM_res.diffusion(xfa.reshape(-1, 1)), label='KM',ls= '--')
axs[1].plot(xfa, VEC_res.diffusion(xfa.reshape(-1, 1)), label='VEC',ls= '-.')

axs[2].plot(xfa, friction_function(xfa.reshape(-1, 1)), label='Model')
axs[2].plot(xfa, KM_res.friction(xfa.reshape(-1, 1)), label='KM',ls= '--')
axs[2].plot(xfa, VEC_res.friction(xfa.reshape(-1, 1)), label='VEC',ls= '-.')

axs[0].set_title('Force')
axs[1].set_title('Diffusion')
axs[2].set_title('Friction')
for ax in axs:
    ax.legend()

# %%
init_val = VEC_estimator._loop_over_trajs(VEC_estimator.transition, underdamped_data.weights, underdamped_data, trainmodel.coefficients)

# %%
init_val
# Out:
# [-13.359153087794443,
#  array([ 7.69978803e-06,  5.62366547e-05,  2.71998379e-04,  1.56740401e-03,
#          2.63721336e-05, -2.21513787e-05,  3.14095038e-04,  1.94361842e-03,
#          4.72028403e-04,  8.42840321e-03])]

# %%
print('Likelihood of inferred model')
print(VEC_estimator._log_likelihood_negative(coefficients = VEC_res.coefficients, data = underdamped_data))
print('Likelihood of ground truth model')
print(VEC_estimator._log_likelihood_negative(coefficients = model_simu.coefficients, data = underdamped_data))
# Out:
# Likelihood of inferred model
# -13.359094884862554
# Likelihood of ground truth model
# -13.359153087794443

# %%
print('Likelihood of inferred model')
print(VEC_estimator._log_likelihood_negative(coefficients = VEC_res.coefficients, data = underdamped_data))
print('Likelihood of ground truth model')
print(VEC_estimator._log_likelihood_negative(coefficients = model_simu.coefficients, data = underdamped_data))
# Out:
# Likelihood of inferred model
# -13.351333428169752
# Likelihood of ground truth model
# -13.351389946228524

# %%
force_coeff
# Out:
# array([-0.  ,  0.9 , -0.  , -0.04])

# %% [markdown]
# Here the ground truth is, again, a local minimum, more stable than the one found starting from KM !

# %% [markdown]
# #### b) i) Constant diffusion, constant friction

# %%
coeff=0.1*np.array([0,0,-4.5,0,0.1]) # coefficients of the free energy
free_energy = np.polynomial.Polynomial(coeff)
force_coeff=np.array([-coeff[1],-2*coeff[2],-3*coeff[3],-4*coeff[4]]) #coefficients of the free energy
force_function = fl.functions.Polynomial(deg=3,coefficients=force_coeff)
diff_function= fl.functions.Polynomial(deg=0,coefficients=np.asarray([0.5]))
friction_function = fl.functions.Polynomial(deg=0,coefficients=np.asarray([1.]))

# %%
# Define model to simulate and type of simulator to use
dt=1e-3
model_simu = fl.models.underdamped.Underdamped(force_function,friction_function, diffusion=diff_function)
simulator = fl.simulations.UnderdampedSimulator(fl.simulations.VECStepper(model_simu), dt)

# %%
ntrajs = 60
X0 = np.zeros(2*ntrajs)
constant_gamma_diff_data = simulator.run(15000, X0, 1)

# %%
# Plot the trajecories
fig, axs = plt.subplots(1,1)
for n, trj in enumerate(constant_gamma_diff_data):
    axs.plot(trj["x"])
    axs.set_title("Trajectory")
    axs.set_xlabel("$timestep$")

# %%
trainforce =fl.functions.Polynomial(deg=3,coefficients=np.asarray([1,1,1,1]))
deg_diff = 0
traindiff = fl.functions.Polynomial(deg=deg_diff,coefficients=np.ones(deg_diff+1)*.1)
deg_frict = 0
trainfriction = fl.functions.Polynomial(deg=deg_frict,coefficients=np.ones(deg_frict+1)*.1)
trainmodel = fl.models.Underdamped(trainforce, friction=trainfriction, diffusion=traindiff, has_bias=None)

KM_estimator_1D = fl.estimation.direct_estimation.UnderdampedKramersMoyalEstimator(deepcopy(trainmodel))
VEC_estimator_1D = fl.LikelihoodEstimator(fl.VECDensity(deepcopy(trainmodel), use_jac=False),n_jobs=1)

KM_res_1D= deepcopy(KM_estimator_1D.fit_fetch(constant_gamma_diff_data))
VEC_res_1D = deepcopy(VEC_estimator_1D.fit_fetch(constant_gamma_diff_data,  minimize_kwargs={"method": "L-BFGS-B", "options":{"iprint":1}}))
# Out:
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            6     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -1.35584D+01    |proj g|=  3.76107D-01
#
# At iterate    1    f= -1.35747D+01    |proj g|=  3.13460D-01
#
# At iterate    2    f= -1.35964D+01    |proj g|=  4.30672D-02
#
# At iterate    3    f= -1.35966D+01    |proj g|=  2.54747D-02
#
# At iterate    4    f= -1.35966D+01    |proj g|=  1.11680D-03
#
# At iterate    5    f= -1.35966D+01    |proj g|=  4.97025D-04
#
# At iterate    6    f= -1.35966D+01    |proj g|=  4.99867D-04
#
# At iterate    7    f= -1.35966D+01    |proj g|=  1.14344D-03
#
# At iterate    8    f= -1.35966D+01    |proj g|=  2.43343D-03
#
# At iterate    9    f= -1.35966D+01    |proj g|=  4.23661D-03
#
# At iterate   10    f= -1.35966D+01    |proj g|=  8.09344D-03
#
# At iterate   11    f= -1.35967D+01    |proj g|=  1.22650D-02
#
# At iterate   12    f= -1.35967D+01    |proj g|=  1.68386D-02
#
# At iterate   13    f= -1.35967D+01    |proj g|=  1.74278D-02
#
# At iterate   14    f= -1.35968D+01    |proj g|=  1.82292D-02
#
# At iterate   15    f= -1.35968D+01    |proj g|=  3.73355D-03
#
# At iterate   16    f= -1.35968D+01    |proj g|=  9.20508D-04
#
# At iterate   17    f= -1.35968D+01    |proj g|=  2.54730D-04
#
# At iterate   18    f= -1.35968D+01    |proj g|=  2.41585D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     6     18     21      1     0     0   2.416D-04  -1.360D+01
#   F =  -13.596783371945152
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH

# %%
# KM_res.remove_bias()
xfa = np.linspace(-6,6,100)
fig, axs = plt.subplots(1,3, figsize=(12,5))
axs[0].plot(xfa, KM_res_1D.pos_drift(xfa.reshape(-1, 1)), label='KM', ls='--')
axs[0].plot(xfa, VEC_res_1D.pos_drift(xfa.reshape(-1, 1)), label='VEC', ls='-.' )
axs[0].plot(xfa, force_function(xfa.reshape(-1, 1)), label='Model' )
#axs[0].plot(xfa, trainforce(xfa.reshape(-1, 1)), label='KM' )

axs[1].plot(xfa, KM_res_1D.diffusion(xfa.reshape(-1, 1)), label='KM',ls= '--')
axs[1].plot(xfa, VEC_res_1D.diffusion(xfa.reshape(-1, 1)), label='VEC',ls= '-.')
axs[1].plot(xfa, diff_function(xfa.reshape(-1, 1)), label='Model')

axs[2].plot(xfa, KM_res_1D.friction(xfa.reshape(-1, 1)), label='KM',ls= '--')
axs[2].plot(xfa, VEC_res_1D.friction(xfa.reshape(-1, 1)), label='VEC',ls= '-.')
axs[2].plot(xfa, friction_function(xfa.reshape(-1, 1)), label='Model')

for ax in axs:
    ax.legend()

# %% [markdown]
# #### ii) dt = 5e-4

# %%
coeff=0.1*np.array([0,0,-4.5,0,0.1]) # coefficients of the free energy
free_energy = np.polynomial.Polynomial(coeff)
force_coeff=np.array([-coeff[1],-2*coeff[2],-3*coeff[3],-4*coeff[4]]) #coefficients of the free energy
force_function = fl.functions.Polynomial(deg=3,coefficients=force_coeff)
diff_function= fl.functions.Polynomial(deg=0,coefficients=np.asarray([0.5]))
friction_function = fl.functions.Polynomial(deg=0,coefficients=np.asarray([1.]))

# %%
# Define model to simulate and type of simulator to use
dt=5e-4
model_simu = fl.models.underdamped.Underdamped(force_function,friction_function, diffusion=diff_function)
simulator = fl.simulations.UnderdampedSimulator(fl.simulations.VECStepper(model_simu), dt)

# %%
ntrajs = 60
X0 = np.zeros(2*ntrajs)
constant_gamma_diff_data_dt4 = simulator.run(30000, X0, 1)

# %%
# Plot the trajecories
fig, axs = plt.subplots(1,1)
for n, trj in enumerate(constant_gamma_diff_data_dt4):
    axs.plot(trj["x"])
    axs.set_title("Trajectory")
    axs.set_xlabel("$timestep$")

# %%
trainforce =fl.functions.Polynomial(deg=3,coefficients=np.asarray([1,1,1,1]))
deg_diff = 0
traindiff = fl.functions.Polynomial(deg=deg_diff,coefficients=np.ones(deg_diff+1)*.1)
deg_frict = 0
trainfriction = fl.functions.Polynomial(deg=deg_frict,coefficients=np.ones(deg_frict+1)*.1)
trainmodel = fl.models.Underdamped(trainforce, friction=trainfriction, diffusion=traindiff, has_bias=None)

KM_estimator_1D_dt4 = fl.estimation.direct_estimation.UnderdampedKramersMoyalEstimator(deepcopy(trainmodel))
VEC_estimator_1D_dt4 = fl.LikelihoodEstimator(fl.VECDensity(deepcopy(trainmodel), use_jac=True),start_from_KM=True,n_jobs=10)

KM_res_1D_dt4= deepcopy(KM_estimator_1D_dt4.fit_fetch(constant_gamma_diff_data_dt4))
VEC_res_1D_dt4 = deepcopy(VEC_estimator_1D_dt4.fit_fetch(constant_gamma_diff_data_dt4,  minimize_kwargs={"method": "L-BFGS-B", "options":{"iprint":1}}))
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            6     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -1.49485D+01    |proj g|=  3.75382D-01
#  This problem is unconstrained.
# At iterate    1    f= -1.49650D+01    |proj g|=  3.10244D-01
#
# At iterate    2    f= -1.49859D+01    |proj g|=  4.04284D-02
#
# At iterate    3    f= -1.49860D+01    |proj g|=  2.31956D-02
#
# At iterate    4    f= -1.49861D+01    |proj g|=  9.55874D-04
#
# At iterate    5    f= -1.49861D+01    |proj g|=  2.49879D-04
#
# At iterate    6    f= -1.49861D+01    |proj g|=  2.49880D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     6      6      9      1     0     0   2.499D-04  -1.499D+01
#   F =  -14.986097205209257
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH

# %%
# KM_res.remove_bias()
xfa = np.linspace(-6,6,100)
fig, axs = plt.subplots(1,3, figsize=(12,5))
axs[0].plot(xfa, KM_res_1D_dt4.pos_drift(xfa.reshape(-1, 1)), label='KM', ls='--')
axs[0].plot(xfa, VEC_res_1D_dt4.pos_drift(xfa.reshape(-1, 1)), label='VEC', ls='-.' )
axs[0].plot(xfa, force_function(xfa.reshape(-1, 1)), label='Model' )
#axs[0].plot(xfa, trainforce(xfa.reshape(-1, 1)), label='KM' )

axs[1].plot(xfa, KM_res_1D_dt4.diffusion(xfa.reshape(-1, 1)), label='KM',ls= '--')
axs[1].plot(xfa, VEC_res_1D_dt4.diffusion(xfa.reshape(-1, 1)), label='VEC',ls= '-.')
axs[1].plot(xfa, diff_function(xfa.reshape(-1, 1)), label='Model')

axs[2].plot(xfa, KM_res_1D_dt4.friction(xfa.reshape(-1, 1)), label='KM',ls= '--')
axs[2].plot(xfa, VEC_res_1D_dt4.friction(xfa.reshape(-1, 1)), label='VEC',ls= '-.')
axs[2].plot(xfa, friction_function(xfa.reshape(-1, 1)), label='Model')

axs[0].set_title('Force')

axs[1].set_title('Diffusion')

axs[2].set_title('Friction')

for ax in axs:
    ax.legend()

# %%
print('Likelihood of inferred model')
print(VEC_estimator_1D_dt4._log_likelihood_negative(coefficients = VEC_res_1D_dt4.coefficients, data = constant_gamma_diff_data_dt4))
print('Likelihood of ground truth model')
print(VEC_estimator_1D_dt4._log_likelihood_negative(coefficients = model_simu.coefficients, data = constant_gamma_diff_data_dt4))
# Out:
# Likelihood of inferred model
# -14.986097205209257
# Likelihood of ground truth model
# -14.986179511801422

# %% [markdown]
# #### iii) Initial guess : ground truth

# %%
trainforce = force_function
deg_diff = 0
traindiff = diff_function
deg_frict = 0
trainfriction = friction_function
trainmodel = fl.models.Underdamped(trainforce, friction=trainfriction, diffusion=traindiff, has_bias=None)

KM_estimator_1D_dt4_start_from_truth = fl.estimation.direct_estimation.UnderdampedKramersMoyalEstimator(deepcopy(trainmodel))
VEC_estimator_1D_dt4_start_from_truth = fl.LikelihoodEstimator(fl.VECDensity(deepcopy(trainmodel), use_jac=True),start_from_KM=False,n_jobs=10)

KM_res_1D_dt4_start_from_truth = deepcopy(KM_estimator_1D_dt4_start_from_truth.fit_fetch(constant_gamma_diff_data_dt4))
VEC_res_1D_dt4_start_from_truth = deepcopy(VEC_estimator_1D_dt4_start_from_truth.fit_fetch(constant_gamma_diff_data_dt4,  minimize_kwargs={"method": "L-BFGS-B", "options":{"iprint":1}}))
# Out:
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            6     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -1.49862D+01    |proj g|=  3.78015D-03
#
# At iterate    1    f= -1.49862D+01    |proj g|=  5.88112D-04
#
# At iterate    2    f= -1.49862D+01    |proj g|=  6.34379D-05
#
# At iterate    3    f= -1.49862D+01    |proj g|=  4.94566D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     6      3      6      1     0     0   4.946D-05  -1.499D+01
#   F =  -14.986181564882475
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH

# %%
# KM_res.remove_bias()
xfa = np.linspace(-6,6,100)
fig, axs = plt.subplots(1,3, figsize=(12,5))
axs[0].plot(xfa, KM_res_1D_dt4_start_from_truth.pos_drift(xfa.reshape(-1, 1)), label='KM', ls='--')
axs[0].plot(xfa, VEC_res_1D_dt4_start_from_truth.pos_drift(xfa.reshape(-1, 1)), label='VEC', ls='-.' )
axs[0].plot(xfa, force_function(xfa.reshape(-1, 1)), label='Model' , ls='--')
axs[0].set_title('Force')
#axs[0].plot(xfa, trainforce(xfa.reshape(-1, 1)), label='KM' )

axs[1].plot(xfa, KM_res_1D_dt4_start_from_truth.diffusion(xfa.reshape(-1, 1)), label='KM',ls= '--')
axs[1].plot(xfa, VEC_res_1D_dt4_start_from_truth.diffusion(xfa.reshape(-1, 1)), label='VEC',ls= '-.')
axs[1].plot(xfa, diff_function(xfa.reshape(-1, 1)), label='Model', ls='--')
axs[1].set_title('Diffusion')

axs[2].plot(xfa, KM_res_1D_dt4_start_from_truth.friction(xfa.reshape(-1, 1)), label='KM',ls= '--')
axs[2].plot(xfa, VEC_res_1D_dt4_start_from_truth.friction(xfa.reshape(-1, 1)), label='VEC',ls= '-.')
axs[2].plot(xfa, friction_function(xfa.reshape(-1, 1)), label='Model', ls='--')
axs[2].set_title('Friction')

for ax in axs:
    ax.legend()

# %% [markdown]
# The ground truth model IS a local maximum of the likelihood.
# It's more stable than the one obtained starting from Kramers-Moyal.

# %% [markdown]
# ### 3) Underdamped with finite velocities

# %% [markdown]
# #### Constant diffusion, constant friction

# %%
coeff=0.1*np.array([0,0,-4.5,0,0.1]) # coefficients of the free energy
free_energy = np.polynomial.Polynomial(coeff)
force_coeff=np.array([-coeff[1],-2*coeff[2],-3*coeff[3],-4*coeff[4]]) #coefficients of the free energy
force_function = fl.functions.Polynomial(deg=3,coefficients=force_coeff)
diff_function= fl.functions.Polynomial(deg=0,coefficients=.1*np.asarray([30.]))
friction_function = fl.functions.Polynomial(deg=0,coefficients=.1*np.asarray([10.]))

# %%
# Define model to simulate and type of simulator to use
dt=1e-3
model_simu = fl.models.underdamped.Underdamped(force_function,friction_function, diffusion=diff_function)
simulator = fl.simulations.UnderdampedSimulator(fl.simulations.VECStepper(model_simu), dt)

# %%
ntrajs = 60
X0 = np.zeros(2*ntrajs)
constant_gamma_diff_data = simulator.run(15000, X0, 1)

# %%
for trj in constant_gamma_diff_data:
    del(trj["v"])
    # plt.plot(trj["x"])

# %% [markdown]
# #### attempts

# %%
def correct_velocities(trj, diff):
    sigma_sq = 2 * diff * trj["dt"]
    a = 1/4*(1+np.sqrt(5/3)) * np.sqrt(sigma_sq)
    b = 1/4*(-1+np.sqrt(5/3)) * np.sqrt(sigma_sq)
    g = np.random.default_rng().standard_normal(size = trj["v"].shape)
    trj["v"] = trj["u"] + a * g + b * np.roll(g, 1, axis=0)
    return trj

# %%
m = 0
for trj in constant_gamma_diff_data:
    # trj["u"] = ( trj["x"] - np.roll(trj["x"], 2, axis=0) ) / 2 / trj["dt"]
    # trj["u"] = np.roll(trj["u"], -1, axis=0)
    # trj["ut"] = trj["u"][2:-1]
    # trj["u"] = trj["u"][1:-2]
    # trj["vt"] = trj["v"][2:-1]
    # trj["v"] = trj["v"][1:-2]
    # del(trj["v"])
    # a = trj["v"]
    diff = nocor_parabdif.diffusion(trj["x"]).ravel().mean() * 12 / 5
    trj = correct_velocities(trj, diff)
    trj["a"] = ( trj["v"] - np.roll(trj["v"], 1, axis=0) )[2:-1] / trj["dt"]

    trj["vt"] = trj["v"][2:-1]
    trj["v"] = trj["v"][1:-2]
    trj["u"] = trj["u"][1:-2]
    
    trj["xt"] = trj["x"][2:-1]
    trj["x"] = trj["x"][1:-2]

    trj["bias"] = trj["bias"][2:-1]

    # del(trj["a"])
    # m += np.mean( (trj["vt"] - trj["v"]) - (trj["ut"] - trj["u"]) ) / trj["dt"]

# %%
ma , md = 0, 0
for trj in constant_gamma_diff_data:
    ma += np.mean(trj["a"])
    md += np.mean(nocor_parabdif.drift(trj["x"], trj["v"]))

# %%
model_simu.coefficients
# Out:
# array([-0.  ,  0.9 , -0.  , -0.04,  1.  ,  0.2 ,  0.  ,  0.1 ])

# %%
trj
# Out:
# {'x': array([[ 0.00000000e+00],
#         [ 0.00000000e+00],
#         [-1.54818685e-04],
#         ...,
#         [ 3.28300448e+00],
#         [ 3.28460556e+00],
#         [ 3.28615252e+00]]),
#  'dt': 0.001,
#  'u': array([[ 0.        ],
#         [-0.04796234],
#         [-0.04300974],
#         ...,
#         [ 1.64264289],
#         [ 1.57401703],
#         [ 1.52630076]]),
#  'v': array([[ 0.        ],
#         [ 0.        ],
#         [-0.04449102],
#         ...,
#         [ 1.65556242],
#         [ 1.55174062],
#         [ 1.46889266]]),
#  'a': array([[   0.        ],
#         [ -19.97204785],
#         [  34.70750343],
#         ...,
#         [-103.82179617],
#         [ -82.84796585],
#         [  71.90120986]]),
#  'vt': array([[ 0.        ],
#         [-0.04449102],
#         [-0.00978352],
#         ...,
#         [ 1.55174062],
#         [ 1.46889266],
#         [ 1.54079387]]),
#  'xt': array([[ 0.00000000e+00],
#         [-1.54818685e-04],
#         [-1.87715212e-04],
#         ...,
#         [ 3.28460556e+00],
#         [ 3.28615252e+00],
#         [ 3.28765817e+00]]),
#  'bias': array([], shape=(0, 1), dtype=float64)}

# %%
for val in trj.values() :
    if isinstance(val, np.ndarray):
        val[0] = 0
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[218], line 3
#       1 for val in trj.values() :
#       2     if isinstance(val, np.ndarray):
# ----> 3         val[0] = 0
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
nocor_parabdif.coefficients
# Out:
# array([-1.10393391e-01,  1.96149038e+00,  6.47609860e-03, -9.01290086e-02,
#         1.14492113e+00,  2.03936914e+01, -1.64377861e-01,  9.96566338e+00])

# %%
nocor_parabdif.diffusion.coefficients*=100

# %%
print(ma)
print(md)
# Out:
# 0.5337802733354191
# 0.4814722197012394

# %% [markdown]
# #### fit

# %%
trainforce = force_function
deg_diff = 0
traindiff = diff_function
deg_frict = 0
trainfriction = friction_function
trainmodel = fl.models.Underdamped(trainforce, friction=trainfriction, diffusion=traindiff, has_bias=None)

KM_estimator = fl.UnderdampedKramersMoyalEstimator(deepcopy(trainmodel))
# VEC_estimator = fl.LikelihoodEstimator(fl.VECDensity(deepcopy(trainmodel),), n_jobs=10)
# VEC_estimator = fl.estimation.mle.FiniteVelocityEMEstimator(fl.VECDensity(deepcopy(trainmodel)) ,n_jobs=10, verbose=2,
                                                            # max_iter=10)

constfrict = deepcopy(KM_estimator.fit_fetch(constant_gamma_diff_data, correct_finite_diff_vel=False))
# VEC_res = VEC_estimator.fit_fetch(constant_gamma_diff_data, use_jac=True,)

# %%
n_fits = 50
pos_drift_coeffs_arr = np.empty((n_fits, len(model_simu.pos_drift.coefficients)))
friction_coeffs_arr = np.empty((n_fits, len(model_simu.friction.coefficients)))
for it in range(n_fits):

    ntrajs = 60
    X0 = np.zeros(2*ntrajs)
    constant_gamma_diff_data = simulator.run(15000, X0, 1)
    
    for trj in constant_gamma_diff_data:
        del(trj["v"])

    KM_estimator = fl.UnderdampedKramersMoyalEstimator(deepcopy(trainmodel))
    constfrict = deepcopy(KM_estimator.fit_fetch(constant_gamma_diff_data, correct_finite_diff_vel=False))

    pos_drift_coeffs_arr[it] = constfrict.pos_drift.coefficients
    friction_coeffs_arr[it] = constfrict.friction.coefficients

# %%
plt.hist(friction_coeffs_arr, bins=10, label='Estimated friction distribution')
plt.axvline(model_simu.friction.coefficients, c='k', label='Ground truth')
plt.xlabel('Friction coeff.')
plt.ylabel('Counts')
plt.text(0.6, 6, f'Mean est. friction: {friction_coeffs_arr.mean():.2f}')
plt.legend()
plt.show()

# %%
fig, axs = plt.subplots(2,2, figsize=(10,7))
for ind, ax in np.ndenumerate(axs):
    k=2*ind[0]+ind[1]
    ax.hist(pos_drift_coeffs_arr[:,k])
    ax.axvline(model_simu.pos_drift.coefficients[k], c='k')

# %% [markdown]
# #### Harmonic oscillator - finite diff

# %%
# coeff=0.1*np.array([0,0,-4.5,0,0.t1]) # coefficients of the free energy
# free_energy = np.polynomial.Polynomial(coeff)
# force_coeff=np.array([-coeff[1],-2*coeff[2],-3*coeff[3],-4*coeff[4]]) #coefficients of the free energy
force_function = fl.functions.Polynomial(deg=1,coefficients=np.asarray([0., -0.]))
diff_function= fl.functions.Polynomial(deg=0,coefficients=np.asarray([0.5]))
friction_function = fl.functions.Polynomial(deg=0,coefficients=np.asarray([1.]))

# Define model to simulate and type of simulator to use
dt=1e-3
model_simu = fl.models.underdamped.Underdamped(force_function,friction_function, diffusion=diff_function)
simulator = fl.simulations.UnderdampedSimulator(fl.simulations.VECStepper(model_simu), dt)

n_fits = 5
pos_drift_coeffs_arr = np.empty((n_fits, len(model_simu.pos_drift.coefficients)))
friction_coeffs_arr = np.empty((n_fits, len(model_simu.friction.coefficients)))
for it in range(n_fits):

    ntrajs = 60
    X0 = np.zeros(2*ntrajs)
    constant_gamma_diff_data = simulator.run(15000, X0, 1)
    
    for trj in constant_gamma_diff_data:
        del(trj["v"])

    trainmodel = model_simu
    KM_estimator = fl.UnderdampedKramersMoyalEstimator(deepcopy(trainmodel))
    constfrict = deepcopy(KM_estimator.fit_fetch(constant_gamma_diff_data, correct_finite_diff_vel=False))

    pos_drift_coeffs_arr[it] = constfrict.pos_drift.coefficients
    friction_coeffs_arr[it] = constfrict.friction.coefficients

# %%
type(model_simu.drift)
# Out:
# folie.functions.base.ModelOverlay

# %%
np.sqrt(np.asarray([trj["v"].ravel()**2 for trj in constant_gamma_diff_data]).mean())
# Out:
# 0.6842249992365562

# %%
friction_coeffs_arr
# Out:
# array([[0.35914441],
#        [0.3280251 ],
#        [0.34669557],
#        [0.3858163 ],
#        [0.3672688 ]])

# %%
pos_drift_coeffs_arr
# Out:
# array([[-0.00349105, -0.04702642],
#        [-0.0001846 , -0.06435262],
#        [ 0.01376417, -0.0648394 ],
#        [-0.01543825, -0.05828637],
#        [ 0.00522833, -0.04862481]])

# %%
np.sqrt(2)/6
# Out:
# 0.23570226039551587

# %% [markdown]
# Constant friction, diffusion, harmonic oscillator:
# - friction ~ .35
# - diffusion = 5/12 OK
# - free energy OK (no bias)
# Constant friction, diffusion, 0 force (=OU process for the velocity)
# - friction ~ .35 again
# - rest is OK

# %% [markdown]
# ### Tests for KM drift bias correction

# %% [markdown]
# #### Dataclass result holder

# %%
from dataclasses import dataclass

@dataclass
class PerTimeAnalysis():
    dt: float
    nsteps: int
    raw_drift: np.ndarray
    corr_drift: np.ndarray

# %% [markdown]
# #### Script to test corrected vs. raw coeffs varying dt / nsteps

# %%
coeff=0.1*np.array([0,0,-4.5,0,0.1]) # coefficients of the free energy
free_energy = np.polynomial.Polynomial(coeff)
force_coeff=np.array([-coeff[1],-2*coeff[2],-3*coeff[3],-4*coeff[4]]) #coefficients of the free energy
results_double_well_parabolic_diffusion_parabolic_friction_newercorr = []
force_function = fl.functions.Polynomial(deg=3,coefficients=force_coeff)
diff_function= fl.functions.Polynomial(deg=2,coefficients=np.asarray([0.5,0.,0.1]))
friction_function = fl.functions.Polynomial(deg=2,coefficients=np.asarray([1.,0.,0.04]))

# Define model to simulate and type of simulator to use
x_list = [1.]
for x in x_list:
    
    dt=8e-3
    model_simu = fl.models.underdamped.Underdamped(force_function,friction_function, diffusion=diff_function)
    simulator = fl.simulations.UnderdampedSimulator(fl.simulations.VECStepper(model_simu), dt)

    n_fits = 10
    pos_drift_coeffs_arr = np.empty((n_fits, len(model_simu.pos_drift.coefficients)))
    friction_coeffs_arr = np.empty((n_fits, len(model_simu.friction.coefficients)))
    drift_coeffs_arr = np.empty((n_fits, len(model_simu.drift.coefficients)))
    corrd_drift_coeffs_arr = deepcopy(drift_coeffs_arr)
    
    for it in range(n_fits):
    
        ntrajs = 60
        X0 = np.zeros(2*ntrajs)
        constant_gamma_diff_data = simulator.run(int(x*15000), X0, 1)
        
        for trj in constant_gamma_diff_data:
            del(trj["v"])
    
        trainmodel = model_simu
        KM_estimator = fl.UnderdampedKramersMoyalEstimator(deepcopy(trainmodel))
        constfrict = deepcopy(KM_estimator.fit_fetch(constant_gamma_diff_data, correct_finite_diff_vel=False))
    
        pos_drift_coeffs_arr[it] = constfrict.pos_drift.coefficients
        friction_coeffs_arr[it] = constfrict.friction.coefficients
        drift_coeffs_arr[it] = constfrict.drift.coefficients
    
        data = deepcopy(constant_gamma_diff_data)
        X = np.concatenate([trj["x"] for trj in data], axis=0)
        V = np.concatenate([trj["v"] for trj in data], axis=0)
        b_eval = KM_estimator.evaluate_basis_matrix(X,V)
        H = KM_estimator.inverse_sqrt_gram(b_eval)
        phi = constfrict.drift.coefficients
        w = KM_estimator.compute_drift_correction(X) * 3/2 @ H
        corrd_coeffs = phi + H @ w
        corrd_drift_coeffs_arr[it] = corrd_coeffs
    
    results_double_well_parabolic_diffusion_parabolic_friction_newercorr.append(PerTimeAnalysis(dt=dt, nsteps=int(x*15000), raw_drift=drift_coeffs_arr, corr_drift=corrd_drift_coeffs_arr))

# %% [markdown]
# #### Script to compare a posteriori correction to correction newly implemented in fl.UnderdampedKM

# %%
coeff=0.1*np.array([0,0,-4.5,0,0.1]) # coefficients of the free energy
free_energy = np.polynomial.Polynomial(coeff)
force_coeff=np.array([-coeff[1],-2*coeff[2],-3*coeff[3],-4*coeff[4]]) #coefficients of the free energy
results_double_well_parabolic_diffusion_parabolic_friction_newerercorr = []
force_function = fl.functions.Polynomial(deg=3,coefficients=force_coeff)
diff_function= fl.functions.Polynomial(deg=2,coefficients=np.asarray([0.5,0.,0.1]))
friction_function = fl.functions.Polynomial(deg=2,coefficients=np.asarray([1.,0.,0.04]))

# Define model to simulate and type of simulator to use
x_list = [False, True]
for x in x_list:
    
    dt=8e-3
    model_simu = fl.models.underdamped.Underdamped(force_function,friction_function, diffusion=diff_function)
    simulator = fl.simulations.UnderdampedSimulator(fl.simulations.VECStepper(model_simu), dt)

    n_fits = 10
    pos_drift_coeffs_arr = np.empty((n_fits, len(model_simu.pos_drift.coefficients)))
    friction_coeffs_arr = np.empty((n_fits, len(model_simu.friction.coefficients)))
    drift_coeffs_arr = np.empty((n_fits, len(model_simu.drift.coefficients)))
    corrd_drift_coeffs_arr = deepcopy(drift_coeffs_arr)
    
    for it in range(n_fits):
    
        ntrajs = 60
        X0 = np.zeros(2*ntrajs)
        constant_gamma_diff_data = simulator.run(int(15000), X0, 1)
        
        for trj in constant_gamma_diff_data:
            del(trj["v"])
    
        trainmodel = model_simu
        KM_estimator = fl.UnderdampedKramersMoyalEstimator(deepcopy(trainmodel))
        uncorr = deepcopy(KM_estimator.fit_fetch(constant_gamma_diff_data, correct_finite_diff_vel=x))
    
        pos_drift_coeffs_arr[it] = uncorr.pos_drift.coefficients
        friction_coeffs_arr[it] = uncorr.friction.coefficients
        drift_coeffs_arr[it] = uncorr.drift.coefficients
    
        data = deepcopy(constant_gamma_diff_data)
        X = np.concatenate([trj["x"] for trj in data], axis=0)
        V = np.concatenate([trj["v"] for trj in data], axis=0)
        b_eval = KM_estimator.model.drift.grad_coeffs(X,V).reshape((X.shape[0] * KM_estimator.model.drift.output_size_, -1))
        H = fl.estimation.direct_estimation.inverse_sqrt_gram(b_eval)
        phi = uncorr.drift.coefficients
        w = KM_estimator.compute_drift_correction(X) * 3/2 @ H
        corrd_coeffs = phi + H @ w
        corrd_drift_coeffs_arr[it] = corrd_coeffs
    
    results_double_well_parabolic_diffusion_parabolic_friction_newerercorr.append(PerTimeAnalysis(dt=dt, nsteps=int(15000), raw_drift=drift_coeffs_arr, corr_drift=corrd_drift_coeffs_arr))

# %% [markdown]
# ##### Not subtracting drift to acceleration basically makes no difference because when you take the square, lowest-order non-zero average terms are O(dt) vs. O(dt^-1) dominant noise terms

# %%
A = np.concatenate([trj["a"] for trj in data], axis=0)

# %%
acc_sq = A**2
diff = KM_estimator.model.diffusion.fit(X, y=acc_sq * dt / 2)

# %%
diff.coefficients * 3/2
# Out:
# array([ 0.49159039, -0.00051342,  0.09995353])

# %% [markdown]
# #### All tests

# %%
print(model_simu.drift.coefficients)
for res in results_double_well_parabolic_diffusion_parabolic_friction_newerercorr:
    print('dt:', res.dt)
    print('nsteps:', res.nsteps)
    print('Raw means:', f"{np.mean(res.raw_drift, axis=0)}")
    print('Corrd. mean:', np.mean(res.corr_drift, axis=0))
# Out:
# [-0.00e+00 9.00e-01 -0.00e+00 -4.00e-02 1.00e+00 0.00e+00 4.00e-02]
# dt: 0.008
# nsteps: 15000
# Raw means: [-9.18e-03 8.72e-01 8.42e-04 -3.92e-02 1.79e-01 -5.22e-05 -7.49e-03]
# Corrd. mean: [-1.44e-02 8.97e-01 1.05e-03 -4.00e-02 9.98e-01 -2.11e-03 3.98e-02]
# dt: 0.008
# nsteps: 15000
# Raw means: [-9.98e-04 9.02e-01 -4.55e-04 -4.01e-02 9.91e-01 1.67e-04 4.06e-02]
# Corrd. mean: [5.90e-04 9.41e-01 -4.74e-04 -4.14e-02 2.20e+00 6.31e-04 1.13e-01]

# %%
uncorr.diffusion.coefficients
# Out:
# array([5.02e-01, 9.31e-04, 9.86e-02])

# %%
print(model_simu.drift.coefficients)
for res in results_double_well_parabolic_diffusion_parabolic_friction_newercorr:
    print('dt:', res.dt)
    print('nsteps:', res.nsteps)
    print('Raw means:', f"{np.mean(res.raw_drift, axis=0)}")
    print('Corrd. mean:', np.mean(res.corr_drift, axis=0))
# Out:
# [-0.    0.9  -0.   -0.04  1.    0.    0.04]
# dt: 0.008
# nsteps: 15000
# Raw means: [ 8.97003462e-03  8.71724541e-01 -1.51372451e-04 -3.90229487e-02
#   1.80336562e-01 -2.47279335e-05 -7.55169066e-03]
# Corrd. mean: [ 1.36038827e-02  8.97056337e-01 -3.23166369e-04 -3.98302097e-02
#   9.95613701e-01 -1.62418590e-03  3.96201930e-02]

# %%
print(model_simu.drift.coefficients)
for res in results_double_well_constant_diffusion_parabolic_friction_newercorr:
    print('dt:', res.dt)
    print('nsteps:', res.nsteps)
    print('Raw means:', f"{np.mean(res.raw_drift, axis=0)}")
    print('Corrd. mean:', np.mean(res.corr_drift, axis=0))
# Out:
# [-0.    0.9  -0.   -0.04  1.    0.    0.04]
# dt: 0.008
# nsteps: 15000
# Raw means: [-7.26310666e-03  8.10386249e-01  6.21205795e-05 -3.63219867e-02
#   4.57229222e-01 -3.82765560e-04 -1.73473811e-02]
# Corrd. mean: [-9.53924673e-03  8.88505516e-01  1.28419890e-04 -3.95376599e-02
#   1.00044510e+00  1.23779539e-03  4.01240920e-02]

# %%
np.mean(corrd_drift_coeffs_arr, axis=0)
# Out:
# array([-2.60e-03, -9.98e-01, 1.00e+00])

# %%
phi @ np.linalg.inv(H) + H @ w
# Out:
# array([-1.12e-03, -9.85e-01, 1.00e+00])

# %%
drift_coeffs_arr

# %%
dr = fl.functions.Polynomial(deg=3, coefficients=np.mean(res.corr_drift, axis=0)[:-1])
xfa = np.linspace(-5,5,100).reshape((-1,1))
plt.plot(xfa, force_function(xfa))
plt.plot(xfa, dr(xfa))

# %%
for trj in constant_gamma_diff_data:
    plt.plot(trj["x"])

# %%
edges.shape
# Out:
# (100,)

# %%
hist.shape
# Out:
# (101,)

# %%
hist, edges = np.histogram(X, bins=100)
centers = ( edges[1:] + edges[:-1] ) / 2
plt.plot(centers, -np.log(hist))

# %%
def f(x, a, b):
    return a*x**2 + b

# %%
hist, edges = np.histogram(V, bins=100)
centers = ( edges[1:] + edges[:-1] ) / 2
plt.plot(centers, hist)
plt.plot(centers, np.exp(-f(centers, *scipy.optimize.curve_fit(f, centers[20:-20], -np.log(hist[20:-20]))[0])))
plt.grid()

# %%
print(np.mean(V, axis=0))
print(np.var(V, axis=0))
# Out:
# [-2.27e-03]
# [1.50e+00]

# %%
np.mean((KM_estimator.model.diffusion(X)*3/2)**2)
# Out:
# 2.4247840989525935

# %%
np.set_printoptions(formatter={'float_kind': lambda x: f"{x:.{2}e}"})

# %%
model_simu.drift.coefficients
# Out:
# array([-0.00e+00, 9.00e-01, -0.00e+00, -4.00e-02, 1.00e+00])

# %% [markdown]
# Taking original phi (ie coeffs in original base b) + H @ w @ H (i.e. correction in base b times inverse Gram matrix) seems to yield an almost-perfect result in that particular case.

# %%
KM_estimator.compute_drift_correction(X) * 3/2
# Out:
# array([0.00e+00, 0.00e+00, 0.00e+00, 0.00e+00, 4.99e-01, -8.82e-05,
#        4.92e-02])

# %%
model_simu.coefficients_drift
# Out:
# array([-0.00e+00, 9.00e-01, -0.00e+00, -4.00e-02, 1.00e+00, 0.00e+00,
#        4.00e-02])

# %%
w @ np.linalg.inv(H)
# Out:
# array([8.13e-20, 1.21e-17, 0.00e+00, 1.28e-16, 4.95e-01, -3.04e-18,
#        0.00e+00])

# %%
print(model_simu.drift.coefficients)
for res in results_double_well_constant_diffusion_parabolic_friction_newcorr:
    print('dt:', res.dt)
    print('nsteps:', res.nsteps)
    print('Raw means:', f"{np.mean(res.raw_drift, axis=0)}")
    print('Corrd. mean:', np.mean(res.corr_drift, axis=0))
# Out:
# [-0.00e+00 9.00e-01 -0.00e+00 -4.00e-02 1.00e+00 0.00e+00 4.00e-02]
# dt: 0.008
# nsteps: 15000
# Raw means: [1.35e-02 8.23e-01 -5.39e-04 -3.69e-02 4.66e-01 1.03e-04 -1.77e-02]
# Corrd. mean: [-1.25e-01 1.66e+00 5.69e-03 -7.26e-02 1.61e+01 6.93e-03 -7.27e-01]

# %%
print(model_simu.drift.coefficients)
for res in results_double_well_parabolic_diffusion_parabolic_friction_newcorr:
    print('dt:', res.dt)
    print('nsteps:', res.nsteps)
    print('Raw means:', f"{np.mean(res.raw_drift, axis=0)}")
    print('Corrd. mean:', np.mean(res.corr_drift, axis=0))
# Out:
# [-0.00e+00 9.00e-01 -0.00e+00 -4.00e-02 1.00e+00 0.00e+00 4.00e-02]
# dt: 0.008
# nsteps: 15000
# Raw means: [4.05e-03 8.63e-01 2.57e-04 -3.87e-02 2.31e-01 2.24e-04 -9.19e-03]
# Corrd. mean: [5.44e-02 9.78e-01 -1.85e-03 -4.31e-02 5.60e+00 -7.70e-04 -2.37e-01]
# dt: 0.008
# nsteps: 30000
# Raw means: [-1.21e-02 8.75e-01 3.44e-04 -3.90e-02 1.74e-01 1.14e-04 -7.18e-03]
# Corrd. mean: [-1.57e-02 9.41e-01 4.79e-04 -4.15e-02 6.28e+00 -1.72e-04 -2.64e-01]

# %%
print(model_simu.drift.coefficients)
for res in results_double_well_parabolic_diffusion_constant_friction_newcorr:
    print('dt:', res.dt)
    print('nsteps:', res.nsteps)
    print('Raw means:', f"{np.mean(res.raw_drift, axis=0)}")
    print('Corrd. mean:', np.mean(res.corr_drift, axis=0))
# Out:
# [-0.00e+00 9.00e-01 -0.00e+00 -4.00e-02 1.00e+00]
# dt: 0.008
# nsteps: 15000
# Raw means: [-5.86e-03 8.73e-01 2.05e-04 -3.91e-02 1.79e-02]
# Corrd. mean: [-9.84e-03 8.93e-01 3.66e-04 -3.98e-02 1.00e+00]
# dt: 0.008
# nsteps: 30000
# Raw means: [-4.84e-03 8.86e-01 1.33e-04 -3.95e-02 9.03e-03]
# Corrd. mean: [-5.28e-03 8.96e-01 1.52e-04 -3.98e-02 9.92e-01]

# %% [markdown]
# Writing coeffs + coeffs_fitted_on_diff @ H @ H yields seemingly correct results when friction = 1., but the friction becomes pretty terrible if we start taking a parabolic profile.
#
# -> that was because in the correction we used a linear regression fit which includes a product by the inverse of the Gram matrix of the friction basis $G_{\alpha \beta}^{\Gamma} = \langle b_{\alpha}^{\Gamma}(x), b_{\beta}^{\Gamma}(x) \rangle $.

# %%
print(model_simu.drift.coefficients)
for res in results_double_well_parabolic_diffusion_constant_friction:
    print('dt:', res.dt)
    print('nsteps:', res.nsteps)
    print('Raw means:', f"{np.mean(res.raw_drift, axis=0)}")
    print('Corrd. mean:', np.mean(res.corr_drift, axis=0))
# Out:
# [-0.00e+00 9.00e-01 -0.00e+00 -4.00e-02 1.00e+00]
# dt: 0.008
# nsteps: 15000
# Raw means: [-1.39e-02 8.77e-01 1.57e-04 -3.92e-02 1.85e-02]
# Corrd. mean: [-1.20e-01 4.14e-01 4.65e-03 -1.50e-02 1.01e+00]
# dt: 0.008
# nsteps: 30000
# Raw means: [1.15e-02 8.93e-01 -3.77e-04 -3.99e-02 9.43e-03]
# Corrd. mean: [2.86e-02 4.03e-01 -1.19e-03 -1.46e-02 1.00e+00]

# %%
print(model_simu.drift.coefficients)
for res in results_double_well:
    print('dt:', res.dt)
    print('nsteps:', res.nsteps)
    print('Raw means:', f"{np.mean(res.raw_drift, axis=0)}")
    print('Corrd. mean:', np.mean(res.corr_drift, axis=0))
# Out:
# [-0.    0.9  -0.   -0.04  1.  ]
# dt: 0.008
# nsteps: 75000
# Raw means: [ 1.28673400e-02  8.87201340e-01 -6.08578816e-04 -3.94837122e-02
#   1.47692205e-02]
# Corrd. mean: [ 0.13705558  0.94582143 -0.00612511 -0.03918422  1.0307959 ]

# %% [markdown]
# Double well : systematic improvement when we increase nsteps ! (encouraging kinda ; unfortunately data was lost)
#
# No improvement when the number of trajectories is increased (even though it should be an effective way to increase the number of uncorrelated data points)
#
# WITH $dt=8 \times 10^{-3}$ and nsteps=$ 5 \times 15000$ (& 60 trajectories) , we get the following coeffs when we correct for finite diff velocities using Ronceray's protocol :
#
# Corrd. mean: [ 0.13705558  0.94582143 -0.00612511 -0.03918422  1.0307959 ]
#
# (vs. ground truth : [-0.    0.9  -0.   -0.04  1.  ] ; 4 first coeffs are drift, last one is friction)

# %%
for res in results:
    print('dt:', res.dt)
    print('Raw means:', f"{np.mean(res.raw_drift, axis=0)[0] : .3g}",f"{np.mean(res.raw_drift, axis=0)[1] : .3g}")
    print('Abs corrd mean of "pos drift":', f"{np.mean(np.abs(res.corr_drift), axis=0)[0] : .3g}")
    print('Corrd. mean:', f'{np.mean(res.corr_drift, axis=0)[0] : .3g}',f'{np.mean(res.corr_drift, axis=0)[1] : .3g}')
# Out:
# dt: 0.001
# Raw means:  0.000746 -0.0352
# Abs corrd mean of "pos drift":  0.0351
# Corrd. mean:  0.0233  0.964
# dt: 0.002
# Raw means:  4.85e-05 -0.0327
# Abs corrd mean of "pos drift":  0.0257
# Corrd. mean:  0.000618  0.973
# dt: 0.004
# Raw means: -0.00013 -0.0381
# Abs corrd mean of "pos drift":  0.0197
# Corrd. mean:  0.00611  0.961
# dt: 0.008
# Raw means: -0.00225 -0.0339
# Abs corrd mean of "pos drift":  0.0409
# Corrd. mean:  0.00433  0.958
# dt: 0.016
# Raw means:  0.000312 -0.033
# Abs corrd mean of "pos drift":  0.0279
# Corrd. mean:  0.00651  0.984
# dt: 0.032
# Raw means: -0.00153 -0.0319
# Abs corrd mean of "pos drift":  0.0238
# Corrd. mean: -0.0143  0.955
# dt: 0.0005
# Raw means:  0.000907 -0.0326
# Abs corrd mean of "pos drift":  0.0253
# Corrd. mean: -0.00385  0.998
# dt: 0.00025
# Raw means:  0.00418 -0.0366
# Abs corrd mean of "pos drift":  0.0263
# Corrd. mean:  0.00503  0.963
# dt: 0.001
# Raw means: -0.00135 -0.0345
# Abs corrd mean of "pos drift":  0.0312
# Corrd. mean: -0.00927  0.957

# %%
for res in results_with_OH_free_energy:
    print('dt:', res.dt)
    print('Raw means:', f"{np.mean(res.raw_drift, axis=0)[0] : .3g}",f"{np.mean(res.raw_drift, axis=0)[1] : .3g}",f"{np.mean(res.raw_drift, axis=0)[2] : .3g}")
    print('Abs corrd mean of "pos drift":', f"{np.mean(np.abs(res.corr_drift), axis=0)[0] : .3g}")
    print('Corrd. mean:', f'{np.mean(res.corr_drift, axis=0)[0] : .3g}',f'{np.mean(res.corr_drift, axis=0)[1] : .3g}',f'{np.mean(res.corr_drift, axis=0)[2] : .3g}')
# Out:
# dt: 0.0003333333333333333
# Raw means: -0.00588 -1.04 -0.072
# Abs corrd mean of "pos drift":  0.0783
# Corrd. mean: -0.0182 -2.32  0.841
# dt: 0.0005
# Raw means: -0.00185 -1.04 -0.0774
# Abs corrd mean of "pos drift":  0.0565
# Corrd. mean: -0.00679 -2.26  0.811
# dt: 0.001
# Raw means: -0.00097 -1.06 -0.0733
# Abs corrd mean of "pos drift":  0.0821
# Corrd. mean: -0.000329 -2.43  0.848
# dt: 0.002
# Raw means: -0.01 -1.05 -0.0722
# Abs corrd mean of "pos drift":  0.0586
# Corrd. mean: -0.034 -2.41  0.851
# dt: 0.004
# Raw means:  0.000631 -1.06 -0.076
# Abs corrd mean of "pos drift":  0.076
# Corrd. mean:  0.00449 -2.4  0.828
# dt: 0.008
# Raw means:  0.0128 -1.03 -0.0696
# Abs corrd mean of "pos drift":  0.0869
# Corrd. mean:  0.0354 -2.27  0.856

# %%
for res in results_changing_nsteps:
    print('dt:', res.dt)
    print('Raw means:', f"{np.mean(res.raw_drift, axis=0)[0] : .3g}",f"{np.mean(res.raw_drift, axis=0)[1] : .3g}",f"{np.mean(res.raw_drift, axis=0)[2] : .3g}")
    print('Abs corrd mean of "pos drift":', f"{np.mean(np.abs(res.corr_drift), axis=0)[0] : .3g}")
    print('Corrd. mean:', f'{np.mean(res.corr_drift, axis=0)[0] : .3g}',f'{np.mean(res.corr_drift, axis=0)[1] : .3g}',f'{np.mean(res.corr_drift, axis=0)[2] : .3g}')
# Out:
# dt: 0.5
# Raw means:  0.0121 -1.1 -0.157
# Abs corrd mean of "pos drift":  0.141
# Corrd. mean:  0.0385 -2.75  0.6
# dt: 0.75
# Raw means:  0.00201 -1.08 -0.099
# Abs corrd mean of "pos drift":  0.0654
# Corrd. mean:  0.00948 -2.51  0.762
# dt: 1
# Raw means:  0.00142 -1.06 -0.0748
# Abs corrd mean of "pos drift":  0.0845
# Corrd. mean:  0.0103 -2.41  0.832
# dt: 1.25
# Raw means: -0.0114 -1.03 -0.0577
# Abs corrd mean of "pos drift":  0.086
# Corrd. mean: -0.0369 -2.27  0.889
# dt: 1.5
# Raw means: -0.00957 -1.03 -0.052
# Abs corrd mean of "pos drift":  0.0951
# Corrd. mean: -0.0302 -2.24  0.887
# dt: 2
# Raw means:  0.0101 -1.02 -0.0351
# Abs corrd mean of "pos drift":  0.0604
# Corrd. mean:  0.0307 -2.16  0.929

# %%
np.mean(results[0].raw_drift, axis=0)
# Out:
# array([ 0.00074617, -0.03517275])

# %%
np.mean(results[1].raw_drift, axis=0)
# Out:
# array([ 4.84925613e-05, -3.26507749e-02])

# %%
np.mean(results[0].corr_drift, axis=0)
# Out:
# array([0.02328407, 0.96418637])

# %%
np.mean(results[1].corr_drift, axis=0)
# Out:
# array([6.17849419e-04, 9.73355027e-01])

# %%
np.mean(results[1].corr_drift - results[0].corr_drift, axis=0)
# Out:
# array([-0.02266622,  0.00916866])

# %%
results[0].corr_drift
# Out:
# array([[ 0.06786199,  1.01457143],
#        [-0.04549283,  0.94636148],
#        [ 0.01508944,  0.93514417],
#        [ 0.09594811,  0.94848685],
#        [ 0.01201363,  1.00904193],
#        [-0.0134747 ,  0.98890529],
#        [ 0.01264433,  0.9402667 ],
#        [ 0.01358361,  0.97562681],
#        [ 0.04165283,  0.96869295],
#        [ 0.03301426,  0.9147661 ]])

# %%
results[1].corr_drift
# Out:
# array([[-3.71688218e-02,  9.80206810e-01],
#        [ 5.34368416e-02,  1.09764639e+00],
#        [ 2.82594912e-02,  9.52394996e-01],
#        [-3.38318277e-02,  9.36322826e-01],
#        [-2.02501933e-04,  9.84895393e-01],
#        [-3.16223444e-03,  9.12080562e-01],
#        [ 2.94493568e-02,  9.21626619e-01],
#        [ 1.27977925e-02,  9.45892049e-01],
#        [ 7.59940407e-03,  1.04202442e+00],
#        [-5.09990062e-02,  9.60460213e-01]])

# %%
corrd_drift_coeffs_arr
# Out:
# array([[ 0.06786199,  1.01457143],
#        [-0.04549283,  0.94636148],
#        [ 0.01508944,  0.93514417],
#        [ 0.09594811,  0.94848685],
#        [ 0.01201363,  1.00904193],
#        [-0.0134747 ,  0.98890529],
#        [ 0.01264433,  0.9402667 ],
#        [ 0.01358361,  0.97562681],
#        [ 0.04165283,  0.96869295],
#        [ 0.03301426,  0.9147661 ]])

# %%
drift_coeffs_arr
# Out:
# array([[ 0.00030197, -0.03927493],
#        [-0.00361629, -0.0318247 ],
#        [ 0.00704096, -0.0528701 ],
#        [ 0.01202096, -0.03769551],
#        [-0.00276248, -0.02637747],
#        [ 0.00458409, -0.02906037],
#        [-0.00347981, -0.02546047],
#        [ 0.00649539, -0.03704642],
#        [-0.00259211, -0.03286638],
#        [-0.01053103, -0.03925119]])

# %% [markdown]
# dt=5e-4 30k steps

# %%
pos_drift_coeffs_arr
# Out:
# array([[ 0.00492661],
#        [-0.00815764],
#        [-0.00444284],
#        [ 0.0048892 ],
#        [ 0.00656983]])

# %%
friction_coeffs_arr
# Out:
# array([[-0.03732824],
#        [-0.03212332],
#        [-0.03102789],
#        [-0.04690479],
#        [-0.02760071]])

# %% [markdown]
# dt=5e-4 15k steps

# %%
pos_drift_coeffs_arr
# Out:
# array([[ 0.01308915],
#        [ 0.01255854],
#        [ 0.02164301],
#        [-0.00437652],
#        [-0.01624206]])

# %%
friction_coeffs_arr
# Out:
# array([[-0.05844831],
#        [-0.08187356],
#        [-0.07982549],
#        [-0.05845112],
#        [-0.08324304]])

# %% [markdown]
# dt=1e-3 15k steps

# %%
pos_drift_coeffs_arr
# Out:
# array([[-0.00167173],
#        [ 0.00109067],
#        [-0.00721201],
#        [ 0.00609725],
#        [-0.00749438]])

# %%
friction_coeffs_arr
# Out:
# array([[-0.03801686],
#        [-0.0435851 ],
#        [-0.04291226],
#        [-0.03408239],
#        [-0.04172269]])

# %%
data = deepcopy(constant_gamma_diff_data)
X = np.concatenate([trj["x"] for trj in data], axis=0)
U = np.concatenate([trj["u"] for trj in data], axis=0)
V = np.concatenate([trj["v"] for trj in data], axis=0)

# %%
b_eval = KM_estimator.evaluate_basis_matrix(X,V)

# %%
b_eval
# Out:
# array([[ 1.        , -0.00182653],
#        [ 1.        , -0.02377556],
#        [ 1.        , -0.03583377],
#        ...,
#        [ 1.        ,  0.66537662],
#        [ 1.        ,  0.67343009],
#        [ 1.        ,  0.66698842]])

# %%
KM_estimator.build_gram_matrix(b_eval)
# Out:
# array([[ 1.        , -0.07233352],
#        [-0.07233352,  0.48759345]])

# %%
G = KM_estimator.build_gram_matrix(b_eval)

# %%
KM_estimator.model.drift.coefficients
# Out:
# array([ 0.00656983, -0.02760071])

# %%
KM_estimator.model.diffusion.coefficients
# Out:
# array([0.33306075])

# %%
KM_estimator.inverse_sqrt_gram(b_eval)
# Out:
# array([[1.00353188, 0.06140599],
#        [0.06140599, 1.43852844]])

# %%
H = KM_estimator.inverse_sqrt_gram(b_eval)

# %%
H@H
# Out:
# array([[1.01084693, 0.14995714],
#        [0.14995714, 2.07313477]])

# %%
H@H.T
# Out:
# array([[1.01084693, 0.14995714],
#        [0.14995714, 2.07313477]])

# %%
KM_estimator.inverse_sqrt_gram(b_eval) @ KM_estimator.build_gram_matrix(b_eval) @ KM_estimator.inverse_sqrt_gram(b_eval)
# Out:
# array([[ 1.00000000e+00, -3.18982611e-17],
#        [ 6.30441587e-18,  1.00000000e+00]])

# %%
KM_estimator.compute_drift_correction(X) * 3/2
# Out:
# array([0.        , 0.49959113])

# %%
constfrict.drift.coefficients
# Out:
# array([ 0.00656983, -0.02760071])

# %%
phi = constfrict.drift.coefficients @H
w = KM_estimator.compute_drift_correction(X) * 3/2 @ H

# %%
phi+w
# Out:
# array([0.03557608, 0.67937506])

# %%
H @ (phi+w)
# Out:
# array([0.07741943, 0.97948494])

# %% [markdown]
# not ridiculous but still heavily biased... is it bcs of higher order terms ? -> try to reduce dt

# %% [markdown]
# not good

# %%
H@(constfrict.drift.coefficients + KM_estimator.compute_drift_correction(X)*12/5)
# Out:
# array([-0.00344894, -0.06132965,  1.03910835])

# %%
model_simu.coefficients
# Out:
# array([ 0. , -0.1,  1. ,  0.5])

# %%
w0 = KM_estimator.compute_drift_correction(X) @ H

# %%
def corcoef(y):
    c_base = phi + w0 * y
    return H @ c_base

# %%
model_simu.coefficients
# Out:
# array([ 0. , -0.1,  1. ,  0.5])

# %%
H @ c_base
# Out:
# array([0.01926696, 0.04407113, 2.00919763])

# %%
model_simu.drift.coefficients
# Out:
# array([ 0. , -0.1,  1. ])

# %%
KM_estimator.model.friction.grad_coeffs(X).T @ KM_estimator.model.friction.grad_coeffs(X)
# Out:
# array([[899820.]])

# %%
diff_function.n_functions_features_
# Out:
# 1

# %% [markdown]
# ####

# %%
constfrict.diffusion.coefficients
# Out:
# array([0.20884947])

# %%
np.sqrt(1e-3)
# Out:
# 0.03162277660168379

# %%
2.172/3
# Out:
# 0.7240000000000001

# %%
constfrict.coefficients
# Out:
# array([-4.65777978e-02,  8.00037637e-01, -1.75520712e-04, -3.77563476e-02,
#         4.12697337e-01,  1.25281735e+00])

# %%
model_simu.coefficients
# Out:
# array([-0.  ,  0.9 , -0.  , -0.04,  1.  ,  3.  ])

# %%
cor_finvels.coefficients
# Out:
# array([-1.16323109e-01,  9.17713445e-01,  8.12839817e-03, -4.04035207e-02,
#         1.12931482e+00,  1.93892663e-01, -7.76448016e-06,  1.00453915e-01])

# %%
realvels.coefficients
# Out:
# array([-0.05216949,  0.94514994,  0.0124966 , -0.04152955,  0.95251845,
#         0.20156959,  0.00279034,  0.09945959])

# %%
X = np.concatenate([trj["x"] for trj in constant_gamma_diff_data], axis=0)
num_bins = 100
histo , edges = np.histogram(X, bins=num_bins)
centers = (edges[1:] + edges[:-1])/2
free_e = -np.log(histo)
free_e -= free_e[num_bins//2]
plt.plot(centers, free_e)
plt.plot(xfa, free_energy(xfa.reshape(-1, 1)), label='Model' )

# %%
np.std(trj["v"])
# Out:
# 1.0540919367685566

# %%
np.std(trj["u"])
# Out:
# 1.053531582640164

# %%
2 * np.sqrt(VEC_res.diffusion(trj["x"]).ravel().mean()) * trj["dt"]
# Out:
# 0.0025844626576756596

# %% [markdown]
# ### VEC likelihood finite-diff correction

# %% [markdown]
# #### Before correcting KM drift
#
# Bias on friction and free energy estimates.

# %%
xfa = np.linspace(-6,6,100)
xfarg = xfa.reshape(-1, 1)
fig, axs = plt.subplots(1,3, figsize=(12,5))
axs[0].plot(xfa, force_function(xfa.reshape(-1, 1)), label='Model' )
axs[0].plot(xfa, cor_finvels.pos_drift(xfarg), label='Corr. fin. vels.')
axs[0].plot(xfa, realvels.pos_drift(xfarg), label='Real vels.')
axs[0].plot(xfa, VEC_res.pos_drift(xfarg), label='VEC')
axs[1].plot(xfa, friction_function(xfarg), label='Model')
axs[1].plot(xfa, cor_finvels.friction(xfarg), label='Corr. fin. vels.')
axs[1].plot(xfa, realvels.friction(xfarg), label='Real vels.')
axs[1].plot(xfa, VEC_res.friction(xfarg), label='VEC')
axs[2].plot(xfa, diff_function(xfarg), label='Model')
axs[2].plot(xfa, cor_finvels.diffusion(xfarg), label='Corr. fin. vels.')
axs[2].plot(xfa, realvels.diffusion(xfarg), label='Real vels.')
axs[2].plot(xfa, VEC_res.diffusion(xfarg), label='VEC')

plt.legend()
plt.show()
# Out:
# /home/student/Documents/langevin/folie/folie/estimation/transitionDensity.py:38: RuntimeWarning: invalid value encountered in log
#   ll = -0.5 * np.einsum("ti,ti-> t", xt - E, invVE) - 0.5 * np.log(np.sqrt(2 * np.pi) * np.linalg.det(V))
# /home/student/Documents/langevin/folie/folie/estimation/transitionDensity.py:38: RuntimeWarning: invalid value encountered in log
#   ll = -0.5 * np.einsum("ti,ti-> t", xt - E, invVE) - 0.5 * np.log(np.sqrt(2 * np.pi) * np.linalg.det(V))
# /home/student/Documents/langevin/folie/folie/estimation/transitionDensity.py:38: RuntimeWarning: invalid value encountered in log
#   ll = -0.5 * np.einsum("ti,ti-> t", xt - E, invVE) - 0.5 * np.log(np.sqrt(2 * np.pi) * np.linalg.det(V))
# /home/student/Documents/langevin/folie/folie/estimation/transitionDensity.py:38: RuntimeWarning: invalid value encountered in log
#   ll = -0.5 * np.einsum("ti,ti-> t", xt - E, invVE) - 0.5 * np.log(np.sqrt(2 * np.pi) * np.linalg.det(V))
# /home/student/Documents/langevin/folie/folie/estimation/transitionDensity.py:38: RuntimeWarning: invalid value encountered in log
#   ll = -0.5 * np.einsum("ti,ti-> t", xt - E, invVE) - 0.5 * np.log(np.sqrt(2 * np.pi) * np.linalg.det(V))
# /home/student/Documents/langevin/folie/folie/estimation/transitionDensity.py:38: RuntimeWarning: invalid value encountered in log
#   ll = -0.5 * np.einsum("ti,ti-> t", xt - E, invVE) - 0.5 * np.log(np.sqrt(2 * np.pi) * np.linalg.det(V))
# /home/student/Documents/langevin/folie/folie/estimation/transitionDensity.py:38: RuntimeWarning: invalid value encountered in log
#   ll = -0.5 * np.einsum("ti,ti-> t", xt - E, invVE) - 0.5 * np.log(np.sqrt(2 * np.pi) * np.linalg.det(V))
# /home/student/Documents/langevin/folie/folie/estimation/transitionDensity.py:38: RuntimeWarning: invalid value encountered in log
#   ll = -0.5 * np.einsum("ti,ti-> t", xt - E, invVE) - 0.5 * np.log(np.sqrt(2 * np.pi) * np.linalg.det(V))
# /home/student/Documents/langevin/folie/folie/estimation/transitionDensity.py:38: RuntimeWarning: invalid value encountered in log
#   ll = -0.5 * np.einsum("ti,ti-> t", xt - E, invVE) - 0.5 * np.log(np.sqrt(2 * np.pi) * np.linalg.det(V))

# %% [markdown]
# #### After correcting KM

# %% [markdown]
# ##### Functions

# %%
from dataclasses import dataclass
from typing import Union

@dataclass
class PerTimeAnalysis():
    dt: float
    nsteps: int
    n_fits: int
    ntrajs: int
    exact_vels: bool
    KM_pos_drift: fl.functions.FunctionSum
    KM_friction: fl.functions.FunctionSum
    KM_diffusion: fl.functions.FunctionSum
    VEC_pos_drift: fl.functions.FunctionSum
    VEC_friction: fl.functions.FunctionSum
    VEC_diffusion: fl.functions.FunctionSum

@dataclass
class OneSimEstResults():
    dt: int
    nsteps: int
    ntrajs: int
    exact_vels: bool
    KM_est: fl.estimation.direct_estimation.UnderdampedKramersMoyalEstimator
    VEC_est: Union[fl.estimation.mle.LikelihoodEstimator, None]
    Eul_est: Union[fl.estimation.mle.LikelihoodEstimator, None]
    data: Union[fl.Trajectories, None]

# %%
def build_pol_model(free_energy_coef = 0.1*np.array([0,0,-4.5,0,0.1]), diff_coef = np.asarray([0.5,0.,0.1]),
               friction_coef = np.asarray([1.,0.,0.04])):
    
    free_energy = np.polynomial.Polynomial(free_energy_coef)
    force_coeff = - free_energy.deriv(1).coef
    force_function = fl.functions.Polynomial(deg=len(force_coeff)-1,coefficients=np.asarray(force_coeff))
    diff_function= fl.functions.Polynomial(deg=len(diff_coef)-1,coefficients=np.asarray(diff_coef))
    friction_function = fl.functions.Polynomial(deg=len(friction_coef)-1,coefficients=np.asarray(friction_coef))

    model_simu = fl.models.underdamped.Underdamped(force_function,friction_function, diffusion=diff_function)

    return model_simu

model_simu = build_pol_model()

# %%
def simulation_estimation(results_list = [],  n_fits = 10, ntrajs=60, X0 = None, dt_list = None,
                          nsteps_list = None, dt_base=8e-3, nsteps_base = 15000, do_VEC = True,
                          keep_product_constant=False, compare_exact_vels=True,
                          **model_kwargs):

    current_results = results_list

    model_simu = build_pol_model(**model_kwargs)    
        
    if dt_list is None:
        if nsteps_list is None:
            dt_list = [dt_base]
            nsteps_list = [nsteps_base]
        else:
            if keep_product_constant:
                dt_list = dt_base / np.asarray(nsteps_list) * nsteps_base
            else:
                dt_list = [dt_base] * len(nsteps_list)
    elif nsteps_list is None:
        if keep_product_constant:
            nsteps_list = nsteps_base / np.asarray(dt_list) * dt_base
        else:
            nsteps_list = [nsteps_base] * len(dt_list)

    if compare_exact_vels:
        dt_list = np.repeat(dt_list, 2)
        nsteps_list = np.repeat(nsteps_list, 2)
        exact_vels_list = np.empty((len(dt_list),))
        exact_vels_list[::2] = False
        exact_vels_list[1::2] = True
    else:
        exact_vels_list = np.repeat([False], len(dt_list))

    
    for dt, nsteps, exact_vels in zip(dt_list, nsteps_list, exact_vels_list):
        
        simulator = fl.simulations.UnderdampedSimulator(fl.simulations.VECStepper(model_simu), dt)

        # return model_simu
        KM_pos_drift, KM_friction, KM_diffusion, VEC_pos_drift, VEC_friction, VEC_diffusion = [], [], [], [], [], [], 
        
        for it in range(n_fits):
        
            if X0 is None:
                X0 = np.zeros(2*ntrajs)
            
            data = simulator.run(nsteps, X0, 1)

            if not exact_vels:
                for trj in data:
                    del(trj["v"])
        
            trainmodel = model_simu
            KM_estimator = fl.UnderdampedKramersMoyalEstimator(deepcopy(trainmodel))
            KM_res = deepcopy(KM_estimator.fit_fetch(data))
        
            KM_pos_drift.append(KM_res.pos_drift)
            KM_friction.append(KM_res.friction)
            KM_diffusion.append(KM_res.diffusion)

            if do_VEC:
                VEC_estimator = fl.LikelihoodEstimator(fl.VECDensity(deepcopy(trainmodel),), n_jobs=10)
                VEC_res = deepcopy(VEC_estimator.fit_fetch(data,  minimize_kwargs={"method": "L-BFGS-B", "options":{"iprint":1}}))

                VEC_pos_drift.append(VEC_res.pos_drift)
                VEC_friction.append(VEC_res.friction)
                VEC_diffusion.append(VEC_res.diffusion)

        
        current_results.append(PerTimeAnalysis(dt=dt, nsteps=nsteps, exact_vels=exact_vels, n_fits=n_fits, ntrajs=ntrajs,
                                               KM_pos_drift=fl.functions.FunctionSum(KM_pos_drift), 
                                               KM_friction = fl.functions.FunctionSum(KM_friction),
                                               KM_diffusion = fl.functions.FunctionSum(KM_diffusion),
                                               VEC_pos_drift=fl.functions.FunctionSum(VEC_pos_drift),
                                               VEC_friction = fl.functions.FunctionSum(VEC_friction),
                                               VEC_diffusion = fl.functions.FunctionSum(VEC_diffusion),                     
                                              ))
    return current_results

def one_simulation_estimation(ntrajs=60, X0 = None, dt=8e-3, nsteps = 15000, exact_vels=False, do_VEC = True,
                              model_simu = None, trainmodel = None, data=None, coefficients0=None, 
                              correct_finite_diff_vel_KM=True, stepper = fl.simulations.VECStepper, save_every=1,
                              return_data=False, use_jac = True, do_Euler = False,
                             ):

    if model_simu is None:
        model_simu = build_pol_model()           
    simulator = fl.simulations.UnderdampedSimulator(stepper(model_simu), dt)
    if X0 is None:
        X0 = np.zeros(2*ntrajs)
        
    if data is None:
        data = simulator.run(nsteps, X0, save_every)
        if not exact_vels:
            for trj in data:
                del(trj["v"])
    else:
        dt = data[0]["dt"]
        ntrajs = len(data)
        nsteps = len(data[0]["x"])
        exact_vels = "v" in data[0]


    if trainmodel is None:
        trainmodel = model_simu
        
    KM_estimator = fl.UnderdampedKramersMoyalEstimator(deepcopy(trainmodel))
    KM_estimator.fit(data, correct_finite_diff_vel=correct_finite_diff_vel_KM)

    if do_VEC:
        VEC_estimator = fl.LikelihoodEstimator(fl.VECDensity(deepcopy(trainmodel),), n_jobs=10,)
        VEC_estimator.fit(data, coefficients0=coefficients0, use_jac=use_jac, minimize_kwargs={"method": "L-BFGS-B", "options":{"iprint":1}})

    if do_Euler:
        Eul_estimator = fl.LikelihoodEstimator(fl.underdamped_transitionDensity.UnderdampedTransitionDensity(deepcopy(trainmodel),), n_jobs=10)
        Eul_estimator.fit(data, coefficients0=coefficients0, use_jac=use_jac, minimize_kwargs={"method": "L-BFGS-B", "options":{"iprint":1}})
    
    return OneSimEstResults(dt=dt, nsteps=nsteps, ntrajs=ntrajs, exact_vels=exact_vels,
            KM_est=KM_estimator, VEC_est=[VEC_estimator if do_VEC else None][0], 
                            Eul_est = [Eul_estimator if do_Euler else None][0],
                            data=[data if return_data else None][0])

# %%
def plot_results(simulation_estimation_res, xfa = np.linspace(-6,6,100), show=True, **model_kwargs):
    
    model_simu = build_pol_model(**model_kwargs)

    xfarg = xfa.reshape(-1, 1)
    fig, axs = plt.subplots(1,3, figsize=(12,5))
    
    axs[0].plot(xfa, model_simu.pos_drift(xfa.reshape(-1, 1)), label='Model' , c='k')
    axs[1].plot(xfa, model_simu.friction(xfarg), c='k')
    axs[2].plot(xfa, model_simu.diffusion(xfarg), c='k')

    # Set up a colormap
    cmap = plt.get_cmap('Dark2')  # or another like 'Set1', 'Dark2', etc.
    markersize = 4 # Small uniform marker size
    marker_step = 10

    for i, res in enumerate(simulation_estimation_res):
        color = cmap(i % 10)
        exact_vels, not_exact_vels = bool(res.exact_vels), bool(1 - res.exact_vels)

        label_suffix = '(real vels.)' if exact_vels else '(est. vels.)'
        label_base = f'dt={res.dt:.1e} nsteps={res.nsteps} {label_suffix}'

        # KM
        y_KM_drift = res.KM_pos_drift(xfarg)
        axs[0].plot(xfa, y_KM_drift, '--', color=color)
        axs[0].plot(xfa[::marker_step], y_KM_drift[::marker_step], 'o', color=color, markersize=markersize, label=f'KM {label_base}')

        y_KM_friction = res.KM_friction(xfarg)
        axs[1].plot(xfa, y_KM_friction, '--', color=color)
        axs[1].plot(xfa[::marker_step], y_KM_friction[::marker_step], 'o', color=color, markersize=markersize)

        y_KM_diffusion = res.KM_diffusion(xfarg)
        axs[2].plot(xfa, y_KM_diffusion, '--', color=color)
        axs[2].plot(xfa[::marker_step], y_KM_diffusion[::marker_step], 'o', color=color, markersize=markersize)

        # VEC
        y_VEC_drift = res.VEC_pos_drift(xfarg)
        axs[0].plot(xfa, y_VEC_drift, '--', color=color)
        axs[0].plot(xfa[marker_step//2::marker_step], y_VEC_drift[marker_step//2::marker_step], 'x',linestyle='None', color=color, markersize=markersize, label=f'VEC {label_base}')

        y_VEC_friction = res.VEC_friction(xfarg)
        axs[1].plot(xfa, y_VEC_friction, '--', color=color)
        axs[1].plot(xfa[marker_step//2::marker_step], y_VEC_friction[marker_step//2::marker_step], 'x', color=color, markersize=markersize)

        y_VEC_diffusion = res.VEC_diffusion(xfarg)
        axs[2].plot(xfa, y_VEC_diffusion, '--', color=color)
        axs[2].plot(xfa[marker_step//2::marker_step], y_VEC_diffusion[marker_step//2::marker_step], 'x', color=color, markersize=markersize)
        # axs[0].plot(xfa, res.KM_pos_drift(xfarg), 'o-', label=f'KM '+f'(real '*exact_vels + f'(est. '*not_exact_vels + 'vels.)'+
        #            f'dt={res.dt:.1e} nsteps={res.nsteps}')
        # axs[0].plot(xfa, res.VEC_pos_drift(xfarg), 'x-', label=f'VEC '+f'(real '*exact_vels+f'(est. '*not_exact_vels + 'vels.)'+
        #            f'dt={res.dt:.1e} nsteps={res.nsteps}')
        # axs[1].plot(xfa, res.KM_friction(xfarg), 'o-', )
        # axs[1].plot(xfa, res.VEC_friction(xfarg), 'x-',)
        # axs[2].plot(xfa, res.KM_diffusion(xfarg), 'o-', )
        # axs[2].plot(xfa, res.VEC_diffusion(xfarg), 'x-',)

    axs[0].legend()
    axs[0].set_title('Mean force')
    axs[1].set_title('Friction')
    axs[2].set_title('Diffusion')
    for ax in axs:
        ax.set_xlabel('x')
        ax.grid()
    if show:
        plt.show()

    return fig, axs

def plot_one_result(one_simulation_estimation_res, xfa = np.linspace(-6,6,100), 
                    fig=None, axs=None, show=True, KM_label=None, VEC_label=None,
                    Eul_label=None, model_simu=build_pol_model()):

    res = one_simulation_estimation_res

    xfarg = xfa.reshape(-1, 1)
    
    if fig is None:
        fig, axs = plt.subplots(1,3, figsize=(12,5))
        axs[0].plot(xfa, model_simu.pos_drift(xfa.reshape(-1, 1)), label='Model' )
        axs[1].plot(xfa, model_simu.friction(xfarg))
        axs[2].plot(xfa, model_simu.diffusion(xfarg))

    exact_vels, not_exact_vels = bool(res.exact_vels), bool(1-res.exact_vels)

    if KM_label is None:
        KM_label = f'KM '+f'(real '*exact_vels + f'(est. '*not_exact_vels + 'vels.)'
    if VEC_label is None:
        VEC_label = 'VEC ' + KM_label[3:]
    if Eul_label is None:
        Eul_label = 'Eul ' + KM_label[3:]

    axs[0].plot(xfa, res.KM_est.model.pos_drift(xfarg), '--', label=KM_label)
    axs[1].plot(xfa, res.KM_est.model.friction(xfarg), '--', )
    axs[2].plot(xfa, res.KM_est.model.diffusion(xfarg), '--', )

    if res.VEC_est is not None:
        axs[0].plot(xfa, res.VEC_est.model.pos_drift(xfarg), '-.', label=VEC_label)
        axs[1].plot(xfa, res.VEC_est.model.friction(xfarg), '-.',)
        axs[2].plot(xfa, res.VEC_est.model.diffusion(xfarg), '-.',)

    if res.Eul_est is not None:
        axs[0].plot(xfa, res.Eul_est.model.pos_drift(xfarg), '-.', label=Eul_label)
        axs[1].plot(xfa, res.Eul_est.model.friction(xfarg), '-.',)
        axs[2].plot(xfa, res.Eul_est.model.diffusion(xfarg), '-.',)

    axs[0].legend()
    axs[0].set_title('Mean force')
    axs[1].set_title('Friction')
    axs[2].set_title('Diffusion')
    
    for ax in axs:
        ax.set_xlabel('x')
        ax.grid(visible=True)
    if show:
        plt.show()

    return fig, axs

# %% [markdown]
# ##### Comparing KM and VEC with parabolic friction and diffusion in double well

# %%
for i, res in enumerate(one_fit_comp_km_vec):
    print('Result' ,i)
    for attr in ['dt', 'nsteps', 'n_fits', 'exact_vels',
                ]:
        print(attr ,':',getattr(res, attr))
# Out:
# Result 0
# dt : 0.008
# nsteps : 15000
# n_fits : 1
# exact_vels : 0.0
# Result 1
# dt : 0.008
# nsteps : 15000
# n_fits : 1
# exact_vels : 1.0

# %%
one_fit_comp_km_vec = simulation_estimation(n_fits = 1)
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           10     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -8.36572D+00    |proj g|=  3.21790D+00
#  This problem is unconstrained.
# At iterate    1    f= -8.47537D+00    |proj g|=  2.57679D+00
#
# At iterate    2    f= -8.48689D+00    |proj g|=  6.17437D-02
#
# At iterate    3    f= -8.48691D+00    |proj g|=  5.98037D-02
#
# At iterate    4    f= -8.48696D+00    |proj g|=  6.84150D-02
#
# At iterate    5    f= -8.48705D+00    |proj g|=  1.50604D-01
#
# At iterate    6    f= -8.48733D+00    |proj g|=  3.15609D-01
#
# At iterate    7    f= -8.48798D+00    |proj g|=  5.50542D-01
#
# At iterate    8    f= -8.48948D+00    |proj g|=  8.65252D-01
#
# At iterate    9    f= -8.49168D+00    |proj g|=  1.01486D+00
#
# At iterate   10    f= -8.49355D+00    |proj g|=  6.55965D-01
#
# At iterate   11    f= -8.49461D+00    |proj g|=  6.89489D-02
#
# At iterate   12    f= -8.49463D+00    |proj g|=  3.18276D-02
#
# At iterate   13    f= -8.49465D+00    |proj g|=  2.57511D-02
#
# At iterate   14    f= -8.49468D+00    |proj g|=  5.40205D-02
#
# At iterate   15    f= -8.49470D+00    |proj g|=  4.88311D-02
#
# At iterate   16    f= -8.49476D+00    |proj g|=  3.94645D-02
#
# At iterate   17    f= -8.49482D+00    |proj g|=  3.03958D-02
#
# At iterate   18    f= -8.49483D+00    |proj g|=  3.46426D-02
#
# At iterate   19    f= -8.49484D+00    |proj g|=  4.32832D-03
#
# At iterate   20    f= -8.49484D+00    |proj g|=  7.83558D-04
#
# At iterate   21    f= -8.49484D+00    |proj g|=  1.97406D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    10     21     35      1     0     0   1.974D-04  -8.495D+00
#   F =  -8.4948353179180618
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           10     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -7.93004D+00    |proj g|=  4.15735D-02
#
# At iterate    1    f= -7.93005D+00    |proj g|=  2.47181D-02
#
# At iterate    2    f= -7.93006D+00    |proj g|=  6.13690D-03
#
# At iterate    3    f= -7.93006D+00    |proj g|=  8.61345D-03
#
# At iterate    4    f= -7.93007D+00    |proj g|=  1.74827D-02
#
# At iterate    5    f= -7.93008D+00    |proj g|=  1.14535D-02
#
# At iterate    6    f= -7.93008D+00    |proj g|=  2.63950D-03
#
# At iterate    7    f= -7.93008D+00    |proj g|=  1.81285D-03
#
# At iterate    8    f= -7.93008D+00    |proj g|=  4.73555D-03
#
# At iterate    9    f= -7.93008D+00    |proj g|=  5.75966D-03
#
# At iterate   10    f= -7.93008D+00    |proj g|=  5.96390D-03
#
# At iterate   11    f= -7.93009D+00    |proj g|=  6.13037D-03
#
# At iterate   12    f= -7.93009D+00    |proj g|=  4.16219D-03
#
# At iterate   13    f= -7.93009D+00    |proj g|=  3.25985D-03
#
# At iterate   14    f= -7.93009D+00    |proj g|=  1.88267D-04
#
# At iterate   15    f= -7.93009D+00    |proj g|=  2.43632D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    10     15     18      1     0     0   2.436D-04  -7.930D+00
#   F =  -7.9300901512666870
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH

# %%
fin_dif_vels, real_vels = one_fit_comp_km_vec

# %%
fig, axs = plot_results([fin_dif_vels], show=False)
xfa = np.linspace(-6,6,100)
axs[2].plot(xfa, 3/2*fin_dif_vels.VEC_diffusion(xfa.reshape(-1,1)), '-.', label=r'VEC diffusion $\times$ 3/2')
axs[2].legend()
plt.show()

# %%
plot_results([real_vels])

# %% [markdown]
# ##### Comparing KM and VEC with parabolic friction and constant diffusion in double well

# %%
for i, res in enumerate(const_diff):
    print('Result' ,i)
    for attr in ['dt', 'nsteps', 'n_fits', 'exact_vels',
                ]:
        print(attr ,':',getattr(res, attr))
# Out:
# Result 0
# dt : 0.008
# nsteps : 15000
# n_fits : 1
# exact_vels : 0.0
# Result 1
# dt : 0.008
# nsteps : 15000
# n_fits : 1
# exact_vels : 1.0

# %%
const_diff = simulation_estimation(n_fits=1, diff_coef=np.asarray([.5]))
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            8     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -9.86231D+00    |proj g|=  8.62201D-01
#  This problem is unconstrained.
# At iterate    1    f= -9.99113D+00    |proj g|=  9.60509D-02
#
# At iterate    2    f= -9.99135D+00    |proj g|=  1.67595D-01
#
# At iterate    3    f= -9.99154D+00    |proj g|=  3.18114D-02
#
# At iterate    4    f= -9.99163D+00    |proj g|=  2.72556D-02
#
# At iterate    5    f= -9.99180D+00    |proj g|=  7.96266D-03
#
# At iterate    6    f= -9.99180D+00    |proj g|=  2.99547D-04
#
# At iterate    7    f= -9.99180D+00    |proj g|=  7.92202D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     8      7     12      1     0     0   7.922D-05  -9.992D+00
#   F =  -9.9918016483709291
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            8     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -9.44786D+00    |proj g|=  1.59801D-02
#  This problem is unconstrained.
# At iterate    1    f= -9.44790D+00    |proj g|=  1.83084D-02
#
# At iterate    2    f= -9.44791D+00    |proj g|=  7.70879D-03
#
# At iterate    3    f= -9.44791D+00    |proj g|=  4.27091D-03
#
# At iterate    4    f= -9.44792D+00    |proj g|=  2.72585D-03
#
# At iterate    5    f= -9.44792D+00    |proj g|=  6.63459D-04
#
# At iterate    6    f= -9.44792D+00    |proj g|=  8.26404D-05
#
# At iterate    7    f= -9.44792D+00    |proj g|=  8.17865D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     8      7     11      1     0     0   8.179D-05  -9.448D+00
#   F =  -9.4479189119526215
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH

# %%
fin_dif_vels_consdif, real_vels_consdif = const_diff

# %%
fig, axs = plot_results([fin_dif_vels_consdif], show=False, diff_coef=np.asarray([.5]))
xfa = np.linspace(-6,6,100)
axs[2].plot(xfa, 3/2*fin_dif_vels_consdif.VEC_diffusion(xfa.reshape(-1,1)), '-.', label=r'VEC diffusion $\times$ 3/2')
axs[2].legend()
plt.show()

# %%
plot_results([real_vels_consdif], diff_coef=[.5])
# Out:
# (<Figure size 1200x500 with 3 Axes>,
#  array([<Axes: title={'center': 'Mean force'}, xlabel='x'>,
#         <Axes: title={'center': 'Friction'}, xlabel='x'>,
#         <Axes: title={'center': 'Diffusion'}, xlabel='x'>], dtype=object))

# %% [markdown]
# ##### Testing David's noise correction for VEC
#
# Starting optimization from Kramers-Moyal coefficients with modified velocities

# %%
km_sim = one_simulation_estimation(do_VEC=False, return_data=True, model_simu=build_pol_model(diff_coef=[.5]))

# %%
data_to_correct = km_sim.data
init_coeffs = km_sim.KM_est.model.coefficients
model_simu = build_pol_model(diff_coef=[.5])
vec_dens = fl.VECDensity(model=model_simu)
for trj in data_to_correct:
    trj = vec_dens.correct_velocities(trj)

# %%
for trj in data_to_correct:
    trj["u"] = trj["v"].copy()

# %%
vec_sim = one_simulation_estimation(model_simu=build_pol_model(diff_coef=[.5]), data=data_to_correct, coefficients0=init_coeffs, correct_finite_diff_vel_KM=False)

# %%
new_km_sim_with_correction = one_simulation_estimation(do_VEC=False, data=data_to_correct, 
                                                          model_simu=build_pol_model(diff_coef=[.5]),
                                                         correct_finite_diff_vel_KM=True)

# %%
fig, axs = plot_one_result(vec_sim, diff_coef=[.5], show=False, KM_label='KM David corr', VEC_label='VEC David corr')
plot_one_result(new_km_sim_with_correction, diff_coef=[.5], show=False, fig=fig, axs=axs, KM_label="KM David + Ronceray")
_,__=plot_one_result(km_sim, diff_coef=[.5], show=True, fig=fig, axs=axs, KM_label='KM Ronceray')

# %% [markdown]
# - VEC + David correction : bad
# - KM + David correction : bad
# - KM + David correction + Ronceray correction : exactly equivalent to KM + Ronceray correction (which is perfect)
#
# This is quite counter-intuitive since one wouldn't expect David's correction to mess up KM before Ronceray magically makes it right again.

# %% [markdown]
# ##### What does the jacobian do to VEC ?

# %%
model_simu = build_pol_model(diff_coef=[.5])
no_jac = one_simulation_estimation(model_simu=model_simu, use_jac=False)

# %%
plot_one_result(no_jac, diff_coef=[.5], VEC_label = 'VEC w/o jacobian', show=True)
# Out:
# (<Figure size 1200x500 with 3 Axes>,
#  array([<Axes: title={'center': 'Mean force'}, xlabel='x'>,
#         <Axes: title={'center': 'Friction'}, xlabel='x'>,
#         <Axes: title={'center': 'Diffusion'}, xlabel='x'>], dtype=object))

# %% [markdown]
# If we compare to the VEC optimization with jacobian (two subsections above) we can clearly see that **they are exactly the same** : **jacobian has no impact on the minimum in this case.**
#
# **HOWEVER WE SAW IN OTHER CASES THAT NOT USING A JACOBIAN CAN REALLY MESS UP WITH THE MINIMIZATION AND YIELD VERY STRANGE RESULTS : KEEP THAT IN MIND**

# %%
no_jac.VEC_est.model.diffusion.coefficients
# Out:
# array([2.84e-01])

# %% [markdown]
# Maybe there is a simple correction to do to the VEC estimated diffusion as is with finite diff velocities to get to the true value ? (Ideally a coefficient...). We should try that out on different models (compute ratio betwen real coeffs and the coeffs that we estimate w/ finite-diff vels. + VEC).

# %% [markdown]
# ##### Trying out different models ? (desperately)

# %% [markdown]
# Model 1 : HO + parab frict + const. diff
#
# Model 2 : DW + parab frict + parab diff
#
# Model 3 : DW + const frict + DW diff (for funsies)

# %%
# exact_res_list = []
fe_coefs = [ [0., 0., .1], 0.1*np.array([0,0,-4.5,0,0.1]), 0.1*np.array([0,0,-4.5,0,0.1]) ]
frict_coefs = [ np.asarray([1.,0.,0.04]), np.asarray([1.,0.,0.04]), [1.] ]
diff_coefs = [  np.asarray([0.5]),  np.asarray([0.5,0.,0.1]), 0.05*np.array([100.,0,-3.5,0,0.2]) ]

k=0
for fe, fr, di in zip(fe_coefs, frict_coefs, diff_coefs):
    if k ==1:
        model_simu = build_pol_model(free_energy_coef=fe, friction_coef=fr, diff_coef=di)
        res_list.append(one_simulation_estimation(model_simu=model_simu, use_jac=True, exact_vels=False))
    k+=1

# %% [markdown]
# ##### Comparing coefficients for every model :

# %% [markdown]
# Diffusion coefs

# %%
for k in range(3):
    print(diff_coefs[k] / res_list[k].VEC_est.model.diffusion.coefficients)
print(.5 / no_jac.VEC_est.model.diffusion.coefficients)
# Out:
# [1.74e+00]
# [1.73e+00 0.00e+00 1.77e+00]
# [1.74e+00 0.00e+00 1.73e+00 0.00e+00 1.74e+00]
# [1.76e+00]

# %% [markdown]
# **It seems that there IS simply proportionality between actual coefs and estimated coefs !!**
# **Prop. factor $\approx$ 1.74**
#
# This is observed for constant, parabolic and double well diffusion with very different coefficients ; also free energy and friction were varied which suggests this factor is quite general.
#
# Problem : there is no closed-form expression of the estimated diffusion coefficient (contrary to KM), it can only be expressed as $\underset{\Theta}{argmin} ( -\log L(\Theta) )$. As a result it would probably be pretty hard to rigorously show that this coefficient doesn't come from nowhere.

# %% [markdown]
# Friction coefs

# %%
for k in range(3):
    print(frict_coefs[k] / res_list[k].VEC_est.model.friction.coefficients)
# Out:
# [9.80e-01 -0.00e+00 7.60e-01]
# [1.06e+00 -0.00e+00 9.28e-01]
# [1.04e+00]

# %% [markdown]
# Mean force coefs

# %%
for k in range(3):
    print(-np.polynomial.Polynomial(fe_coefs[k]).deriv(1).coef / res_list[k].VEC_est.model.pos_drift.coefficients)
# Out:
# [0.00e+00 9.71e-01]
# [0.00e+00 9.83e-01 -0.00e+00 9.73e-01]
# [-0.00e+00 1.01e+00 0.00e+00 1.03e+00]

# %% [markdown]
# Other coefs. seem roughly unaffected (? maybe they should be idk ; anyway if there is a drift bias it is not as huge as the KM one)

# %%
for k in range(3):
    fig, axs = plot_one_result(res_list[k], free_energy_coef=fe_coefs[k], friction_coef=frict_coefs[k], diff_coef=diff_coefs[k],
                             show=False)
    plot_one_result(exact_res_list[k], fig=fig, axs=axs, free_energy_coef=fe_coefs[k], friction_coef=frict_coefs[k], diff_coef=diff_coefs[k],
                   show=False)
    xfa = ax[2].lines[0].get_xydata()[:,0]
    axs[2].plot(ax[2].lines[0].get_xydata()[:,0], 1.75*res_list[k].VEC_est.model.diffusion(xfa.reshape(-1,1)), '-.', label=r'VEC diffusion $\times$ 7/4')
    axs[2].legend()

# %% [markdown]
# One thing that would work to just get a 7/4 factor out of the minimization would be to multiply every occurence of "c" (=self.model.diffusion) in the log density by 4/7 or 7/4 maybe idk...

# %%
model_simu = build_pol_model(diff_coef=[.5])
test1 = one_simulation_estimation(model_simu=model_simu, use_jac=False)

# %%
plot_one_result(test1, diff_coef=[.5])
# Out:
# (<Figure size 1200x500 with 3 Axes>,
#  array([<Axes: title={'center': 'Mean force'}, xlabel='x'>,
#         <Axes: title={'center': 'Friction'}, xlabel='x'>,
#         <Axes: title={'center': 'Diffusion'}, xlabel='x'>], dtype=object))

# %%
test1.VEC_est.model.diffusion.coefficients * (7/4)**2
# Out:
# array([5.05e-01])

# %% [markdown]
# When we only multiply the first term in Mvv by 7/4 we get a ratio of $7/4^2$ between estimated coef and real coef...

# %%
model_simu = build_pol_model(diff_coef=[.5])
test2 = one_simulation_estimation(model_simu=model_simu, use_jac=True)

# %%
plot_one_result(test2, diff_coef=[.5])
# Out:
# (<Figure size 1200x500 with 3 Axes>,
#  array([<Axes: title={'center': 'Mean force'}, xlabel='x'>,
#         <Axes: title={'center': 'Friction'}, xlabel='x'>,
#         <Axes: title={'center': 'Diffusion'}, xlabel='x'>], dtype=object))

# %% [markdown]
# **Multiplying c, c_x and c_xx by 4/7 : SHIT IT WORKS**

# %% [markdown]
# Let's reproduce our testing with 3 different models

# %%
res_list_corr = []
fe_coefs = [ [0., 0., .1], 0.1*np.array([0,0,-4.5,0,0.1]), 0.1*np.array([0,0,-4.5,0,0.1]) ]
frict_coefs = [ np.asarray([1.,0.,0.04]), np.asarray([1.,0.,0.04]), [1.] ]
diff_coefs = [  np.asarray([0.5]),  np.asarray([0.5,0.,0.1]), 0.05*np.array([100.,0,-3.5,0,0.2]) ]

for fe, fr, di in zip(fe_coefs, frict_coefs, diff_coefs):
    model_simu = build_pol_model(free_energy_coef=fe, friction_coef=fr, diff_coef=di)
    res_list_corr.append(one_simulation_estimation(model_simu=model_simu, use_jac=True, exact_vels=False))

# %%
for k in range(3):
    fig, axs = plot_one_result(res_list_corr[k], free_energy_coef=fe_coefs[k], friction_coef=frict_coefs[k], diff_coef=diff_coefs[k],
                             show=True)
    # plot_one_result(exact_res_list[k], fig=fig, axs=axs, free_energy_coef=fe_coefs[k], friction_coef=frict_coefs[k], diff_coef=diff_coefs[k],
    #                show=False)
    # xfa = ax[2].lines[0].get_xydata()[:,0]
    # axs[2].plot(ax[2].lines[0].get_xydata()[:,0], 1.75*res_list[k].VEC_est.model.diffusion(xfa.reshape(-1,1)), '-.', label=r'VEC diffusion $\times$ 7/4')
    # axs[2].legend()

# %% [markdown]
# ##### Doing c, c_x, c_xx *= 4/7 in the log density seems to be an almost-perfect correction

# %% [markdown]
# *Maybe remaining discrepancies are due to higher-order corrections that we do not take into account*

# %%
model_simu = build_pol_model(diff_coef=[.5])
test3 = one_simulation_estimation(model_simu=model_simu, use_jac=False)
plot_one_result(test3, diff_coef=[.5])
# Out:
# (<Figure size 1200x500 with 3 Axes>,
#  array([<Axes: title={'center': 'Mean force'}, xlabel='x'>,
#         <Axes: title={'center': 'Friction'}, xlabel='x'>,
#         <Axes: title={'center': 'Diffusion'}, xlabel='x'>], dtype=object))
# /home/student/Documents/langevin/folie/folie/estimation/transitionDensity.py:38: RuntimeWarning: invalid value encountered in log
#   ll = -0.5 * np.einsum("ti,ti-> t", xt - E, invVE) - 0.5 * np.log(np.sqrt(2 * np.pi) * np.linalg.det(V))
# /home/student/Documents/langevin/folie/folie/estimation/transitionDensity.py:17: RuntimeWarning: invalid value encountered in log
#   return -0.5 * np.einsum("ti,ti-> t", xt - E, invVE) - 0.5 * np.log(np.sqrt(2 * np.pi) * np.linalg.det(V))
# /home/student/Documents/langevin/langevenv/lib/python3.8/site-packages/numpy/linalg/linalg.py:2139: RuntimeWarning: invalid value encountered in det
#   r = _umath_linalg.det(a, signature=signature)
# /home/student/Documents/langevin/folie/folie/estimation/transitionDensity.py:38: RuntimeWarning: invalid value encountered in log
#   ll = -0.5 * np.einsum("ti,ti-> t", xt - E, invVE) - 0.5 * np.log(np.sqrt(2 * np.pi) * np.linalg.det(V))
# /home/student/Documents/langevin/folie/folie/estimation/transitionDensity.py:17: RuntimeWarning: invalid value encountered in log
#   return -0.5 * np.einsum("ti,ti-> t", xt - E, invVE) - 0.5 * np.log(np.sqrt(2 * np.pi) * np.linalg.det(V))
# /home/student/Documents/langevin/langevenv/lib/python3.8/site-packages/numpy/linalg/linalg.py:2139: RuntimeWarning: invalid value encountered in det
#   r = _umath_linalg.det(a, signature=signature)
# /home/student/Documents/langevin/folie/folie/estimation/transitionDensity.py:38: RuntimeWarning: invalid value encountered in log
#   ll = -0.5 * np.einsum("ti,ti-> t", xt - E, invVE) - 0.5 * np.log(np.sqrt(2 * np.pi) * np.linalg.det(V))
# /home/student/Documents/langevin/folie/folie/estimation/transitionDensity.py:17: RuntimeWarning: invalid value encountered in log
#   return -0.5 * np.einsum("ti,ti-> t", xt - E, invVE) - 0.5 * np.log(np.sqrt(2 * np.pi) * np.linalg.det(V))
# /home/student/Documents/langevin/langevenv/lib/python3.8/site-packages/numpy/linalg/linalg.py:2139: RuntimeWarning: invalid value encountered in det
#   r = _umath_linalg.det(a, signature=signature)
# /home/student/Documents/langevin/folie/folie/estimation/transitionDensity.py:38: RuntimeWarning: invalid value encountered in log
#   ll = -0.5 * np.einsum("ti,ti-> t", xt - E, invVE) - 0.5 * np.log(np.sqrt(2 * np.pi) * np.linalg.det(V))
# /home/student/Documents/langevin/folie/folie/estimation/transitionDensity.py:17: RuntimeWarning: invalid value encountered in log
#   return -0.5 * np.einsum("ti,ti-> t", xt - E, invVE) - 0.5 * np.log(np.sqrt(2 * np.pi) * np.linalg.det(V))
# /home/student/Documents/langevin/langevenv/lib/python3.8/site-packages/numpy/linalg/linalg.py:2139: RuntimeWarning: invalid value encountered in det
#   r = _umath_linalg.det(a, signature=signature)
# /home/student/Documents/langevin/folie/folie/estimation/transitionDensity.py:38: RuntimeWarning: invalid value encountered in log
#   ll = -0.5 * np.einsum("ti,ti-> t", xt - E, invVE) - 0.5 * np.log(np.sqrt(2 * np.pi) * np.linalg.det(V))
# /home/student/Documents/langevin/folie/folie/estimation/transitionDensity.py:17: RuntimeWarning: invalid value encountered in log
#   return -0.5 * np.einsum("ti,ti-> t", xt - E, invVE) - 0.5 * np.log(np.sqrt(2 * np.pi) * np.linalg.det(V))
# /home/student/Documents/langevin/langevenv/lib/python3.8/site-packages/numpy/linalg/linalg.py:2139: RuntimeWarning: invalid value encountered in det
#   r = _umath_linalg.det(a, signature=signature)
# /home/student/Documents/langevin/folie/folie/estimation/transitionDensity.py:38: RuntimeWarning: invalid value encountered in log
#   ll = -0.5 * np.einsum("ti,ti-> t", xt - E, invVE) - 0.5 * np.log(np.sqrt(2 * np.pi) * np.linalg.det(V))
# /home/student/Documents/langevin/folie/folie/estimation/transitionDensity.py:17: RuntimeWarning: invalid value encountered in log
#   return -0.5 * np.einsum("ti,ti-> t", xt - E, invVE) - 0.5 * np.log(np.sqrt(2 * np.pi) * np.linalg.det(V))
# /home/student/Documents/langevin/langevenv/lib/python3.8/site-packages/numpy/linalg/linalg.py:2139: RuntimeWarning: invalid value encountered in det
#   r = _umath_linalg.det(a, signature=signature)
# /home/student/Documents/langevin/folie/folie/estimation/transitionDensity.py:38: RuntimeWarning: invalid value encountered in log
#   ll = -0.5 * np.einsum("ti,ti-> t", xt - E, invVE) - 0.5 * np.log(np.sqrt(2 * np.pi) * np.linalg.det(V))
# /home/student/Documents/langevin/folie/folie/estimation/transitionDensity.py:17: RuntimeWarning: invalid value encountered in log
#   return -0.5 * np.einsum("ti,ti-> t", xt - E, invVE) - 0.5 * np.log(np.sqrt(2 * np.pi) * np.linalg.det(V))
# /home/student/Documents/langevin/langevenv/lib/python3.8/site-packages/numpy/linalg/linalg.py:2139: RuntimeWarning: invalid value encountered in det
#   r = _umath_linalg.det(a, signature=signature)
# /home/student/Documents/langevin/folie/folie/estimation/transitionDensity.py:38: RuntimeWarning: invalid value encountered in log
#   ll = -0.5 * np.einsum("ti,ti-> t", xt - E, invVE) - 0.5 * np.log(np.sqrt(2 * np.pi) * np.linalg.det(V))
# /home/student/Documents/langevin/folie/folie/estimation/transitionDensity.py:17: RuntimeWarning: invalid value encountered in log
#   return -0.5 * np.einsum("ti,ti-> t", xt - E, invVE) - 0.5 * np.log(np.sqrt(2 * np.pi) * np.linalg.det(V))
# /home/student/Documents/langevin/langevenv/lib/python3.8/site-packages/numpy/linalg/linalg.py:2139: RuntimeWarning: invalid value encountered in det
#   r = _umath_linalg.det(a, signature=signature)
# /home/student/Documents/langevin/folie/folie/estimation/transitionDensity.py:38: RuntimeWarning: invalid value encountered in log
#   ll = -0.5 * np.einsum("ti,ti-> t", xt - E, invVE) - 0.5 * np.log(np.sqrt(2 * np.pi) * np.linalg.det(V))
# /home/student/Documents/langevin/folie/folie/estimation/transitionDensity.py:17: RuntimeWarning: invalid value encountered in log
#   return -0.5 * np.einsum("ti,ti-> t", xt - E, invVE) - 0.5 * np.log(np.sqrt(2 * np.pi) * np.linalg.det(V))
# /home/student/Documents/langevin/langevenv/lib/python3.8/site-packages/numpy/linalg/linalg.py:2139: RuntimeWarning: invalid value encountered in det
#   r = _umath_linalg.det(a, signature=signature)
# /home/student/Documents/langevin/folie/folie/estimation/transitionDensity.py:38: RuntimeWarning: invalid value encountered in log
#   ll = -0.5 * np.einsum("ti,ti-> t", xt - E, invVE) - 0.5 * np.log(np.sqrt(2 * np.pi) * np.linalg.det(V))
# /home/student/Documents/langevin/folie/folie/estimation/transitionDensity.py:17: RuntimeWarning: invalid value encountered in log
#   return -0.5 * np.einsum("ti,ti-> t", xt - E, invVE) - 0.5 * np.log(np.sqrt(2 * np.pi) * np.linalg.det(V))
# /home/student/Documents/langevin/langevenv/lib/python3.8/site-packages/numpy/linalg/linalg.py:2139: RuntimeWarning: invalid value encountered in det
#   r = _umath_linalg.det(a, signature=signature)

# %%
test3.KM_est.model.coefficients
# Out:
# array([-6.81e-02, 8.58e-01, 2.37e-03, -3.83e-02, 9.17e-01, 4.65e-03,
#        4.37e-02, 4.94e-01])

# %%
test3.VEC_est.model.coefficients
# Out:
# array([-6.81e-02, 8.58e-01, 2.37e-03, -3.83e-02, 9.17e-01, 4.65e-03,
#        4.37e-02, 4.94e-01])

# %% [markdown]
# test3 did not work

# %%
model_simu = build_pol_model(diff_coef=[.5])
test4 = one_simulation_estimation(model_simu=model_simu, use_jac=True)
plot_one_result(test4, diff_coef=[.5])
# Out:
# (<Figure size 1200x500 with 3 Axes>,
#  array([<Axes: title={'center': 'Mean force'}, xlabel='x'>,
#         <Axes: title={'center': 'Friction'}, xlabel='x'>,
#         <Axes: title={'center': 'Diffusion'}, xlabel='x'>], dtype=object))
# /home/student/Documents/langevin/folie/folie/estimation/transitionDensity.py:38: RuntimeWarning: invalid value encountered in log
#   ll = -0.5 * np.einsum("ti,ti-> t", xt - E, invVE) - 0.5 * np.log(np.sqrt(2 * np.pi) * np.linalg.det(V))
# /home/student/Documents/langevin/folie/folie/estimation/transitionDensity.py:38: RuntimeWarning: invalid value encountered in log
#   ll = -0.5 * np.einsum("ti,ti-> t", xt - E, invVE) - 0.5 * np.log(np.sqrt(2 * np.pi) * np.linalg.det(V))
# /home/student/Documents/langevin/folie/folie/estimation/transitionDensity.py:38: RuntimeWarning: invalid value encountered in log
#   ll = -0.5 * np.einsum("ti,ti-> t", xt - E, invVE) - 0.5 * np.log(np.sqrt(2 * np.pi) * np.linalg.det(V))
# /home/student/Documents/langevin/folie/folie/estimation/transitionDensity.py:38: RuntimeWarning: invalid value encountered in log
#   ll = -0.5 * np.einsum("ti,ti-> t", xt - E, invVE) - 0.5 * np.log(np.sqrt(2 * np.pi) * np.linalg.det(V))
# /home/student/Documents/langevin/folie/folie/estimation/transitionDensity.py:38: RuntimeWarning: invalid value encountered in log
#   ll = -0.5 * np.einsum("ti,ti-> t", xt - E, invVE) - 0.5 * np.log(np.sqrt(2 * np.pi) * np.linalg.det(V))
# /home/student/Documents/langevin/folie/folie/estimation/transitionDensity.py:38: RuntimeWarning: invalid value encountered in log
#   ll = -0.5 * np.einsum("ti,ti-> t", xt - E, invVE) - 0.5 * np.log(np.sqrt(2 * np.pi) * np.linalg.det(V))
# /home/student/Documents/langevin/folie/folie/estimation/transitionDensity.py:38: RuntimeWarning: invalid value encountered in log
#   ll = -0.5 * np.einsum("ti,ti-> t", xt - E, invVE) - 0.5 * np.log(np.sqrt(2 * np.pi) * np.linalg.det(V))
# /home/student/Documents/langevin/folie/folie/estimation/transitionDensity.py:38: RuntimeWarning: invalid value encountered in log
#   ll = -0.5 * np.einsum("ti,ti-> t", xt - E, invVE) - 0.5 * np.log(np.sqrt(2 * np.pi) * np.linalg.det(V))
# /home/student/Documents/langevin/folie/folie/estimation/transitionDensity.py:38: RuntimeWarning: invalid value encountered in log
#   ll = -0.5 * np.einsum("ti,ti-> t", xt - E, invVE) - 0.5 * np.log(np.sqrt(2 * np.pi) * np.linalg.det(V))
# /home/student/Documents/langevin/folie/folie/estimation/transitionDensity.py:38: RuntimeWarning: invalid value encountered in log
#   ll = -0.5 * np.einsum("ti,ti-> t", xt - E, invVE) - 0.5 * np.log(np.sqrt(2 * np.pi) * np.linalg.det(V))

# %% [markdown]
# C'EST N'IMPORTE QUOI OMG

# %% [markdown]
# **Multiplier uniquement le premier terme de Mvv par 4/7 = désastreux**

# %% [markdown]
# #### Changing dt, nsteps, bcs this is just weird

# %%
diff_coef = [.5] # stay simple
frict_coef = [1.]

dt_list = [2e-3, 4e-3, 8e-3]
nsteps_list = [15000, 20000, 20000]

test_fin_diff_change_dt_nsteps = simulation_estimation(dt_list=dt_list, nsteps_list=nsteps_list, compare_exact_vels=False,
                                                       n_fits=1, diff_coef = diff_coef, friction_coef = frict_coef)
# Out:
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            6     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -1.26285D+01    |proj g|=  8.36694D-01
#
# At iterate    1    f= -1.27520D+01    |proj g|=  1.69973D-03
#
# At iterate    2    f= -1.27520D+01    |proj g|=  7.60770D-04
#
# At iterate    3    f= -1.27520D+01    |proj g|=  1.24969D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     6      3      7      1     0     0   1.250D-04  -1.275D+01
#   F =  -12.751988604065680
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            6     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -1.12429D+01    |proj g|=  8.40667D-01
#
# At iterate    1    f= -1.13675D+01    |proj g|=  7.45690D-03
#
# At iterate    2    f= -1.13675D+01    |proj g|=  6.92574D-03
#
# At iterate    3    f= -1.13676D+01    |proj g|=  2.10218D-04
#
# At iterate    4    f= -1.13676D+01    |proj g|=  1.58553D-03
#
# At iterate    5    f= -1.13676D+01    |proj g|=  4.76553D-03
#
# At iterate    6    f= -1.13676D+01    |proj g|=  9.48966D-03
#
# At iterate    7    f= -1.13676D+01    |proj g|=  1.12919D-02
#
# At iterate    8    f= -1.13676D+01    |proj g|=  7.56842D-03
#
# At iterate    9    f= -1.13676D+01    |proj g|=  2.23640D-03
#
# At iterate   10    f= -1.13676D+01    |proj g|=  2.04474D-04
#
# At iterate   11    f= -1.13676D+01    |proj g|=  4.94317D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     6     11     18      1     0     0   4.943D-05  -1.137D+01
#   F =  -11.367555684219116
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            6     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -9.86179D+00    |proj g|=  8.51386D-01
#
# At iterate    1    f= -9.98811D+00    |proj g|=  6.48087D-02
#
# At iterate    2    f= -9.98816D+00    |proj g|=  7.70293D-02
#
# At iterate    3    f= -9.98828D+00    |proj g|=  1.82303D-03
#
# At iterate    4    f= -9.98828D+00    |proj g|=  2.99038D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     6      4      8      1     0     0   2.990D-04  -9.988D+00
#   F =  -9.9882813252257936
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH

# %%
plot_results(test_fin_diff_change_dt_nsteps, diff_coef = diff_coef, friction_coef = frict_coef)
# Out:
# (<Figure size 1200x500 with 3 Axes>,
#  array([<Axes: title={'center': 'Mean force'}, xlabel='x'>,
#         <Axes: title={'center': 'Friction'}, xlabel='x'>,
#         <Axes: title={'center': 'Diffusion'}, xlabel='x'>], dtype=object))

# %% [markdown]
# #### Projecting 2D data on one CV

# %%
x = np.linspace(-1.8,1.8,36)
y = np.linspace(-1.8,1.8,36)
input=np.transpose(np.array([x,y]))

diff_function= fl.functions.Polynomial(deg=0,coefficients=np.diag([.5, 10.]))
friction_function= fl.functions.Polynomial(deg=0,coefficients=np.asarray([1.])*np.eye(2,2))
a,b = 5.0, 10.0
quartic2d= fl.functions.Quartic2D(a=a,b=b)
X,Y =np.meshgrid(x,y)

# Plot potential surface 
pot = quartic2d.potential_plot(X,Y)
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot_surface(X,Y,pot, rstride=1, cstride=1,cmap='jet', edgecolor = 'none')

# Plot Force function
# ff=quartic2d.force(input) # returns x and y components of the force : x_comp =ff[:,0] , y_comp =ff[:,1]
# U,V = np.meshgrid(ff[:,0],ff[:,1])
# fig, ax =plt.subplots()
# ax.quiver(x,y,U,V)
# ax.set_title('Force')

# %%
dt = 8e-3
model_simu=fl.models.underdamped.Underdamped(quartic2d,friction=friction_function, diffusion=diff_function, dim=2)
simulator = fl.simulations.UnderdampedSimulator(fl.simulations.VECStepper(model_simu), dt)

ntrajs=60
X0 = np.zeros(4*ntrajs)

nsteps=15000
data = simulator.run(nsteps, X0, 1)

# %%
for trj in data:
    plt.plot(trj["x"][:,0])

# %%
for trj in data:
    plt.plot(trj["x"][:,1])

# %%
for trj in data:
    trj["x"] = trj["x"][:,:1]
    trj["v"] = trj["v"][:,:1]

# %%
import inspect
sig = inspect.signature(one_simulation_estimation)
kwarg_names = [name for name, param in sig.parameters.items()
               if param.default is not param.empty or param.kind == param.KEYWORD_ONLY]

print(kwarg_names)
# Out:
# ['ntrajs', 'X0', 'dt', 'nsteps', 'exact_vels', 'do_VEC', 'model_simu', 'trainmodel', 'data', 'coefficients0', 'correct_finite_diff_vel_KM', 'return_data', 'use_jac']

# %%
proj_res = one_simulation_estimation(data=data, trainmodel=build_pol_model(friction_coef=[1.], diff_coef=[.5]))

# %%
for trj in data:
    del trj["v"]

# %%
res = []
for k in range(5):
    data = simulator.run(nsteps, X0, 1)
    for trj in data:
        trj["x"] = trj["x"][:,:1]
        del(trj["v"])
    res.append(one_simulation_estimation(data=data, trainmodel=build_pol_model(friction_coef=[1.], diff_coef=[.5])))
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            6     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -9.85999D+00    |proj g|=  8.45972D-01
#  This problem is unconstrained.
# At iterate    1    f= -9.98481D+00    |proj g|=  5.30529D-02
#
# At iterate    2    f= -9.98492D+00    |proj g|=  3.78926D-04
#
# At iterate    3    f= -9.98492D+00    |proj g|=  5.73158D-04
#
# At iterate    4    f= -9.98492D+00    |proj g|=  3.96847D-03
#
# At iterate    5    f= -9.98492D+00    |proj g|=  5.90638D-03
#
# At iterate    6    f= -9.98493D+00    |proj g|=  4.94945D-03
#
# At iterate    7    f= -9.98493D+00    |proj g|=  1.85623D-03
#
# At iterate    8    f= -9.98493D+00    |proj g|=  2.27951D-04
#
# At iterate    9    f= -9.98493D+00    |proj g|=  4.40390D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     6      9     14      1     0     0   4.404D-06  -9.985D+00
#   F =  -9.9849284512038334
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            6     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -9.86220D+00    |proj g|=  8.47827D-01
#  This problem is unconstrained.
# At iterate    1    f= -9.98691D+00    |proj g|=  7.23432D-02
#
# At iterate    2    f= -9.98712D+00    |proj g|=  3.78782D-04
#
# At iterate    3    f= -9.98712D+00    |proj g|=  3.78414D-04
#
# At iterate    4    f= -9.98712D+00    |proj g|=  1.96391D-03
#
# At iterate    5    f= -9.98712D+00    |proj g|=  3.91911D-03
#
# At iterate    6    f= -9.98712D+00    |proj g|=  6.22222D-03
#
# At iterate    7    f= -9.98713D+00    |proj g|=  6.85623D-03
#
# At iterate    8    f= -9.98713D+00    |proj g|=  4.13803D-03
#
# At iterate    9    f= -9.98713D+00    |proj g|=  1.05011D-03
#
# At iterate   10    f= -9.98713D+00    |proj g|=  7.17043D-05
#
# At iterate   11    f= -9.98713D+00    |proj g|=  6.73587D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     6     11     15      1     0     0   6.736D-06  -9.987D+00
#   F =  -9.9871289723767642
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            6     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -9.86182D+00    |proj g|=  8.47476D-01
#  This problem is unconstrained.
# At iterate    1    f= -9.98656D+00    |proj g|=  6.86104D-02
#
# At iterate    2    f= -9.98674D+00    |proj g|=  3.78993D-04
#
# At iterate    3    f= -9.98674D+00    |proj g|=  3.78505D-04
#
# At iterate    4    f= -9.98674D+00    |proj g|=  2.24654D-03
#
# At iterate    5    f= -9.98674D+00    |proj g|=  4.29342D-03
#
# At iterate    6    f= -9.98675D+00    |proj g|=  6.48381D-03
#
# At iterate    7    f= -9.98675D+00    |proj g|=  6.37350D-03
#
# At iterate    8    f= -9.98675D+00    |proj g|=  1.34743D-03
#
# At iterate    9    f= -9.98675D+00    |proj g|=  1.07123D-04
#
# At iterate   10    f= -9.98675D+00    |proj g|=  3.39457D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     6     10     14      1     0     0   3.395D-06  -9.987D+00
#   F =  -9.9867512766876736
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            6     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -9.85903D+00    |proj g|=  8.45381D-01
#
# At iterate    1    f= -9.98396D+00    |proj g|=  4.46851D-02
#
# At iterate    2    f= -9.98404D+00    |proj g|=  3.73453D-04
#
# At iterate    3    f= -9.98404D+00    |proj g|=  1.49940D-03
#
# At iterate    4    f= -9.98405D+00    |proj g|=  4.78721D-03
#
# At iterate    5    f= -9.98405D+00    |proj g|=  4.69590D-03
#
# At iterate    6    f= -9.98405D+00    |proj g|=  5.15604D-04
#
# At iterate    7    f= -9.98405D+00    |proj g|=  3.44464D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     6      7     13      1     0     0   3.445D-05  -9.984D+00
#   F =  -9.9840526241110528
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            6     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -9.85765D+00    |proj g|=  8.43776D-01
#  This problem is unconstrained.
# At iterate    1    f= -9.98243D+00    |proj g|=  3.39121D-02
#
# At iterate    2    f= -9.98247D+00    |proj g|=  3.85741D-04
#
# At iterate    3    f= -9.98248D+00    |proj g|=  2.77270D-03
#
# At iterate    4    f= -9.98248D+00    |proj g|=  3.16788D-03
#
# At iterate    5    f= -9.98248D+00    |proj g|=  6.51572D-04
#
# At iterate    6    f= -9.98248D+00    |proj g|=  4.11020D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     6      6     13      1     0     0   4.110D-05  -9.982D+00
#   F =  -9.9824815991082012
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH

# %%
for re in res:
    print(re.VEC_est.model.friction.coefficients)
# Out:
# [1.05e+00]
# [1.05e+00]
# [1.04e+00]
# [1.06e+00]
# [1.04e+00]

# %%
for re in res:
    print(re.VEC_est.model.diffusion.coefficients*1.738)
# Out:
# [5.00e-01]
# [4.99e-01]
# [4.99e-01]
# [5.01e-01]
# [5.02e-01]

# %%
plot_one_result(proj_res, xfa = np.linspace(-1.15, 1.15, 100), free_energy_coef=[5., 0., -10., 0., 5.], friction_coef=[1.], diff_coef=[.5])
plot_one_result(findifvels, xfa = np.linspace(-1.15, 1.15, 100), free_energy_coef=[5., 0., -10., 0., 5.], friction_coef=[1.], diff_coef=[.5])
# Out:
# (<Figure size 1200x500 with 3 Axes>,
#  array([<Axes: title={'center': 'Mean force'}, xlabel='x'>,
#         <Axes: title={'center': 'Friction'}, xlabel='x'>,
#         <Axes: title={'center': 'Diffusion'}, xlabel='x'>], dtype=object))

# %% [markdown]
# #### Euler Maruyama integrator

# %%
dt = 8e-3
model_simu=build_pol_model(friction_coef=[1.], diff_coef=[.5])
simulator = fl.simulations.UnderdampedSimulator(fl.simulations.stepper.EulerMaruyamaStepper(model_simu), dt)

ntrajs=60
X0 = np.zeros(2*ntrajs)

nsteps=15000
data = simulator.run(nsteps, X0, 1)

# %%
for trj in data:
    plt.plot(trj["x"][:])

# %%
euler = one_simulation_estimation(data=data, trainmodel=build_pol_model(friction_coef=[1.], diff_coef=[.5]))
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            6     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -8.44757D+00    |proj g|=  1.96751D+00
#  This problem is unconstrained.
# At iterate    1    f= -8.67142D+00    |proj g|=  2.25720D-01
#
# At iterate    2    f= -8.67733D+00    |proj g|=  4.83395D-01
#
# At iterate    3    f= -8.70482D+00    |proj g|=  4.70664D-01
#
# At iterate    4    f= -8.74473D+00    |proj g|=  2.49107D-01
#
# At iterate    5    f= -8.74553D+00    |proj g|=  1.33629D-01
#
# At iterate    6    f= -8.74659D+00    |proj g|=  2.11042D-02
#
# At iterate    7    f= -8.74662D+00    |proj g|=  1.70643D-02
#
# At iterate    8    f= -8.74663D+00    |proj g|=  7.83746D-03
#
# At iterate    9    f= -8.74665D+00    |proj g|=  1.29833D-02
#
# At iterate   10    f= -8.74670D+00    |proj g|=  4.80885D-02
#
# At iterate   11    f= -8.74682D+00    |proj g|=  9.52941D-02
#
# At iterate   12    f= -8.74715D+00    |proj g|=  1.75338D-01
#
# At iterate   13    f= -8.74794D+00    |proj g|=  2.91537D-01
#
# At iterate   14    f= -8.74975D+00    |proj g|=  4.40490D-01
#
# At iterate   15    f= -8.75307D+00    |proj g|=  5.44499D-01
#
# At iterate   16    f= -8.75696D+00    |proj g|=  4.45421D-01
#
# At iterate   17    f= -8.75902D+00    |proj g|=  1.77880D-01
#
# At iterate   18    f= -8.75937D+00    |proj g|=  2.81177D-02
#
# At iterate   19    f= -8.75939D+00    |proj g|=  3.24368D-03
#
# At iterate   20    f= -8.75939D+00    |proj g|=  1.82782D-03
#
# At iterate   21    f= -8.75939D+00    |proj g|=  6.85940D-04
#
# At iterate   22    f= -8.75939D+00    |proj g|=  6.97684D-04
#
# At iterate   23    f= -8.75939D+00    |proj g|=  6.80378D-04
#
# At iterate   24    f= -8.75939D+00    |proj g|=  1.30201D-03
#
# At iterate   25    f= -8.75940D+00    |proj g|=  3.97993D-03
#
# At iterate   26    f= -8.75941D+00    |proj g|=  3.88406D-03
#
# At iterate   27    f= -8.75943D+00    |proj g|=  1.01363D-02
#
# At iterate   28    f= -8.75944D+00    |proj g|=  6.64808D-03
#
# At iterate   29    f= -8.75945D+00    |proj g|=  4.87572D-03
#
# At iterate   30    f= -8.75945D+00    |proj g|=  4.31801D-03
#
# At iterate   31    f= -8.75945D+00    |proj g|=  1.12727D-04
#
# At iterate   32    f= -8.75945D+00    |proj g|=  2.12450D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     6     32     35      1     0     0   2.124D-05  -8.759D+00
#   F =  -8.7594474150579860
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH

# %%
plot_one_result(euler, model_simu=model_simu)
# Out:
# (<Figure size 1200x500 with 3 Axes>,
#  array([<Axes: title={'center': 'Mean force'}, xlabel='x'>,
#         <Axes: title={'center': 'Friction'}, xlabel='x'>,
#         <Axes: title={'center': 'Diffusion'}, xlabel='x'>], dtype=object))

# %%
dt = 1e-3
model_simu=build_pol_model(friction_coef=[1.], diff_coef=[.5])
simulator = fl.simulations.UnderdampedSimulator(fl.simulations.stepper.EulerMaruyamaStepper(model_simu), dt)

ntrajs=60
X0 = np.zeros(2*ntrajs)

nsteps=15000
data = simulator.run(nsteps, X0, 5)

# %%
data[0]["dt"]
# Out:
# 0.005

# %%
for trj in data:
    plt.plot(trj["x"][:])

# %%
euler_save_every_5 = one_simulation_estimation(data=data, do_VEC=True,
                                               trainmodel=build_pol_model(friction_coef=[1.], diff_coef=[.5]))
# Out:
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            6     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -1.03447D+01    |proj g|=  7.01341D-02
#
# At iterate    1    f= -1.03453D+01    |proj g|=  3.75624D-04
#
# At iterate    2    f= -1.03453D+01    |proj g|=  2.99252D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     6      2      6      1     0     0   2.993D-04  -1.035D+01
#   F =  -10.345319844784317
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH

# %%
fig, axs = plot_one_result(euler_save_every_5, model_simu=model_simu,show=True)
# xfa = axs[2].lines[0].get_xydata()[:,0]
# axs[2].plot(ax[2].lines[0].get_xydata()[:,0], 1/5*euler_save_every_5.KM_est.model.diffusion(xfa.reshape(-1,1)), '-.', label=r'KM diffusion/5')
# axs[0].plot(ax[0].lines[0].get_xydata()[:,0], 1/5*euler_save_every_5.KM_est.model.pos_drift(xfa.reshape(-1,1)), '-.', label=r'KM diffusion/5')

# axs[0].legend()

# %%
model_simu=build_pol_model(friction_coef=[1.], diff_coef=[.5])
euler_save_every_5_findif = one_simulation_estimation(dt = 1e-3, stepper=fl.simulations.EulerMaruyamaStepper, save_every=5,
                          model_simu=model_simu)
# Out:
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            6     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -1.07718D+01    |proj g|=  8.16827D-01
#
# At iterate    1    f= -1.08931D+01    |proj g|=  1.34096D-01
#
# At iterate    2    f= -1.08940D+01    |proj g|=  5.62990D-02
#
# At iterate    3    f= -1.08940D+01    |proj g|=  4.48670D-03
#
# At iterate    4    f= -1.08940D+01    |proj g|=  3.96504D-04
#
# At iterate    5    f= -1.08940D+01    |proj g|=  3.73580D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     6      5      9      1     0     0   3.736D-04  -1.089D+01
#   F =  -10.893997899384582
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH

# %%
fig, axs = plot_one_result(euler_save_every_5_findif, model_simu=model_simu,show=True)

# %%
euler_save_every_5_findif.KM_est.model.diffusion.coefficients / euler_save_every_5_findif.VEC_est.model.diffusion.coefficients
# Out:
# array([1.71e+00])

# %%
euler_save_every_5_findif.VEC_est.model.diffusion.coefficients * 7/4
# Out:
# array([5.21e-01])

# %%
test_magic_coef_vary_model_save_every_5 = []
fe_coefs = [ [0., 0., .1], 0.1*np.array([0,0,-4.5,0,0.1]), 0.1*np.array([0,0,-4.5,0,0.1]) ]
frict_coefs = [ np.asarray([1.,0.,0.04]), np.asarray([1.,0.,0.04]), [1.] ]
diff_coefs = [  np.asarray([0.5]),  np.asarray([0.5,0.,0.1]), 0.05*np.array([100.,0,-3.5,0,0.2]) ]

for fe, fr, di in zip(fe_coefs, frict_coefs, diff_coefs):
    model_simu = build_pol_model(free_energy_coef=fe, friction_coef=fr, diff_coef=di)
    test_magic_coef_vary_model_save_every_5.append(one_simulation_estimation(dt = 1e-3, stepper=fl.simulations.EulerMaruyamaStepper, save_every=5,
                                                                             model_simu=model_simu, use_jac=True, exact_vels=False))
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            6     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -1.07749D+01    |proj g|=  8.18515D-01
#  This problem is unconstrained.
# At iterate    1    f= -1.08958D+01    |proj g|=  1.04466D-01
#
# At iterate    2    f= -1.08963D+01    |proj g|=  3.54994D-03
#
# At iterate    3    f= -1.08963D+01    |proj g|=  8.63671D-04
#
# At iterate    4    f= -1.08963D+01    |proj g|=  1.33868D-03
#
# At iterate    5    f= -1.08963D+01    |proj g|=  3.20764D-04
#
# At iterate    6    f= -1.08963D+01    |proj g|=  9.89318D-04
#
# At iterate    7    f= -1.08963D+01    |proj g|=  1.47537D-03
#
# At iterate    8    f= -1.08963D+01    |proj g|=  5.13181D-04
#
# At iterate    9    f= -1.08963D+01    |proj g|=  9.54811D-04
#
# At iterate   10    f= -1.08963D+01    |proj g|=  1.26454D-03
#
# At iterate   11    f= -1.08963D+01    |proj g|=  1.00422D-03
#
# At iterate   12    f= -1.08963D+01    |proj g|=  3.54324D-04
#
# At iterate   13    f= -1.08963D+01    |proj g|=  4.72921D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     6     13     20      1     0     0   4.729D-05  -1.090D+01
#   F =  -10.896344387545117
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           10     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -9.63128D+00    |proj g|=  2.40303D+00
#  This problem is unconstrained.
# At iterate    1    f= -9.71507D+00    |proj g|=  2.09533D+00
#
# At iterate    2    f= -9.72536D+00    |proj g|=  2.10210D-01
#
# At iterate    3    f= -9.72652D+00    |proj g|=  2.00854D-01
#
# At iterate    4    f= -9.73481D+00    |proj g|=  1.20016D+00
#
# At iterate    5    f= -9.74324D+00    |proj g|=  1.59194D+00
#
# At iterate    6    f= -9.74946D+00    |proj g|=  1.08333D+00
#
# At iterate    7    f= -9.75529D+00    |proj g|=  2.73909D-01
#
# At iterate    8    f= -9.75595D+00    |proj g|=  8.72904D-02
#
# At iterate    9    f= -9.75604D+00    |proj g|=  3.98203D-03
#
# At iterate   10    f= -9.75604D+00    |proj g|=  1.97498D-03
#
# At iterate   11    f= -9.75604D+00    |proj g|=  6.63835D-04
#
# At iterate   12    f= -9.75604D+00    |proj g|=  6.05233D-04
#
# At iterate   13    f= -9.75604D+00    |proj g|=  5.11419D-04
#
# At iterate   14    f= -9.75604D+00    |proj g|=  6.76007D-04
#
# At iterate   15    f= -9.75604D+00    |proj g|=  7.09737D-04
#
# At iterate   16    f= -9.75604D+00    |proj g|=  2.78635D-04
#
# At iterate   17    f= -9.75604D+00    |proj g|=  1.74619D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    10     17     33      1     0     0   1.746D-04  -9.756D+00
#   F =  -9.7560391963808240
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           10     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -8.23951D+00    |proj g|=  1.87872D+01
#  This problem is unconstrained.
# At iterate    1    f= -8.28849D+00    |proj g|=  8.70047D+00
#
# At iterate    2    f= -8.29250D+00    |proj g|=  1.07607D+00
#
# At iterate    3    f= -8.29256D+00    |proj g|=  4.22215D-01
#
# At iterate    4    f= -8.29257D+00    |proj g|=  2.86999D-01
#
# At iterate    5    f= -8.29263D+00    |proj g|=  4.19464D-01
#
# At iterate    6    f= -8.29272D+00    |proj g|=  9.17942D-01
#
# At iterate    7    f= -8.29283D+00    |proj g|=  9.61592D-01
#
# At iterate    8    f= -8.29306D+00    |proj g|=  7.96073D-01
#
# At iterate    9    f= -8.29428D+00    |proj g|=  7.63125D-01
#
# At iterate   10    f= -8.29601D+00    |proj g|=  2.13844D+00
#
# At iterate   11    f= -8.30020D+00    |proj g|=  5.04328D+00
#
# At iterate   12    f= -8.30540D+00    |proj g|=  6.14551D+00
#
# At iterate   13    f= -8.30900D+00    |proj g|=  2.51986D+00
#
# At iterate   14    f= -8.30948D+00    |proj g|=  6.44130D-01
#
# At iterate   15    f= -8.30951D+00    |proj g|=  1.24743D-01
#
# At iterate   16    f= -8.30951D+00    |proj g|=  3.06065D-02
#
# At iterate   17    f= -8.30952D+00    |proj g|=  3.05453D-02
#
# At iterate   18    f= -8.30952D+00    |proj g|=  3.04048D-02
#
# At iterate   19    f= -8.30955D+00    |proj g|=  6.86336D-02
#
# At iterate   20    f= -8.30972D+00    |proj g|=  2.74953D-01
#
# At iterate   21    f= -8.31016D+00    |proj g|=  6.07907D-01
#
# At iterate   22    f= -8.31116D+00    |proj g|=  9.98481D-01
#
# At iterate   23    f= -8.31304D+00    |proj g|=  1.21516D+00
#
# At iterate   24    f= -8.31553D+00    |proj g|=  1.06342D+00
#
# At iterate   25    f= -8.31921D+00    |proj g|=  3.64542D-01
#
# At iterate   26    f= -8.32478D+00    |proj g|=  3.70928D-01
#
# At iterate   27    f= -8.32488D+00    |proj g|=  1.01565D+00
#
# At iterate   28    f= -8.32839D+00    |proj g|=  4.68241D-01
#
# At iterate   29    f= -8.33048D+00    |proj g|=  5.03834D-01
#
# At iterate   30    f= -8.33133D+00    |proj g|=  7.76404D-01
#
# At iterate   31    f= -8.33190D+00    |proj g|=  9.32213D-01
#
# At iterate   32    f= -8.33217D+00    |proj g|=  3.15844D-01
#
# At iterate   33    f= -8.33219D+00    |proj g|=  6.61644D-02
#
# At iterate   34    f= -8.33219D+00    |proj g|=  4.72752D-02
#
# At iterate   35    f= -8.33222D+00    |proj g|=  6.13428D-02
#
# At iterate   36    f= -8.33229D+00    |proj g|=  1.86398D-01
#
# At iterate   37    f= -8.33248D+00    |proj g|=  3.79102D-01
#
# At iterate   38    f= -8.33278D+00    |proj g|=  2.27379D+00
#
# At iterate   39    f= -8.33347D+00    |proj g|=  1.85671D+00
#
# At iterate   40    f= -8.33652D+00    |proj g|=  1.19777D+00
#
# At iterate   41    f= -8.34463D+00    |proj g|=  1.29597D+00
#
# At iterate   42    f= -8.34549D+00    |proj g|=  1.45202D+00
#
# At iterate   43    f= -8.35461D+00    |proj g|=  8.95751D-01
#
# At iterate   44    f= -8.35718D+00    |proj g|=  1.46116D+00
#
# At iterate   45    f= -8.35980D+00    |proj g|=  7.10944D-01
#
# At iterate   46    f= -8.36047D+00    |proj g|=  1.80011D-01
#
# At iterate   47    f= -8.36057D+00    |proj g|=  1.31831D-01
#
# At iterate   48    f= -8.36078D+00    |proj g|=  1.14315D-01
#
# At iterate   49    f= -8.36082D+00    |proj g|=  3.13187D-01
#
# At iterate   50    f= -8.36083D+00    |proj g|=  1.37803D-02
#
# At iterate   51    f= -8.36083D+00    |proj g|=  1.19657D-02
#
# At iterate   52    f= -8.36084D+00    |proj g|=  2.14084D-02
#
# At iterate   53    f= -8.36085D+00    |proj g|=  2.00276D-01
#
# At iterate   54    f= -8.36089D+00    |proj g|=  3.36662D-02
#
# At iterate   55    f= -8.36099D+00    |proj g|=  1.98663D-01
#
# At iterate   56    f= -8.36112D+00    |proj g|=  2.77642D-01
#
# At iterate   57    f= -8.36113D+00    |proj g|=  4.60243D-01
#
# At iterate   58    f= -8.36120D+00    |proj g|=  2.28628D-01
#
# At iterate   59    f= -8.36122D+00    |proj g|=  3.77292D-02
#
# At iterate   60    f= -8.36122D+00    |proj g|=  1.06850D-03
#
# At iterate   61    f= -8.36122D+00    |proj g|=  8.51485D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    10     61     85      1     0     0   8.515D-04  -8.361D+00
#   F =  -8.3612203463344166
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH

# %%
for k in range(3):
    model_plot = build_pol_model(free_energy_coef=fe_coefs[k], friction_coef=frict_coefs[k], diff_coef=diff_coefs[k],)
    fig, axs = plot_one_result(test_magic_coef_vary_model_save_every_5[k], model_simu=model_plot,
                             show=False)

    xfa = axs[2].lines[0].get_xydata()[:,0]
    axs[2].plot(axs[2].lines[0].get_xydata()[:,0], 1.75*test_magic_coef_vary_model_save_every_5[k].VEC_est.model.diffusion(xfa.reshape(-1,1)), '-.', label=r'VEC diffusion $\times$ 7/4')
    axs[2].legend()

# %%
test_magic_coef_vary_model_save_every_5_nsteps30000 = []
fe_coefs = [ [0., 0., .1], 0.1*np.array([0,0,-4.5,0,0.1]), 0.1*np.array([0,0,-4.5,0,0.1]) ]
frict_coefs = [ np.asarray([1.,0.,0.04]), np.asarray([1.,0.,0.04]), [1.] ]
diff_coefs = [  np.asarray([0.5]),  np.asarray([0.5,0.,0.1]), 0.05*np.array([100.,0,-3.5,0,0.2]) ]

for fe, fr, di in zip(fe_coefs, frict_coefs, diff_coefs):
    model_simu = build_pol_model(free_energy_coef=fe, friction_coef=fr, diff_coef=di)
    test_magic_coef_vary_model_save_every_5_nsteps30000.append(one_simulation_estimation(dt = 1e-3, stepper=fl.simulations.EulerMaruyamaStepper, save_every=5,
                                                                             nsteps=30000, model_simu=model_simu, use_jac=True, exact_vels=False))
# Out:
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            6     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -1.07746D+01    |proj g|=  8.18608D-01
#
# At iterate    1    f= -1.08956D+01    |proj g|=  1.05629D-01
#
# At iterate    2    f= -1.08961D+01    |proj g|=  3.64047D-03
#
# At iterate    3    f= -1.08961D+01    |proj g|=  6.86504D-04
#
# At iterate    4    f= -1.08961D+01    |proj g|=  1.37246D-03
#
# At iterate    5    f= -1.08961D+01    |proj g|=  4.52275D-03
#
# At iterate    6    f= -1.08961D+01    |proj g|=  3.67473D-03
#
# At iterate    7    f= -1.08961D+01    |proj g|=  1.06102D-03
#
# At iterate    8    f= -1.08961D+01    |proj g|=  4.12594D-04
#
# At iterate    9    f= -1.08961D+01    |proj g|=  7.77087D-04
#
# At iterate   10    f= -1.08961D+01    |proj g|=  1.75621D-03
#
# At iterate   11    f= -1.08961D+01    |proj g|=  2.95414D-03
#
# At iterate   12    f= -1.08961D+01    |proj g|=  4.77941D-03
#
# At iterate   13    f= -1.08961D+01    |proj g|=  6.61719D-03
#
# At iterate   14    f= -1.08961D+01    |proj g|=  7.02822D-03
#
# At iterate   15    f= -1.08961D+01    |proj g|=  7.07016D-03
#
# At iterate   16    f= -1.08961D+01    |proj g|=  2.87783D-03
#
# At iterate   17    f= -1.08961D+01    |proj g|=  1.00471D-03
#
# At iterate   18    f= -1.08961D+01    |proj g|=  1.81826D-04
#
# At iterate   19    f= -1.08961D+01    |proj g|=  2.87087D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     6     19     27      1     0     0   2.871D-04  -1.090D+01
#   F =  -10.896106203633328
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           10     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -9.43095D+00    |proj g|=  2.77394D+00
#  This problem is unconstrained.
# At iterate    1    f= -9.52583D+00    |proj g|=  2.28312D+00
#
# At iterate    2    f= -9.53669D+00    |proj g|=  1.19882D-01
#
# At iterate    3    f= -9.53698D+00    |proj g|=  1.21138D-01
#
# At iterate    4    f= -9.53769D+00    |proj g|=  3.38821D-01
#
# At iterate    5    f= -9.53983D+00    |proj g|=  7.65428D-01
#
# At iterate    6    f= -9.54405D+00    |proj g|=  1.26141D+00
#
# At iterate    7    f= -9.54890D+00    |proj g|=  1.31909D+00
#
# At iterate    8    f= -9.55065D+00    |proj g|=  1.04725D+00
#
# At iterate    9    f= -9.55309D+00    |proj g|=  4.62911D-01
#
# At iterate   10    f= -9.55378D+00    |proj g|=  6.23077D-02
#
# At iterate   11    f= -9.55381D+00    |proj g|=  9.02823D-03
#
# At iterate   12    f= -9.55381D+00    |proj g|=  5.77271D-03
#
# At iterate   13    f= -9.55381D+00    |proj g|=  5.35811D-03
#
# At iterate   14    f= -9.55383D+00    |proj g|=  4.64767D-03
#
# At iterate   15    f= -9.55383D+00    |proj g|=  2.12121D-03
#
# At iterate   16    f= -9.55383D+00    |proj g|=  6.35104D-04
#
# At iterate   17    f= -9.55383D+00    |proj g|=  1.74190D-04
#
# At iterate   18    f= -9.55383D+00    |proj g|=  2.55928D-04
#
# At iterate   19    f= -9.55383D+00    |proj g|=  6.21243D-04
#
# At iterate   20    f= -9.55383D+00    |proj g|=  1.34681D-03
#
# At iterate   21    f= -9.55383D+00    |proj g|=  2.19629D-03
#
# At iterate   22    f= -9.55383D+00    |proj g|=  1.47212D-02
#
# At iterate   23    f= -9.55383D+00    |proj g|=  3.48769D-03
#
# At iterate   24    f= -9.55383D+00    |proj g|=  2.09586D-03
#
# At iterate   25    f= -9.55383D+00    |proj g|=  5.47379D-04
#
# At iterate   26    f= -9.55383D+00    |proj g|=  5.77706D-04
#
# At iterate   27    f= -9.55384D+00    |proj g|=  1.66685D-03
#
# At iterate   28    f= -9.55384D+00    |proj g|=  2.74450D-03
#
# At iterate   29    f= -9.55384D+00    |proj g|=  6.07818D-03
#
# At iterate   30    f= -9.55384D+00    |proj g|=  2.08830D-03
#
# At iterate   31    f= -9.55384D+00    |proj g|=  1.14843D-03
#
# At iterate   32    f= -9.55384D+00    |proj g|=  1.07370D-03
#
# At iterate   33    f= -9.55384D+00    |proj g|=  5.66469D-03
#
# At iterate   34    f= -9.55384D+00    |proj g|=  2.80639D-03
#
# At iterate   35    f= -9.55384D+00    |proj g|=  1.32735D-03
#
# At iterate   36    f= -9.55384D+00    |proj g|=  4.57213D-04
#
# At iterate   37    f= -9.55384D+00    |proj g|=  4.23664D-04
#
# At iterate   38    f= -9.55384D+00    |proj g|=  5.74094D-04
#
# At iterate   39    f= -9.55384D+00    |proj g|=  4.96876D-04
#
# At iterate   40    f= -9.55384D+00    |proj g|=  1.37956D-04
#
# At iterate   41    f= -9.55384D+00    |proj g|=  1.42847D-04
#
# At iterate   42    f= -9.55384D+00    |proj g|=  6.14166D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    10     42     62      1     0     0   6.142D-04  -9.554D+00
#   F =  -9.5538435160873938
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           10     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -8.26679D+00    |proj g|=  2.01128D+01
#
# At iterate    1    f=          NaN    |proj g|=  3.41730D+05
#
# At iterate    2    f= -8.32673D+00    |proj g|=  1.42588D+01
#
# At iterate    3    f= -8.32772D+00    |proj g|=  1.23153D+01
#
# At iterate    4    f= -8.33104D+00    |proj g|=  2.50739D+00
#
# At iterate    5    f= -8.33123D+00    |proj g|=  5.43024D-01
#
# At iterate    6    f= -8.33125D+00    |proj g|=  3.23554D-01
#
# At iterate    7    f= -8.33126D+00    |proj g|=  3.29273D-01
#
# At iterate    8    f= -8.33131D+00    |proj g|=  8.60313D-01
#
# At iterate    9    f= -8.33142D+00    |proj g|=  1.67135D+00
#
# At iterate   10    f= -8.33171D+00    |proj g|=  3.01175D+00
#
# At iterate   11    f= -8.33244D+00    |proj g|=  4.90985D+00
#
# At iterate   12    f= -8.33423D+00    |proj g|=  7.43848D+00
#
# At iterate   13    f= -8.33830D+00    |proj g|=  1.00970D+01
#
# At iterate   14    f= -8.34580D+00    |proj g|=  1.11944D+01
#
# At iterate   15    f= -8.35272D+00    |proj g|=  8.90587D+00
#
# At iterate   16    f= -8.35560D+00    |proj g|=  6.64585D+00
#
# At iterate   17    f= -8.35805D+00    |proj g|=  1.09960D+00
#
# At iterate   18    f= -8.35872D+00    |proj g|=  2.91433D+00
#
# At iterate   19    f= -8.35914D+00    |proj g|=  2.25965D+00
#
# At iterate   20    f= -8.35947D+00    |proj g|=  8.78064D-02
#
# At iterate   21    f= -8.35948D+00    |proj g|=  7.62193D-02
#
# At iterate   22    f= -8.35949D+00    |proj g|=  2.48881D-02
#
# At iterate   23    f= -8.35949D+00    |proj g|=  1.45625D-01
#
# At iterate   24    f= -8.35950D+00    |proj g|=  2.99644D-01
#
# At iterate   25    f= -8.35952D+00    |proj g|=  5.81206D-01
#
# At iterate   26    f= -8.35959D+00    |proj g|=  1.01947D+00
#
# At iterate   27    f= -8.35976D+00    |proj g|=  1.74773D+00
#
# At iterate   28    f= -8.36020D+00    |proj g|=  2.89405D+00
#
# At iterate   29    f= -8.36130D+00    |proj g|=  4.55717D+00
#
# At iterate   30    f= -8.36365D+00    |proj g|=  6.34771D+00
#
# At iterate   31    f= -8.36714D+00    |proj g|=  6.34520D+00
#
# At iterate   32    f= -8.36717D+00    |proj g|=  5.66262D+00
#
# At iterate   33    f= -8.36976D+00    |proj g|=  3.03330D+00
#
# At iterate   34    f= -8.37058D+00    |proj g|=  5.10782D-01
#
# At iterate   35    f= -8.37067D+00    |proj g|=  3.16395D-01
#
# At iterate   36    f= -8.37070D+00    |proj g|=  5.18417D-01
#
# At iterate   37    f= -8.37080D+00    |proj g|=  7.68838D-01
#
# At iterate   38    f= -8.37098D+00    |proj g|=  6.77430D-01
#
# At iterate   39    f= -8.37153D+00    |proj g|=  1.57183D+00
#
# At iterate   40    f= -8.37283D+00    |proj g|=  1.38375D+00
#
# At iterate   41    f= -8.37412D+00    |proj g|=  1.50557D+00
#
# At iterate   42    f= -8.37639D+00    |proj g|=  2.68736D+00
#
# At iterate   43    f= -8.37659D+00    |proj g|=  4.50794D+00
#
# At iterate   44    f= -8.37833D+00    |proj g|=  5.15885D-01
#
# At iterate   45    f= -8.37872D+00    |proj g|=  7.97312D-01
#
# At iterate   46    f= -8.37875D+00    |proj g|=  4.73293D-02
#
# At iterate   47    f= -8.37876D+00    |proj g|=  4.68746D-02
#
# At iterate   48    f= -8.37881D+00    |proj g|=  1.01207D-01
#
# At iterate   49    f= -8.37960D+00    |proj g|=  5.82822D-01
#
# At iterate   50    f= -8.38171D+00    |proj g|=  1.15453D+00
#
# At iterate   51    f= -8.38529D+00    |proj g|=  2.02196D+00
#
# At iterate   52    f= -8.38813D+00    |proj g|=  1.52240D+00
#
# At iterate   53    f= -8.38940D+00    |proj g|=  1.08572D+00
#
# At iterate   54    f= -8.38988D+00    |proj g|=  8.02827D-01
#
# At iterate   55    f= -8.38995D+00    |proj g|=  1.88448D-01
#
# At iterate   56    f= -8.38995D+00    |proj g|=  4.47899D-02
#
# At iterate   57    f= -8.38996D+00    |proj g|=  2.71530D-02
#
# At iterate   58    f= -8.38996D+00    |proj g|=  5.64094D-02
#
# At iterate   59    f= -8.38996D+00    |proj g|=  1.45846D-01
#
# At iterate   60    f= -8.38997D+00    |proj g|=  9.19650D-02
#
# At iterate   61    f= -8.38997D+00    |proj g|=  6.24977D-03
#
# At iterate   62    f= -8.38997D+00    |proj g|=  4.45196D-02
#
# At iterate   63    f= -8.38997D+00    |proj g|=  4.50322D-02
#
# At iterate   64    f= -8.38997D+00    |proj g|=  3.84930D-02
#
# At iterate   65    f= -8.38997D+00    |proj g|=  3.07455D-03
#
# At iterate   66    f= -8.38997D+00    |proj g|=  2.58796D-03
#
# At iterate   67    f= -8.38997D+00    |proj g|=  2.98942D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    10     67     91      1     0     0   2.989D-03  -8.390D+00
#   F =  -8.3899748854028431
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH

# %%
for k in range(3):
    model_plot = build_pol_model(free_energy_coef=fe_coefs[k], friction_coef=frict_coefs[k], diff_coef=diff_coefs[k],)
    fig, axs = plot_one_result(test_magic_coef_vary_model_save_every_5_nsteps30000[k], model_simu=model_plot,
                             show=False)

    xfa = axs[2].lines[0].get_xydata()[:,0]
    axs[2].plot(axs[2].lines[0].get_xydata()[:,0], 1.75*test_magic_coef_vary_model_save_every_5_nsteps30000[k].VEC_est.model.diffusion(xfa.reshape(-1,1)), '-.', label=r'VEC diffusion $\times$ 7/4')
    axs[2].legend()
# Out:
# /home/student/Documents/langevin/folie/folie/estimation/transitionDensity.py:38: RuntimeWarning: invalid value encountered in log
#   ll = -0.5 * np.einsum("ti,ti-> t", xt - E, invVE) - 0.5 * np.log(np.sqrt(2 * np.pi) * np.linalg.det(V))
# /home/student/Documents/langevin/folie/folie/estimation/transitionDensity.py:38: RuntimeWarning: invalid value encountered in log
#   ll = -0.5 * np.einsum("ti,ti-> t", xt - E, invVE) - 0.5 * np.log(np.sqrt(2 * np.pi) * np.linalg.det(V))
# /home/student/Documents/langevin/folie/folie/estimation/transitionDensity.py:38: RuntimeWarning: invalid value encountered in log
#   ll = -0.5 * np.einsum("ti,ti-> t", xt - E, invVE) - 0.5 * np.log(np.sqrt(2 * np.pi) * np.linalg.det(V))
# /home/student/Documents/langevin/folie/folie/estimation/transitionDensity.py:38: RuntimeWarning: invalid value encountered in log
#   ll = -0.5 * np.einsum("ti,ti-> t", xt - E, invVE) - 0.5 * np.log(np.sqrt(2 * np.pi) * np.linalg.det(V))
# /home/student/Documents/langevin/folie/folie/estimation/transitionDensity.py:38: RuntimeWarning: invalid value encountered in log
#   ll = -0.5 * np.einsum("ti,ti-> t", xt - E, invVE) - 0.5 * np.log(np.sqrt(2 * np.pi) * np.linalg.det(V))
# /home/student/Documents/langevin/folie/folie/estimation/transitionDensity.py:38: RuntimeWarning: invalid value encountered in log
#   ll = -0.5 * np.einsum("ti,ti-> t", xt - E, invVE) - 0.5 * np.log(np.sqrt(2 * np.pi) * np.linalg.det(V))
# /home/student/Documents/langevin/folie/folie/estimation/transitionDensity.py:38: RuntimeWarning: invalid value encountered in log
#   ll = -0.5 * np.einsum("ti,ti-> t", xt - E, invVE) - 0.5 * np.log(np.sqrt(2 * np.pi) * np.linalg.det(V))
# /home/student/Documents/langevin/folie/folie/estimation/transitionDensity.py:38: RuntimeWarning: invalid value encountered in log
#   ll = -0.5 * np.einsum("ti,ti-> t", xt - E, invVE) - 0.5 * np.log(np.sqrt(2 * np.pi) * np.linalg.det(V))
# /home/student/Documents/langevin/folie/folie/estimation/transitionDensity.py:38: RuntimeWarning: invalid value encountered in log
#   ll = -0.5 * np.einsum("ti,ti-> t", xt - E, invVE) - 0.5 * np.log(np.sqrt(2 * np.pi) * np.linalg.det(V))
# /home/student/Documents/langevin/folie/folie/estimation/transitionDensity.py:38: RuntimeWarning: invalid value encountered in log
#   ll = -0.5 * np.einsum("ti,ti-> t", xt - E, invVE) - 0.5 * np.log(np.sqrt(2 * np.pi) * np.linalg.det(V))

# %%
model_simu.coefficients
# Out:
# array([-0.00e+00, 9.00e-01, -0.00e+00, -4.00e-02, 1.00e+00, 5.00e-01])

# %%
euler_save_every_5.KM_est.model.coefficients
# Out:
# array([-8.88e-02, 4.35e+00, 7.40e-03, -1.93e-01, 4.89e+00, 2.49e+00])

# %% [markdown]
# #### Euler density

# %%
model_simu=build_pol_model(friction_coef=[1.], diff_coef=[.5])
euler_save_every_5_findif = one_simulation_estimation(dt = 1e-3, stepper=fl.simulations.EulerMaruyamaStepper, save_every=5,
                          model_simu=model_simu, do_Euler=True, do_VEC=False)
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            6     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -1.97809D+00    |proj g|=  5.81894D-01
#  This problem is unconstrained.
# At iterate    1    f= -2.12767D+00    |proj g|=  1.07709D-01
#
# At iterate    2    f= -2.12808D+00    |proj g|=  1.37023D-01
#
# At iterate    3    f= -2.12824D+00    |proj g|=  3.55345D-03
#
# At iterate    4    f= -2.12824D+00    |proj g|=  3.55877D-03
#
# At iterate    5    f= -2.12825D+00    |proj g|=  3.55064D-03
#
# At iterate    6    f= -2.12829D+00    |proj g|=  1.95496D-02
#
# At iterate    7    f= -2.12837D+00    |proj g|=  3.74966D-02
#
# At iterate    8    f= -2.12855D+00    |proj g|=  5.55980D-02
#
# At iterate    9    f= -2.12876D+00    |proj g|=  5.22817D-02
#
# At iterate   10    f= -2.12886D+00    |proj g|=  2.24361D-02
#
# At iterate   11    f= -2.12892D+00    |proj g|=  9.00570D-03
#
# At iterate   12    f= -2.12893D+00    |proj g|=  3.22589D-03
#
# At iterate   13    f= -2.12894D+00    |proj g|=  5.28248D-03
#
# At iterate   14    f= -2.12895D+00    |proj g|=  1.38249D-02
#
# At iterate   15    f= -2.12895D+00    |proj g|=  3.38571D-02
#
# At iterate   16    f= -2.12897D+00    |proj g|=  1.92780D-02
#
# At iterate   17    f= -2.12900D+00    |proj g|=  2.85368D-02
#
# At iterate   18    f= -2.12903D+00    |proj g|=  3.00603D-02
#
# At iterate   19    f= -2.12903D+00    |proj g|=  9.92170D-03
#
# At iterate   20    f= -2.12903D+00    |proj g|=  2.03965D-03
#
# At iterate   21    f= -2.12903D+00    |proj g|=  3.18801D-04
#
# At iterate   22    f= -2.12903D+00    |proj g|=  2.72133D-04
#
# At iterate   23    f= -2.12903D+00    |proj g|=  3.68720D-04
#
# At iterate   24    f= -2.12903D+00    |proj g|=  5.30450D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     6     24     29      1     0     0   5.304D-05  -2.129D+00
#   F =  -2.1290324671668155
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH

# %%
model_simu=build_pol_model(friction_coef=[1.], diff_coef=[.5])
euler_save_every_5_realvel = one_simulation_estimation(dt = 1e-3, stepper=fl.simulations.EulerMaruyamaStepper, save_every=5,
                          model_simu=model_simu, do_Euler=True, do_VEC=False, exact_vels=True)
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            6     M =           10
#
# At X0         0 variables are exactly at the bounds
#  This problem is unconstrained.
# At iterate    0    f= -1.69264D+00    |proj g|=  6.46965D-15
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     6      0      1      0     0     0   6.470D-15  -1.693D+00
#   F =  -1.6926400355849036
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL

# %%
model_simu=build_pol_model(friction_coef=[1.], diff_coef=[.5])
euler_save_every_5_findif_nocorr = one_simulation_estimation(dt = 1e-3, stepper=fl.simulations.EulerMaruyamaStepper, save_every=5,
                          model_simu=model_simu, do_Euler=True, do_VEC=False, exact_vels=False, correct_finite_diff_vel_KM=False)
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            6     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -1.97451D+00    |proj g|=  5.77729D-01
#  This problem is unconstrained.
# At iterate    1    f= -2.12328D+00    |proj g|=  1.59085D-01
#
# At iterate    2    f= -2.12460D+00    |proj g|=  4.49522D-02
#
# At iterate    3    f= -2.12462D+00    |proj g|=  1.97410D-02
#
# At iterate    4    f= -2.12463D+00    |proj g|=  3.54942D-03
#
# At iterate    5    f= -2.12463D+00    |proj g|=  3.54975D-03
#
# At iterate    6    f= -2.12464D+00    |proj g|=  3.79958D-03
#
# At iterate    7    f= -2.12464D+00    |proj g|=  1.01577D-02
#
# At iterate    8    f= -2.12466D+00    |proj g|=  2.00373D-02
#
# At iterate    9    f= -2.12471D+00    |proj g|=  3.46157D-02
#
# At iterate   10    f= -2.12482D+00    |proj g|=  5.19986D-02
#
# At iterate   11    f= -2.12500D+00    |proj g|=  6.09523D-02
#
# At iterate   12    f= -2.12519D+00    |proj g|=  4.39984D-02
#
# At iterate   13    f= -2.12527D+00    |proj g|=  1.48425D-02
#
# At iterate   14    f= -2.12528D+00    |proj g|=  1.68504D-03
#
# At iterate   15    f= -2.12528D+00    |proj g|=  2.93447D-03
#
# At iterate   16    f= -2.12528D+00    |proj g|=  1.66544D-03
#
# At iterate   17    f= -2.12528D+00    |proj g|=  1.70458D-03
#
# At iterate   18    f= -2.12528D+00    |proj g|=  2.40582D-03
#
# At iterate   19    f= -2.12528D+00    |proj g|=  6.61142D-03
#
# At iterate   20    f= -2.12529D+00    |proj g|=  1.31417D-02
#
# At iterate   21    f= -2.12530D+00    |proj g|=  2.19450D-02
#
# At iterate   22    f= -2.12532D+00    |proj g|=  3.02979D-02
#
# At iterate   23    f= -2.12536D+00    |proj g|=  3.04921D-02
#
# At iterate   24    f= -2.12536D+00    |proj g|=  2.90642D-02
#
# At iterate   25    f= -2.12538D+00    |proj g|=  1.58056D-02
#
# At iterate   26    f= -2.12539D+00    |proj g|=  3.42924D-03
#
# At iterate   27    f= -2.12539D+00    |proj g|=  3.08367D-04
#
# At iterate   28    f= -2.12539D+00    |proj g|=  1.45027D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     6     28     34      1     0     0   1.450D-03  -2.125D+00
#   F =  -2.1253902724383580
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH

# %%
fig, axs = plot_one_result(euler_save_every_5_findif_nocorr, model_simu=model_simu, show=False,
                          KM_label='KM - fin. diff. errs. not corrected')
plot_one_result(euler_save_every_5_realvel, model_simu=model_simu, fig=fig, axs=axs)
# Out:
# (<Figure size 1200x500 with 3 Axes>,
#  array([<Axes: title={'center': 'Mean force'}, xlabel='x'>,
#         <Axes: title={'center': 'Friction'}, xlabel='x'>,
#         <Axes: title={'center': 'Diffusion'}, xlabel='x'>], dtype=object))
# /home/student/Documents/langevin/folie/folie/estimation/transitionDensity.py:21: RuntimeWarning: invalid value encountered in log
#   ll = -0.5 * ((xt.ravel() - E) ** 2 / V) - 0.5 * np.log(np.sqrt(2 * np.pi) * V)
# /home/student/Documents/langevin/folie/folie/estimation/transitionDensity.py:21: RuntimeWarning: invalid value encountered in log
#   ll = -0.5 * ((xt.ravel() - E) ** 2 / V) - 0.5 * np.log(np.sqrt(2 * np.pi) * V)
# /home/student/Documents/langevin/folie/folie/estimation/transitionDensity.py:21: RuntimeWarning: invalid value encountered in log
#   ll = -0.5 * ((xt.ravel() - E) ** 2 / V) - 0.5 * np.log(np.sqrt(2 * np.pi) * V)
# /home/student/Documents/langevin/folie/folie/estimation/transitionDensity.py:21: RuntimeWarning: invalid value encountered in log
#   ll = -0.5 * ((xt.ravel() - E) ** 2 / V) - 0.5 * np.log(np.sqrt(2 * np.pi) * V)
# /home/student/Documents/langevin/folie/folie/estimation/transitionDensity.py:21: RuntimeWarning: invalid value encountered in log
#   ll = -0.5 * ((xt.ravel() - E) ** 2 / V) - 0.5 * np.log(np.sqrt(2 * np.pi) * V)
# /home/student/Documents/langevin/folie/folie/estimation/transitionDensity.py:21: RuntimeWarning: invalid value encountered in log
#   ll = -0.5 * ((xt.ravel() - E) ** 2 / V) - 0.5 * np.log(np.sqrt(2 * np.pi) * V)
# /home/student/Documents/langevin/folie/folie/estimation/transitionDensity.py:21: RuntimeWarning: invalid value encountered in log
#   ll = -0.5 * ((xt.ravel() - E) ** 2 / V) - 0.5 * np.log(np.sqrt(2 * np.pi) * V)
# /home/student/Documents/langevin/folie/folie/estimation/transitionDensity.py:21: RuntimeWarning: invalid value encountered in log
#   ll = -0.5 * ((xt.ravel() - E) ** 2 / V) - 0.5 * np.log(np.sqrt(2 * np.pi) * V)
# /home/student/Documents/langevin/folie/folie/estimation/transitionDensity.py:21: RuntimeWarning: invalid value encountered in log
#   ll = -0.5 * ((xt.ravel() - E) ** 2 / V) - 0.5 * np.log(np.sqrt(2 * np.pi) * V)
# /home/student/Documents/langevin/folie/folie/estimation/transitionDensity.py:21: RuntimeWarning: invalid value encountered in log
#   ll = -0.5 * ((xt.ravel() - E) ** 2 / V) - 0.5 * np.log(np.sqrt(2 * np.pi) * V)

# %% [markdown]
# Euler density finite difference errors :
# - diffusion = just my brother the 5/12 factor
# - mean force + friction = probably Ronceray.
# - We can see that it is not exactly the same as KM when finite diffs are not corrected : this is probably because we don't use the symmetrized acceleration but the antisymmetric one $\frac{v_{n+1} - v_n}{\tau}$ in `UnderdampedEulerDensity`.

# %%
euler_save_every_5_findif.Eul_est.model.diffusion.coefficients / .5
# Out:
# array([4.15e-01])

# %% [markdown]
# Changing the implementation of the Euler log density to use centered acceleration.

# %%
model_simu=build_pol_model(friction_coef=[1.], diff_coef=[.5])
euler_save_every_5_findif_nocorr_cent_acc = one_simulation_estimation(dt = 1e-3, stepper=fl.simulations.EulerMaruyamaStepper, save_every=5,
                          model_simu=model_simu, do_Euler=True, do_VEC=False, exact_vels=False, correct_finite_diff_vel_KM=False)
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            6     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -1.84475D+00    |proj g|=  3.24492D-01
#  This problem is unconstrained.
# At iterate    1    f= -1.88007D+00    |proj g|=  4.74086D-02
#
# At iterate    2    f= -1.88037D+00    |proj g|=  3.72573D-03
#
# At iterate    3    f= -1.88037D+00    |proj g|=  1.99866D-02
#
# At iterate    4    f= -1.88037D+00    |proj g|=  1.07436D-02
#
# At iterate    5    f= -1.88038D+00    |proj g|=  4.18901D-03
#
# At iterate    6    f= -1.88040D+00    |proj g|=  2.83538D-02
#
# At iterate    7    f= -1.88044D+00    |proj g|=  6.53928D-02
#
# At iterate    8    f= -1.88056D+00    |proj g|=  1.17443D-01
#
# At iterate    9    f= -1.88079D+00    |proj g|=  1.71824D-01
#
# At iterate   10    f= -1.88113D+00    |proj g|=  1.82694D-01
#
# At iterate   11    f= -1.88139D+00    |proj g|=  9.14058D-02
#
# At iterate   12    f= -1.88150D+00    |proj g|=  3.21315D-02
#
# At iterate   13    f= -1.88151D+00    |proj g|=  5.38450D-03
#
# At iterate   14    f= -1.88151D+00    |proj g|=  1.83810D-03
#
# At iterate   15    f= -1.88151D+00    |proj g|=  2.40900D-03
#
# At iterate   16    f= -1.88151D+00    |proj g|=  4.89911D-03
#
# At iterate   17    f= -1.88152D+00    |proj g|=  8.60314D-03
#
# At iterate   18    f= -1.88152D+00    |proj g|=  1.53320D-02
#
# At iterate   19    f= -1.88154D+00    |proj g|=  2.55596D-02
#
# At iterate   20    f= -1.88157D+00    |proj g|=  3.83154D-02
#
# At iterate   21    f= -1.88163D+00    |proj g|=  4.51124D-02
#
# At iterate   22    f= -1.88169D+00    |proj g|=  3.21416D-02
#
# At iterate   23    f= -1.88170D+00    |proj g|=  4.09542D-02
#
# At iterate   24    f= -1.88171D+00    |proj g|=  8.32629D-03
#
# At iterate   25    f= -1.88172D+00    |proj g|=  2.88560D-03
#
# At iterate   26    f= -1.88172D+00    |proj g|=  2.70373D-05
#
# At iterate   27    f= -1.88172D+00    |proj g|=  7.92353D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     6     27     32      1     0     0   7.924D-06  -1.882D+00
#   F =  -1.8817226354328995
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL

# %%
model_simu=build_pol_model(friction_coef=[1.], diff_coef=[.5])
euler_save_every_5_realvel = one_simulation_estimation(dt = 1e-3, stepper=fl.simulations.EulerMaruyamaStepper, save_every=5,
                          model_simu=model_simu, do_Euler=True, do_VEC=False, exact_vels=True)
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            6     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -1.69073D+00    |proj g|=  4.54823D-16
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     6      0      1      0     0     0   4.548D-16  -1.691D+00
#   F =  -1.6907295476108348
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#  This problem is unconstrained.

# %%
fig, axs = plot_one_result(euler_save_every_5_findif_nocorr_cent_acc, model_simu=model_simu, show=False,
                          KM_label='KM - fin. diff. errs. not corrected')
plot_one_result(euler_save_every_5_realvel, model_simu=model_simu, fig=fig, axs=axs)
# Out:
# (<Figure size 1200x500 with 3 Axes>,
#  array([<Axes: title={'center': 'Mean force'}, xlabel='x'>,
#         <Axes: title={'center': 'Friction'}, xlabel='x'>,
#         <Axes: title={'center': 'Diffusion'}, xlabel='x'>], dtype=object))
# /home/student/Documents/langevin/folie/folie/estimation/transitionDensity.py:21: RuntimeWarning: invalid value encountered in log
#   ll = -0.5 * ((xt.ravel() - E) ** 2 / V) - 0.5 * np.log(np.sqrt(2 * np.pi) * V)
# /home/student/Documents/langevin/folie/folie/estimation/transitionDensity.py:21: RuntimeWarning: invalid value encountered in log
#   ll = -0.5 * ((xt.ravel() - E) ** 2 / V) - 0.5 * np.log(np.sqrt(2 * np.pi) * V)
# /home/student/Documents/langevin/folie/folie/estimation/transitionDensity.py:21: RuntimeWarning: invalid value encountered in log
#   ll = -0.5 * ((xt.ravel() - E) ** 2 / V) - 0.5 * np.log(np.sqrt(2 * np.pi) * V)
# /home/student/Documents/langevin/folie/folie/estimation/transitionDensity.py:21: RuntimeWarning: invalid value encountered in log
#   ll = -0.5 * ((xt.ravel() - E) ** 2 / V) - 0.5 * np.log(np.sqrt(2 * np.pi) * V)
# /home/student/Documents/langevin/folie/folie/estimation/transitionDensity.py:21: RuntimeWarning: invalid value encountered in log
#   ll = -0.5 * ((xt.ravel() - E) ** 2 / V) - 0.5 * np.log(np.sqrt(2 * np.pi) * V)
# /home/student/Documents/langevin/folie/folie/estimation/transitionDensity.py:21: RuntimeWarning: invalid value encountered in log
#   ll = -0.5 * ((xt.ravel() - E) ** 2 / V) - 0.5 * np.log(np.sqrt(2 * np.pi) * V)
# /home/student/Documents/langevin/folie/folie/estimation/transitionDensity.py:21: RuntimeWarning: invalid value encountered in log
#   ll = -0.5 * ((xt.ravel() - E) ** 2 / V) - 0.5 * np.log(np.sqrt(2 * np.pi) * V)
# /home/student/Documents/langevin/folie/folie/estimation/transitionDensity.py:21: RuntimeWarning: invalid value encountered in log
#   ll = -0.5 * ((xt.ravel() - E) ** 2 / V) - 0.5 * np.log(np.sqrt(2 * np.pi) * V)
# /home/student/Documents/langevin/folie/folie/estimation/transitionDensity.py:21: RuntimeWarning: invalid value encountered in log
#   ll = -0.5 * ((xt.ravel() - E) ** 2 / V) - 0.5 * np.log(np.sqrt(2 * np.pi) * V)
# /home/student/Documents/langevin/folie/folie/estimation/transitionDensity.py:21: RuntimeWarning: invalid value encountered in log
#   ll = -0.5 * ((xt.ravel() - E) ** 2 / V) - 0.5 * np.log(np.sqrt(2 * np.pi) * V)

# %%
euler_save_every_5_findif_nocorr_cent_acc.Eul_est.model.coefficients
# Out:
# array([1.25e-02, 6.95e-01, 1.01e-03, -3.20e-02, 2.61e-01, 3.41e-01])

# %%
euler_save_every_5_findif_nocorr_cent_acc.KM_est.model.coefficients
# Out:
# array([8.76e-03, 6.94e-01, 1.17e-03, -3.20e-02, 2.61e-01, 3.41e-01])

# %% [markdown]
# ##### Trying to correct Euler density fin. diff. errors

# %%
model_simu=build_pol_model(friction_coef=[1.], diff_coef=[.5])
euler_try_corr_findiff_1 = one_simulation_estimation(dt = 1e-3, stepper=fl.simulations.EulerMaruyamaStepper, save_every=5,
                          model_simu=model_simu, do_Euler=True, do_VEC=False, exact_vels=False)
# Out:
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            6     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -1.75636D+00    |proj g|=  3.63846D-01
#
# At iterate    1    f= -1.88255D+00    |proj g|=  7.27950D-02
#
# At iterate    2    f= -1.88305D+00    |proj g|=  4.12288D-02
#
# At iterate    3    f= -1.88326D+00    |proj g|=  1.08284D-02
#
# At iterate    4    f= -1.88326D+00    |proj g|=  4.91515D-03
#
# At iterate    5    f= -1.88326D+00    |proj g|=  3.72509D-03
#
# At iterate    6    f= -1.88342D+00    |proj g|=  1.34619D-02
#
# At iterate    7    f= -1.88403D+00    |proj g|=  3.61961D-02
#
# At iterate    8    f= -1.88436D+00    |proj g|=  2.47609D-02
#
# At iterate    9    f= -1.88444D+00    |proj g|=  6.27231D-03
#
# At iterate   10    f= -1.88445D+00    |proj g|=  1.76268D-03
#
# At iterate   11    f= -1.88445D+00    |proj g|=  3.09358D-03
#
# At iterate   12    f= -1.88446D+00    |proj g|=  6.18007D-03
#
# At iterate   13    f= -1.88447D+00    |proj g|=  1.03434D-02
#
# At iterate   14    f= -1.88449D+00    |proj g|=  1.60450D-02
#
# At iterate   15    f= -1.88454D+00    |proj g|=  2.03569D-02
#
# At iterate   16    f= -1.88455D+00    |proj g|=  2.14068D-02
#
# At iterate   17    f= -1.88462D+00    |proj g|=  1.72102D-02
#
# At iterate   18    f= -1.88467D+00    |proj g|=  6.87399D-03
#
# At iterate   19    f= -1.88468D+00    |proj g|=  1.90392D-03
#
# At iterate   20    f= -1.88468D+00    |proj g|=  2.52873D-04
#
# At iterate   21    f= -1.88468D+00    |proj g|=  1.47481D-05
#
# At iterate   22    f= -1.88468D+00    |proj g|=  1.47361D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     6     22     30      1     0     0   1.474D-05  -1.885D+00
#   F =  -1.8846827078899764
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH

# %%
fig, axs = plot_one_result(euler_try_corr_findiff_1, model_simu=model_simu, show=True,
                          )

# %% [markdown]
# - D -> 3/2 D is bad

# %%
model_simu=build_pol_model(friction_coef=[1.], diff_coef=[.5])
euler_try_corr_findiff_2 = one_simulation_estimation(dt = 1e-3, stepper=fl.simulations.EulerMaruyamaStepper, save_every=5,
                          model_simu=model_simu, do_Euler=True, do_VEC=False, exact_vels=False)
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            6     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -1.88112D+00    |proj g|=  4.21740D-03
#  This problem is unconstrained.
# At iterate    1    f= -1.88113D+00    |proj g|=  7.09000D-03
#
# At iterate    2    f= -1.88114D+00    |proj g|=  3.70581D-03
#
# At iterate    3    f= -1.88114D+00    |proj g|=  2.29753D-02
#
# At iterate    4    f= -1.88117D+00    |proj g|=  9.35586D-03
#
# At iterate    5    f= -1.88123D+00    |proj g|=  1.19928D-02
#
# At iterate    6    f= -1.88141D+00    |proj g|=  3.89326D-02
#
# At iterate    7    f= -1.88172D+00    |proj g|=  6.81839D-02
#
# At iterate    8    f= -1.88209D+00    |proj g|=  7.27039D-02
#
# At iterate    9    f= -1.88231D+00    |proj g|=  3.70646D-02
#
# At iterate   10    f= -1.88236D+00    |proj g|=  2.72826D-03
#
# At iterate   11    f= -1.88236D+00    |proj g|=  4.94484D-03
#
# At iterate   12    f= -1.88237D+00    |proj g|=  8.37450D-03
#
# At iterate   13    f= -1.88238D+00    |proj g|=  1.46897D-02
#
# At iterate   14    f= -1.88240D+00    |proj g|=  1.96554D-02
#
# At iterate   15    f= -1.88241D+00    |proj g|=  5.13406D-02
#
# At iterate   16    f= -1.88246D+00    |proj g|=  4.25245D-02
#
# At iterate   17    f= -1.88252D+00    |proj g|=  2.02721D-02
#
# At iterate   18    f= -1.88255D+00    |proj g|=  4.02786D-03
#
# At iterate   19    f= -1.88255D+00    |proj g|=  1.04051D-03
#
# At iterate   20    f= -1.88255D+00    |proj g|=  3.07665D-04
#
# At iterate   21    f= -1.88255D+00    |proj g|=  3.18255D-05
#
# At iterate   22    f= -1.88255D+00    |proj g|=  3.15954D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     6     22     27      1     0     0   3.160D-05  -1.883D+00
#   F =  -1.8825534103111345
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH

# %%
fig, axs = plot_one_result(euler_try_corr_findiff_2, model_simu=model_simu, show=True,
                          )

# %% [markdown]
# - D -> 2/3 D retrieves correct diffusion (exact same as KM).
# - friction & drift corrs still missing

# %%
model_simu=build_pol_model(friction_coef=[1.], diff_coef=[.5])
euler_try_corr_findiff_3 = one_simulation_estimation(dt = 1e-3, stepper=fl.simulations.EulerMaruyamaStepper, save_every=5,
                          model_simu=model_simu, do_Euler=True, do_VEC=False, exact_vels=False)
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            6     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -1.88369D+00    |proj g|=  4.07847D-03
#  This problem is unconstrained.
# At iterate    1    f= -1.88370D+00    |proj g|=  1.15413D-02
#
# At iterate    2    f= -1.88370D+00    |proj g|=  5.83984D-03
#
# At iterate    3    f= -1.88370D+00    |proj g|=  3.95065D-03
#
# At iterate    4    f= -1.88376D+00    |proj g|=  6.73087D-03
#
# At iterate    5    f= -1.88413D+00    |proj g|=  2.34588D-02
#
# At iterate    6    f= -1.88452D+00    |proj g|=  3.23450D-02
#
# At iterate    7    f= -1.88478D+00    |proj g|=  1.95931D-02
#
# At iterate    8    f= -1.88482D+00    |proj g|=  4.50194D-03
#
# At iterate    9    f= -1.88483D+00    |proj g|=  1.50365D-03
#
# At iterate   10    f= -1.88483D+00    |proj g|=  1.46117D-03
#
# At iterate   11    f= -1.88483D+00    |proj g|=  2.56526D-03
#
# At iterate   12    f= -1.88484D+00    |proj g|=  4.59593D-03
#
# At iterate   13    f= -1.88486D+00    |proj g|=  7.63092D-03
#
# At iterate   14    f= -1.88487D+00    |proj g|=  2.27393D-02
#
# At iterate   15    f= -1.88490D+00    |proj g|=  1.17595D-02
#
# At iterate   16    f= -1.88496D+00    |proj g|=  9.59074D-03
#
# At iterate   17    f= -1.88499D+00    |proj g|=  7.54675D-03
#
# At iterate   18    f= -1.88499D+00    |proj g|=  3.19010D-03
#
# At iterate   19    f= -1.88499D+00    |proj g|=  4.92449D-04
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
# At iterate   20    f= -1.88499D+00    |proj g|=  1.56343D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     6     20     47      2     0     0   1.563D-04  -1.885D+00
#   F =  -1.8849924172235530
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH

# %%
(model_simu.friction(np.ones((10,1))) / model_simu.diffusion(np.ones((10,1)))[:])
# Out:
# array([2.00e+00, 2.00e+00, 2.00e+00, 2.00e+00, 2.00e+00, 2.00e+00,
#        2.00e+00, 2.00e+00, 2.00e+00, 2.00e+00])

# %%
model_simu.diffusion(np.ones((10,1))).shape
# Out:
# (10,)

# %%
fig, axs = plot_one_result(euler_try_corr_findiff_3, model_simu=model_simu, show=True,
                          )

# %%
model_simu=build_pol_model(friction_coef=[1.], diff_coef=[.5])
euler_nocorr_findiff = one_simulation_estimation(dt = 1e-3, stepper=fl.simulations.EulerMaruyamaStepper, save_every=5,
                          model_simu=model_simu, do_Euler=True, do_VEC=False, exact_vels=False, use_jac=False)
# Out:
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            6     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -1.88459D+00    |proj g|=  3.74996D-03
#
# At iterate    1    f= -1.88460D+00    |proj g|=  9.66429D-03
#
# At iterate    2    f= -1.88462D+00    |proj g|=  8.94607D-03
#
# At iterate    3    f= -1.88464D+00    |proj g|=  2.55197D-02
#
# At iterate    4    f= -1.88468D+00    |proj g|=  5.94063D-03
#
# At iterate    5    f= -1.88480D+00    |proj g|=  2.55462D-02
#
# At iterate    6    f= -1.88506D+00    |proj g|=  6.57938D-02
#
# At iterate    7    f= -1.88543D+00    |proj g|=  8.63283D-02
#
# At iterate    8    f= -1.88573D+00    |proj g|=  5.69422D-02
#
# At iterate    9    f= -1.88581D+00    |proj g|=  1.57145D-02
#
# At iterate   10    f= -1.88582D+00    |proj g|=  1.82949D-03
#
# At iterate   11    f= -1.88582D+00    |proj g|=  1.88873D-03
#
# At iterate   12    f= -1.88582D+00    |proj g|=  1.91536D-03
#
# At iterate   13    f= -1.88582D+00    |proj g|=  5.15064D-03
#
# At iterate   14    f= -1.88583D+00    |proj g|=  7.59912D-03
#
# At iterate   15    f= -1.88583D+00    |proj g|=  2.41706D-02
#
# At iterate   16    f= -1.88585D+00    |proj g|=  2.37700D-02
#
# At iterate   17    f= -1.88590D+00    |proj g|=  1.25265D-02
#
# At iterate   18    f= -1.88597D+00    |proj g|=  9.57139D-03
#
# At iterate   19    f= -1.88604D+00    |proj g|=  1.08795D-02
#
# At iterate   20    f= -1.88606D+00    |proj g|=  5.92293D-03
#
# At iterate   21    f= -1.88606D+00    |proj g|=  1.06921D-03
#
# At iterate   22    f= -1.88606D+00    |proj g|=  2.33702D-04
#
# At iterate   23    f= -1.88606D+00    |proj g|=  3.73634D-04
#
# At iterate   24    f= -1.88606D+00    |proj g|=  4.63407D-05
#
# At iterate   25    f= -1.88606D+00    |proj g|=  2.69784D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     6     25     30      1     0     0   2.698D-05  -1.886D+00
#   F =  -1.8860646075361365
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH

# %%
fig, axs = plot_one_result(euler_nocorr_findiff, model_simu=model_simu, show=True,
                          )

# %%
model_simu=build_pol_model(friction_coef=[1.], diff_coef=[.5])
euler_try_corr_findiff_5 = one_simulation_estimation(dt = 1e-3, stepper=fl.simulations.EulerMaruyamaStepper, save_every=5,
                          model_simu=model_simu, do_Euler=True, do_VEC=False, exact_vels=False, use_jac=False)
# Out:
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            6     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -1.88219D+00    |proj g|=  4.15976D-03
#
# At iterate    1    f= -1.88220D+00    |proj g|=  1.04845D-02
#
# At iterate    2    f= -1.88222D+00    |proj g|=  8.50644D-03
#
# At iterate    3    f= -1.88223D+00    |proj g|=  1.97178D-02
#
# At iterate    4    f= -1.88226D+00    |proj g|=  6.30103D-03
#
# At iterate    5    f= -1.88234D+00    |proj g|=  1.36767D-02
#
# At iterate    6    f= -1.88253D+00    |proj g|=  4.49843D-02
#
# At iterate    7    f= -1.88290D+00    |proj g|=  7.58000D-02
#
# At iterate    8    f= -1.88338D+00    |proj g|=  7.86121D-02
#
# At iterate    9    f= -1.88379D+00    |proj g|=  2.80388D-02
#
# At iterate   10    f= -1.88388D+00    |proj g|=  6.99383D-03
#
# At iterate   11    f= -1.88389D+00    |proj g|=  1.40530D-02
#
# At iterate   12    f= -1.88392D+00    |proj g|=  2.30664D-02
#
# At iterate   13    f= -1.88396D+00    |proj g|=  2.80333D-02
#
# At iterate   14    f= -1.88401D+00    |proj g|=  1.02086D-02
#
# At iterate   15    f= -1.88402D+00    |proj g|=  3.06601D-02
#
# At iterate   16    f= -1.88404D+00    |proj g|=  6.11522D-03
#
# At iterate   17    f= -1.88404D+00    |proj g|=  1.01064D-03
#
# At iterate   18    f= -1.88404D+00    |proj g|=  7.83285D-04
#
# At iterate   19    f= -1.88404D+00    |proj g|=  1.89937D-04
#
# At iterate   20    f= -1.88404D+00    |proj g|=  2.65565D-05
#
# At iterate   21    f= -1.88404D+00    |proj g|=  2.70228D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     6     21     26      1     0     0   2.702D-05  -1.884D+00
#   F =  -1.8840388978237403
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH

# %%
fig, axs = plot_one_result(euler_try_corr_findiff_5, model_simu=model_simu, show=True,
                          )

# %%
model_simu=build_pol_model(friction_coef=[1.], diff_coef=[.5])
euler_try_corr_findiff_6 = one_simulation_estimation(dt = 1e-3, stepper=fl.simulations.EulerMaruyamaStepper, save_every=5,
                          model_simu=model_simu, do_Euler=True, do_VEC=False, exact_vels=False, use_jac=True)
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            6     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -1.88526D+00    |proj g|=  8.86232D-03
#  This problem is unconstrained.
# At iterate    1    f= -1.88526D+00    |proj g|=  8.86626D-03
#
# At iterate    2    f= -1.88526D+00    |proj g|=  8.86748D-03
#
# At iterate    3    f= -1.88526D+00    |proj g|=  8.86878D-03
#
# At iterate    4    f= -1.88526D+00    |proj g|=  8.86894D-03
#
# At iterate    5    f= -1.88526D+00    |proj g|=  8.86791D-03
#
# At iterate    6    f= -1.88526D+00    |proj g|=  8.86706D-03
#
# At iterate    7    f= -1.88526D+00    |proj g|=  9.94611D-03
#
# At iterate    8    f= -1.88526D+00    |proj g|=  1.02023D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     6      8     64      1     0     0   1.020D-02  -1.885D+00
#   F =  -1.8852569802743924
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH

# %%
fig, axs = plot_one_result(euler_try_corr_findiff_6, model_simu=model_simu, show=True,
                          )

# %%
model_simu=build_pol_model(friction_coef=[1.], diff_coef=[.5])
euler_try_corr_findiff_7 = one_simulation_estimation(dt = 1e-3, stepper=fl.simulations.EulerMaruyamaStepper, save_every=5,
                          model_simu=model_simu, do_Euler=True, do_VEC=False, exact_vels=False, use_jac=True)
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            6     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -1.88058D+00    |proj g|=  4.58289D-03
#  This problem is unconstrained.
# At iterate    1    f= -1.88058D+00    |proj g|=  3.25463D-02
#
# At iterate    2    f= -1.88059D+00    |proj g|=  1.97757D-02
#
# At iterate    3    f= -1.88060D+00    |proj g|=  8.01329D-03
#
# At iterate    4    f= -1.88061D+00    |proj g|=  1.28174D-02
#
# At iterate    5    f= -1.88067D+00    |proj g|=  3.03821D-02
#
# At iterate    6    f= -1.88085D+00    |proj g|=  5.76988D-02
#
# At iterate    7    f= -1.88113D+00    |proj g|=  7.01883D-02
#
# At iterate    8    f= -1.88142D+00    |proj g|=  6.66899D-02
#
# At iterate    9    f= -1.88159D+00    |proj g|=  2.44214D-02
#
# At iterate   10    f= -1.88166D+00    |proj g|=  4.69276D-03
#
# At iterate   11    f= -1.88167D+00    |proj g|=  2.23216D-03
#
# At iterate   12    f= -1.88167D+00    |proj g|=  1.81111D-03
#
# At iterate   13    f= -1.88167D+00    |proj g|=  1.77987D-03
#
# At iterate   14    f= -1.88168D+00    |proj g|=  1.44047D-03
#
# At iterate   15    f= -1.88171D+00    |proj g|=  4.87692D-03
#
# At iterate   16    f= -1.88173D+00    |proj g|=  5.37179D-03
#
# At iterate   17    f= -1.88175D+00    |proj g|=  2.47489D-03
#
# At iterate   18    f= -1.88175D+00    |proj g|=  1.38449D-03
#
# At iterate   19    f= -1.88175D+00    |proj g|=  1.17043D-03
#
# At iterate   20    f= -1.88175D+00    |proj g|=  9.85076D-04
#
# At iterate   21    f= -1.88175D+00    |proj g|=  1.18108D-03
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
# At iterate   22    f= -1.88175D+00    |proj g|=  1.18218D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     6     22     43      1     0     0   1.182D-03  -1.882D+00
#   F =  -1.8817501800431373
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH

# %%
fig, axs = plot_one_result(euler_try_corr_findiff_7, model_simu=model_simu, show=True,
                          )

# %%
model_simu=build_pol_model(friction_coef=[1.], diff_coef=[3.])
euler_try_corr_findiff_8 = one_simulation_estimation(dt = 5e-3, stepper=fl.simulations.EulerMaruyamaStepper, save_every=1,
                          model_simu=model_simu, do_Euler=True, do_VEC=False, exact_vels=False, use_jac=True)
# Out:
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            6     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -7.91712D-01    |proj g|=  3.37865D-03
#
# At iterate    1    f= -7.91719D-01    |proj g|=  2.98327D-02
#
# At iterate    2    f= -7.91881D-01    |proj g|=  2.78911D-02
#
# At iterate    3    f= -7.92063D-01    |proj g|=  2.05625D-02
#
# At iterate    4    f= -7.92142D-01    |proj g|=  8.13951D-03
#
# At iterate    5    f= -7.92177D-01    |proj g|=  1.29260D-02
#
# At iterate    6    f= -7.92228D-01    |proj g|=  1.35293D-02
#
# At iterate    7    f= -7.92261D-01    |proj g|=  7.74338D-03
#
# At iterate    8    f= -7.92274D-01    |proj g|=  5.69024D-03
#
# At iterate    9    f= -7.92275D-01    |proj g|=  4.52461D-03
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
# At iterate   10    f= -7.92276D-01    |proj g|=  9.45391D-04
#
# At iterate   11    f= -7.92276D-01    |proj g|=  1.08577D-03
#
# At iterate   12    f= -7.92281D-01    |proj g|=  5.04030D-03
#
# At iterate   13    f= -7.92288D-01    |proj g|=  6.35447D-03
#
# At iterate   14    f= -7.92296D-01    |proj g|=  5.60184D-03
#
# At iterate   15    f= -7.92311D-01    |proj g|=  5.47964D-03
#
# At iterate   16    f= -7.92311D-01    |proj g|=  3.18540D-03
#
# At iterate   17    f= -7.92311D-01    |proj g|=  3.05556D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     6     17     57      2     0     0   3.056D-03  -7.923D-01
#   F = -0.79231147915494582
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH

# %%
fig, axs = plot_one_result(euler_try_corr_findiff_8, model_simu=model_simu, show=True,
                          )

# %% [markdown]
# ### Enforcing FDT

# %% [markdown]
# #### Preliminary tests

# %%
coeff=0.1*np.array([0,0,-4.5,0,0.1]) # coefficients of the free energy
free_energy = np.polynomial.Polynomial(coeff)
force_coeff=np.array([-coeff[1],-2*coeff[2],-3*coeff[3],-4*coeff[4]]) #coefficients of the free energy
force_function = fl.functions.Polynomial(deg=3,coefficients=force_coeff)
diffusion_function= fl.functions.Polynomial(deg=0,coefficients=np.asarray([.5]))

model_simu = fl.models.underdamped.UnderdampedFDT(force_function, diffusion_function, mass_kBT=5.)

# %%
# Define model to simulate and type of simulator to use
dt=5e-3
simulator = fl.simulations.UnderdampedSimulator(fl.simulations.VECStepper(model_simu), dt)
ntrajs = 60
X0=np.asarray([[0., 0.1*(2*(k%2)-1)] for k in range(ntrajs)]).flatten()
X0 = np.zeros(2*ntrajs)
underdamped_data = simulator.run(3000, X0, 1)

# %%
for trj in underdamped_data:
    plt.plot(trj["x"])

# %%
force_train = fl.functions.Polynomial(deg=3,coefficients=np.ones(4))
friction_train = fl.functions.Polynomial(deg=2,coefficients=np.asarray([8., 8., 8.]))
trainmodel = fl.models.underdamped.UnderdampedFDT(force_train, friction_train, mass_kBT=10.)

KM_est = fl.direct_estimation.UnderdampedFDTKramersMoyalEstimator(trainmodel)
KM_res = KM_est.fit_fetch(underdamped_data)

Eul_estimator = fl.LikelihoodEstimator(fl.UnderdampedTransitionDensityFDT(deepcopy(trainmodel),), n_jobs=10)
Eul_res = deepcopy(Eul_estimator.fit_fetch(underdamped_data, use_jac=True, minimize_kwargs={"method": "L-BFGS-B", "options":{"iprint":1}}),
                  )
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -1.69069D+00    |proj g|=  8.53072D-01
#  This problem is unconstrained.
# At iterate    1    f= -1.69105D+00    |proj g|=  4.61551D-01
#
# At iterate    2    f= -1.69118D+00    |proj g|=  7.78374D-02
#
# At iterate    3    f= -1.69119D+00    |proj g|=  1.63580D-02
#
# At iterate    4    f= -1.69119D+00    |proj g|=  1.35392D-02
#
# At iterate    5    f= -1.69119D+00    |proj g|=  9.47711D-03
#
# At iterate    6    f= -1.69121D+00    |proj g|=  1.49538D-02
#
# At iterate    7    f= -1.69124D+00    |proj g|=  1.25833D-02
#
# At iterate    8    f= -1.69124D+00    |proj g|=  1.23551D-02
#
# At iterate    9    f= -1.69124D+00    |proj g|=  2.53708D-03
#
# At iterate   10    f= -1.69124D+00    |proj g|=  1.70994D-04
#
# At iterate   11    f= -1.69124D+00    |proj g|=  7.75374D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     11     16      1     0     0   7.754D-05  -1.691D+00
#   F =  -1.6912405731466444
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH

# %%
model_simu.coefficients
# Out:
# array([-0.00e+00, 9.00e-01, -0.00e+00, -4.00e-02, 5.00e-01])

# %%
KM_res.coefficients
# Out:
# [0.010957881229448433,
#  0.8701397799477281,
#  -0.0021372709995604033,
#  -0.03883012880918302,
#  0.48541071761874927,
#  4.090752790161583e-06,
#  0.0016307079264313148]

# %%
Eul_res.coefficients
# Out:
# array([1.10e-02, 8.70e-01, -2.09e-03, -3.88e-02, 4.96e-01, 4.71e-04,
#        1.59e-04])
# /home/student/Documents/langevin/folie/folie/estimation/transitionDensity.py:25: RuntimeWarning: invalid value encountered in log
#   ll = -0.5 * ((xt.ravel() - E) ** 2 / V) - 0.5 * np.log(np.sqrt(2 * np.pi) * V)
# /home/student/Documents/langevin/folie/folie/estimation/transitionDensity.py:25: RuntimeWarning: invalid value encountered in log
#   ll = -0.5 * ((xt.ravel() - E) ** 2 / V) - 0.5 * np.log(np.sqrt(2 * np.pi) * V)
# /home/student/Documents/langevin/folie/folie/estimation/transitionDensity.py:25: RuntimeWarning: invalid value encountered in log
#   ll = -0.5 * ((xt.ravel() - E) ** 2 / V) - 0.5 * np.log(np.sqrt(2 * np.pi) * V)
# /home/student/Documents/langevin/folie/folie/estimation/transitionDensity.py:25: RuntimeWarning: invalid value encountered in log
#   ll = -0.5 * ((xt.ravel() - E) ** 2 / V) - 0.5 * np.log(np.sqrt(2 * np.pi) * V)
# /home/student/Documents/langevin/folie/folie/estimation/transitionDensity.py:25: RuntimeWarning: invalid value encountered in log
#   ll = -0.5 * ((xt.ravel() - E) ** 2 / V) - 0.5 * np.log(np.sqrt(2 * np.pi) * V)
# /home/student/Documents/langevin/folie/folie/estimation/transitionDensity.py:25: RuntimeWarning: invalid value encountered in log
#   ll = -0.5 * ((xt.ravel() - E) ** 2 / V) - 0.5 * np.log(np.sqrt(2 * np.pi) * V)
# /home/student/Documents/langevin/folie/folie/estimation/transitionDensity.py:25: RuntimeWarning: invalid value encountered in log
#   ll = -0.5 * ((xt.ravel() - E) ** 2 / V) - 0.5 * np.log(np.sqrt(2 * np.pi) * V)
# /home/student/Documents/langevin/folie/folie/estimation/transitionDensity.py:25: RuntimeWarning: invalid value encountered in log
#   ll = -0.5 * ((xt.ravel() - E) ** 2 / V) - 0.5 * np.log(np.sqrt(2 * np.pi) * V)
# /home/student/Documents/langevin/folie/folie/estimation/transitionDensity.py:25: RuntimeWarning: invalid value encountered in log
#   ll = -0.5 * ((xt.ravel() - E) ** 2 / V) - 0.5 * np.log(np.sqrt(2 * np.pi) * V)
# /home/student/Documents/langevin/folie/folie/estimation/transitionDensity.py:25: RuntimeWarning: invalid value encountered in log
#   ll = -0.5 * ((xt.ravel() - E) ** 2 / V) - 0.5 * np.log(np.sqrt(2 * np.pi) * V)

# %%
for trj in underdamped_data:
    del trj["v"]

# %%
force_train = fl.functions.Polynomial(deg=3,coefficients=np.ones(4))
friction_train = fl.functions.Polynomial(deg=2,coefficients=np.asarray([8., 8., 8.]))
trainmodel = fl.models.underdamped.UnderdampedFDT(force_train, friction_train, mass_kBT=10.)

KM_est = fl.direct_estimation.UnderdampedFDTKramersMoyalEstimator(trainmodel)
KM_res = KM_est.fit_fetch(underdamped_data)

Eul_estimator = fl.LikelihoodEstimator(fl.estimation.underdampedFDT_transitionDensity._TRYCORR_UnderdampedTransitionDensityFDT(deepcopy(trainmodel),), n_jobs=10)
Eul_res = deepcopy(Eul_estimator.fit_fetch(underdamped_data, use_jac=True, minimize_kwargs={"method": "L-BFGS-B", "options":{"iprint":1}}),
                  )
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -1.67944D+00    |proj g|=  1.06750D+00
#  This problem is unconstrained.
# At iterate    1    f= -1.67966D+00    |proj g|=  9.32929D-01
#
# At iterate    2    f= -1.68025D+00    |proj g|=  2.54088D-01
#
# At iterate    3    f= -1.68028D+00    |proj g|=  4.31493D-02
#
# At iterate    4    f= -1.68028D+00    |proj g|=  1.88076D-02
#
# At iterate    5    f= -1.68028D+00    |proj g|=  1.80190D-02
#
# At iterate    6    f= -1.68029D+00    |proj g|=  4.70169D-02
#
# At iterate    7    f= -1.68029D+00    |proj g|=  6.32225D-02
#
# At iterate    8    f= -1.68030D+00    |proj g|=  4.35560D-02
#
# At iterate    9    f= -1.68030D+00    |proj g|=  1.38241D-02
#
# At iterate   10    f= -1.68031D+00    |proj g|=  4.10051D-02
#
# At iterate   11    f= -1.68031D+00    |proj g|=  8.13291D-02
#
# At iterate   12    f= -1.68032D+00    |proj g|=  1.34555D-01
#
# At iterate   13    f= -1.68034D+00    |proj g|=  1.65586D-01
#
# At iterate   14    f= -1.68037D+00    |proj g|=  1.23831D-01
#
# At iterate   15    f= -1.68038D+00    |proj g|=  3.83471D-02
#
# At iterate   16    f= -1.68038D+00    |proj g|=  4.42861D-03
#
# At iterate   17    f= -1.68038D+00    |proj g|=  2.59567D-04
#
# At iterate   18    f= -1.68038D+00    |proj g|=  8.39688D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     18     20      1     0     0   8.397D-05  -1.680D+00
#   F =  -1.6803766421156250
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH

# %%
model_simu.coefficients
# Out:
# array([-0.00e+00, 9.00e-01, -0.00e+00, -4.00e-02, 5.00e-01])

# %%
KM_res.coefficients
# Out:
# array([5.26e-02, 9.04e-01, -3.51e-03, -4.01e-02, 4.85e-01, 9.80e-04,
#        2.67e-03])

# %%
Eul_res.coefficients
# Out:
# array([5.26e-02, 9.04e-01, -3.54e-03, -4.01e-02, 4.98e-01, 3.44e-04,
#        7.45e-04])

# %%
coeff=0.1*np.array([0,0,-4.5,0,0.1]) # coefficients of the free energy
free_energy = np.polynomial.Polynomial(coeff)
force_coeff=np.array([-coeff[1],-2*coeff[2],-3*coeff[3],-4*coeff[4]]) #coefficients of the free energy
force_function = fl.functions.Polynomial(deg=3,coefficients=force_coeff)
diffusion_function= fl.functions.Polynomial(deg=0,coefficients=np.asarray([.5]))
friction_function = fl.functions.Polynomial(deg=0,coefficients=np.asarray([1.]))

model_simu = fl.models.underdamped.Underdamped(force_function, friction_function,
                                                  diffusion_function)

# Define model to simulate and type of simulator to use
dt=5e-3
simulator = fl.simulations.UnderdampedSimulator(fl.simulations.VECStepper(model_simu), dt)
ntrajs = 60
X0=np.asarray([[0., 0.1*(2*(k%2)-1)] for k in range(ntrajs)]).flatten()
X0 = np.zeros(2*ntrajs)
underdamped_data = simulator.run(3000, X0, 1)

# %%
for trj in underdamped_data:
    del trj["v"]

# %%
force_train = fl.functions.Polynomial(deg=3,coefficients=np.ones(4))
friction_train = fl.functions.Polynomial(deg=2,coefficients=np.asarray([8., 8., 8.]))
diffusion_train = fl.functions.Polynomial(deg=1,coefficients=np.asarray([8., 8.]))
trainmodel = fl.models.underdamped.Underdamped(force_train, friction_train, diffusion_train)

KM_est = fl.direct_estimation.UnderdampedKramersMoyalEstimator(trainmodel)
KM_res = KM_est.fit_fetch(underdamped_data)

Eul_estimator = fl.LikelihoodEstimator(fl.estimation.underdampedFDT_transitionDensity._TERMBYTERM_UnderdampedTransitionDensity(deepcopy(trainmodel),), n_jobs=10)
Eul_res = deepcopy(Eul_estimator.fit_fetch(underdamped_data, use_jac=True, minimize_kwargs={"method": "L-BFGS-B", "options":{"iprint":1}}),
                  )
# Out:
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            9     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -1.68818D+00    |proj g|=  3.66216D-02
#
# At iterate    1    f= -1.68877D+00    |proj g|=  5.55196D-02
#
# At iterate    2    f= -1.68882D+00    |proj g|=  7.87205D-03
#
# At iterate    3    f= -1.68883D+00    |proj g|=  3.45605D-03
#
# At iterate    4    f= -1.68883D+00    |proj g|=  7.82874D-03
#
# At iterate    5    f= -1.68883D+00    |proj g|=  3.75734D-03
#
# At iterate    6    f= -1.68884D+00    |proj g|=  1.07215D-03
#
# At iterate    7    f= -1.68884D+00    |proj g|=  7.09941D-04
#
# At iterate    8    f= -1.68884D+00    |proj g|=  7.09814D-04
#
# At iterate    9    f= -1.68884D+00    |proj g|=  2.01494D-03
#
# At iterate   10    f= -1.68884D+00    |proj g|=  4.25604D-03
#
# At iterate   11    f= -1.68885D+00    |proj g|=  7.77575D-03
#
# At iterate   12    f= -1.68887D+00    |proj g|=  1.10241D-02
#
# At iterate   13    f= -1.68889D+00    |proj g|=  1.07905D-02
#
# At iterate   14    f= -1.68889D+00    |proj g|=  1.26891D-02
#
# At iterate   15    f= -1.68891D+00    |proj g|=  7.57250D-03
#
# At iterate   16    f= -1.68893D+00    |proj g|=  3.08856D-03
#
# At iterate   17    f= -1.68894D+00    |proj g|=  8.46140D-03
#
# At iterate   18    f= -1.68895D+00    |proj g|=  1.34643D-02
#
# At iterate   19    f= -1.68896D+00    |proj g|=  1.24840D-02
#
# At iterate   20    f= -1.68905D+00    |proj g|=  6.41734D-03
#
# At iterate   21    f= -1.68910D+00    |proj g|=  5.52698D-03
#
# At iterate   22    f= -1.68913D+00    |proj g|=  1.62295D-03
#
# At iterate   23    f= -1.68913D+00    |proj g|=  1.29986D-03
#
# At iterate   24    f= -1.68913D+00    |proj g|=  1.22661D-03
#
# At iterate   25    f= -1.68914D+00    |proj g|=  5.64805D-03
#
# At iterate   26    f= -1.68915D+00    |proj g|=  5.39297D-03
#
# At iterate   27    f= -1.68916D+00    |proj g|=  2.73248D-02
#
# At iterate   28    f= -1.68920D+00    |proj g|=  1.82143D-02
#
# At iterate   29    f= -1.68924D+00    |proj g|=  5.07376D-03
#
# At iterate   30    f= -1.68925D+00    |proj g|=  1.02769D-02
#
# At iterate   31    f= -1.68925D+00    |proj g|=  1.67742D-03
#
# At iterate   32    f= -1.68925D+00    |proj g|=  4.10916D-04
#
# At iterate   33    f= -1.68925D+00    |proj g|=  2.92545D-04
#
# At iterate   34    f= -1.68925D+00    |proj g|=  1.24128D-04
#
# At iterate   35    f= -1.68925D+00    |proj g|=  2.63283D-05
#
# At iterate   36    f= -1.68925D+00    |proj g|=  2.66999D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     9     36     44      1     0     0   2.670D-05  -1.689D+00
#   F =  -1.6892513919629266
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH

# %%
model_simu.coefficients
# Out:
# array([-0.00e+00, 9.00e-01, -0.00e+00, -4.00e-02, 1.00e+00, 5.00e-01])

# %%
KM_res.coefficients
# Out:
# array([-5.72e-02, 8.50e-01, 2.00e-03, -3.81e-02, 1.09e+00, 8.50e-03,
#        1.39e-04, 5.00e-01, 9.21e-04])

# %%
Eul_res.coefficients
# Out:
# array([-5.21e-02, 5.38e-01, 1.53e-03, -2.61e-02, 1.56e-01, -7.83e-04,
#        4.95e-03, 5.01e-01, 9.01e-04])

# %%
for trj in underdamped_data:
    del trj["v"]

# %%
force_train = fl.functions.Polynomial(deg=3,coefficients=np.ones(4))
friction_train = fl.functions.Polynomial(deg=2,coefficients=np.asarray([8., 8., 8.]))
trainmodel = fl.models.underdamped.UnderdampedFDT(force_train, friction_train, mass_kBT=10.)

KM_est = fl.estimation.underdampedFDT_transitionDensity.UnderdampedFDTKramersMoyalEstimator(trainmodel)
KM_res = KM_est.fit_fetch(underdamped_data)
# Eul_estimator = fl.LikelihoodEstimator(fl.VECDensity(deepcopy(trainmodel),), n_jobs=10)

# Eul_res = deepcopy(VEC_estimator.fit_fetch(underdamped_data,  minimize_kwargs={"method": "L-BFGS-B", "options":{"iprint":1}}))

# %%
model_simu.coefficients
# Out:
# array([-0.00e+00, 9.00e-01, -0.00e+00, -4.00e-02, 1.00e-01, 0.00e+00,
#        1.00e-02])

# %%
KM_res.coefficients
# Out:
# array([-1.02e-01, 9.27e-01, 1.57e-03, -3.94e-02, 9.39e-02, -2.18e-04,
#        1.05e-02])

# %%
xfa = np.linspace(-6,6, 100).reshape(-1,1)
plt.plot(xfa,KM_res.pos_drift(xfa))
plt.plot(xfa,model_simu.pos_drift(xfa))

# %%
KM_res.mass_kBT
# Out:
# 10.0

# %%
KM_res.diffusion
# Out:
# Polynomial-140020253699184:[{'coefficients': array([9.68e-01, 3.95e-03, 1.03e-01]),
#                             'deg': None,
#                             'domain': <folie.domains.Domain object at 0x7f58f7762460>,
#                             'output_shape': None,
#                             'polynom': Polynomial([1.00e+00], domain=[-1,  1], window=[-1,  1], symbol='x')}]

# %%
KM_res.friction
# Out:
# Polynomial-140020185079568:[{'coefficients': array([9.68e-02, 3.95e-04, 1.03e-02]),
#                             'deg': None,
#                             'domain': <folie.domains.Domain object at 0x7f58fd649fa0>,
#                             'output_shape': None,
#                             'polynom': Polynomial([1.00e+00], domain=[-1,  1], window=[-1,  1], symbol='x')}]

# %%
KM_res
# Out:
# UnderdampedFDT-140020185078752:[{'diffusion': Polynomial-140020253699184:[{'coefficients': array([9.68e-01, 3.95e-03, 1.03e-01]),
#                                                            'deg': None,
#                                                            'domain': <folie.domains.Domain object at 0x7f58f7762460>,
#                                                            'output_shape': None,
#                                                            'polynom': Polynomial([1.00e+00], domain=[-1,  1], window=[-1,  1], symbol='x')}],
#                                 'dim': 1,
#                                 'force': None,
#                                 'mass_kBT': 10.0}]

# %%
Eul_estimator = fl.LikelihoodEstimator(fl.estimation.underdampedFDT_transitionDensity.UnderdampedTransitionDensityFDT(deepcopy(trainmodel),), n_jobs=10)

Eul_res = deepcopy(Eul_estimator.fit_fetch(underdamped_data,  minimize_kwargs={"method": "L-BFGS-B", "options":{"iprint":1}}))
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#  This problem is unconstrained.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: 0-th dimension must be fixed to 5 but got 6
#
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 3
#       1 Eul_estimator = fl.LikelihoodEstimator(fl.estimation.underdampedFDT_transitionDensity.UnderdampedTransitionDensityFDT(deepcopy(trainmodel),), n_jobs=10)
# ----> 3 Eul_res = deepcopy(Eul_estimator.fit_fetch(underdamped_data,  minimize_kwargs={"method": "L-BFGS-B", "options":{"iprint":1}}))
#
# File ~/Documents/langevin/folie/folie/base.py:210, in Estimator.fit_fetch(self, data, **kwargs)
#     195 def fit_fetch(self, data, **kwargs):
#     196     r"""Fits the internal model on data and subsequently fetches it in one call.
#     197
#     198     Parameters
#    (...)
#     208         The estimated model.
#     209     """
# --> 210     self.fit(data, **kwargs)
#     211     return self.fetch_model()
#
# File ~/Documents/langevin/folie/folie/estimation/mle.py:98, in LikelihoodEstimator.fit(self, data, minimizer, coefficients0, use_jac, callback, minimize_kwargs, **kwargs)
#      95 init_val = self._loop_over_trajs(self.transition, data.weights, data, coefficients0, **kwargs)
#      97 if len(init_val) >= 2 and use_jac:
# ---> 98     res = minimizer(self._log_likelihood_negative_with_jac, coefficients0, args=(data,), jac=True, **minimize_kwargs)
#      99 else:
#     100     self.transition.use_jac = False
#
# File ~/Documents/langevin/langevenv/lib/python3.8/site-packages/scipy/optimize/_minimize.py:696, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     693     res = _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback,
#     694                              **options)
#     695 elif meth == 'l-bfgs-b':
# --> 696     res = _minimize_lbfgsb(fun, x0, args, jac, bounds,
#     697                            callback=callback, **options)
#     698 elif meth == 'tnc':
#     699     res = _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#     700                         **options)
#
# File ~/Documents/langevin/langevenv/lib/python3.8/site-packages/scipy/optimize/_lbfgsb_py.py:350, in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     346 n_iterations = 0
#     348 while 1:
#     349     # x, f, g, wa, iwa, task, csave, lsave, isave, dsave = \
# --> 350     _lbfgsb.setulb(m, x, low_bnd, upper_bnd, nbd, f, g, factr,
#     351                    pgtol, wa, iwa, task, iprint, csave, lsave,
#     352                    isave, dsave, maxls)
#     353     task_str = task.tobytes()
#     354     if task_str.startswith(b'FG'):
#     355         # The minimization routine wants f and g at the current x.
#     356         # Note that interruptions due to maxfun are postponed
#     357         # until the completion of the current minimization iteration.
#     358         # Overwrite f and g:
#
# ValueError: failed in converting 7th argument `g' of _lbfgsb.setulb to C/Fortran array

# %% [markdown]
# #### Cleanish plots

# %%
model_simu=build_FDT_pol_model()
euler_stepper_save_5 = one_simulation_estimation(dt = 1e-3, stepper=fl.simulations.EulerMaruyamaStepper, save_every=5,
                          model_simu=model_simu)
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -1.67187D+00    |proj g|=  2.84779D-02
#  This problem is unconstrained.
# At iterate    1    f= -1.67209D+00    |proj g|=  6.99951D-03
#
# At iterate    2    f= -1.67210D+00    |proj g|=  7.09024D-03
#
# At iterate    3    f= -1.67210D+00    |proj g|=  5.68918D-04
#
# At iterate    4    f= -1.67210D+00    |proj g|=  8.39541D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5      4      7      1     0     0   8.395D-06  -1.672D+00
#   F =  -1.6721020513980944
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL

# %%
model_simu=build_FDT_pol_model()
fig, ax = plot_one_result(euler_stepper_save_5, model_simu=model_simu)
fig.savefig('../../../euler_like_cst_frict.png')

# %%
model_simu=build_FDT_pol_model(diff_coef=[.5,0.,.05])
vec_stepper_save_5 = one_simulation_estimation(dt = 1e-3, save_every=5,
                          model_simu=model_simu)
# Out:
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -1.26869D+00    |proj g|=  8.21013D-02
#
# At iterate    1    f= -1.26873D+00    |proj g|=  4.87956D-02
#
# At iterate    2    f= -1.26875D+00    |proj g|=  1.64816D-02
#
# At iterate    3    f= -1.26878D+00    |proj g|=  2.03483D-02
#
# At iterate    4    f= -1.26885D+00    |proj g|=  5.06519D-02
#
# At iterate    5    f= -1.26894D+00    |proj g|=  5.46840D-02
#
# At iterate    6    f= -1.26895D+00    |proj g|=  3.95316D-02
#
# At iterate    7    f= -1.26898D+00    |proj g|=  1.24668D-02
#
# At iterate    8    f= -1.26898D+00    |proj g|=  2.18811D-03
#
# At iterate    9    f= -1.26898D+00    |proj g|=  7.10741D-04
#
# At iterate   10    f= -1.26898D+00    |proj g|=  6.06700D-04
#
# At iterate   11    f= -1.26898D+00    |proj g|=  4.04075D-04
#
# At iterate   12    f= -1.26898D+00    |proj g|=  1.87811D-04
#
# At iterate   13    f= -1.26898D+00    |proj g|=  1.86751D-04
#
# At iterate   14    f= -1.26898D+00    |proj g|=  3.90725D-04
#
# At iterate   15    f= -1.26898D+00    |proj g|=  8.56524D-04
#
# At iterate   16    f= -1.26898D+00    |proj g|=  1.58404D-03
#
# At iterate   17    f= -1.26898D+00    |proj g|=  2.33976D-03
#
# At iterate   18    f= -1.26898D+00    |proj g|=  2.40878D-03
#
# At iterate   19    f= -1.26898D+00    |proj g|=  4.08231D-03
#
# At iterate   20    f= -1.26898D+00    |proj g|=  3.18447D-03
#
# At iterate   21    f= -1.26898D+00    |proj g|=  9.41230D-04
#
# At iterate   22    f= -1.26898D+00    |proj g|=  8.91444D-04
#
# At iterate   23    f= -1.26899D+00    |proj g|=  1.17804D-03
#
# At iterate   24    f= -1.26899D+00    |proj g|=  6.40033D-04
#
# At iterate   25    f= -1.26899D+00    |proj g|=  7.14128D-04
#
# At iterate   26    f= -1.26899D+00    |proj g|=  6.48742D-05
#
# At iterate   27    f= -1.26899D+00    |proj g|=  4.61836D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     27     46      1     0     0   4.618D-05  -1.269D+00
#   F =  -1.2689855054599735
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH

# %%
model_simu=build_FDT_pol_model(diff_coef=[.5,0.,.05])
plot_one_result(vec_stepper_save_5, model_simu=model_simu)
fig.savefig('../../../euler_like_parab_frict.png')

# %%
model_simu=build_FDT_pol_model(free_energy_coef = 0.1*np.array([0,0,-4.5,0,0.1,]), diff_coef=0.1*np.array([60.,0,-4.5,0,0.2]))
vec_stepper_dt_3_save_5 = one_simulation_estimation(dt = 1e-3, save_every=5,
                          model_simu=model_simu)
# Out:
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            9     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -4.01053D-01    |proj g|=  1.47589D-01
#
# At iterate    1    f= -4.01060D-01    |proj g|=  8.76270D-03
#
# At iterate    2    f= -4.01061D-01    |proj g|=  8.71579D-03
#
# At iterate    3    f= -4.01067D-01    |proj g|=  1.52245D-02
#
# At iterate    4    f= -4.01078D-01    |proj g|=  3.04550D-02
#
# At iterate    5    f= -4.01102D-01    |proj g|=  4.31581D-02
#
# At iterate    6    f= -4.01128D-01    |proj g|=  2.86405D-02
#
# At iterate    7    f= -4.01134D-01    |proj g|=  6.07212D-03
#
# At iterate    8    f= -4.01135D-01    |proj g|=  7.03071D-04
#
# At iterate    9    f= -4.01135D-01    |proj g|=  7.41952D-04
#
# At iterate   10    f= -4.01135D-01    |proj g|=  9.80709D-04
#
# At iterate   11    f= -4.01135D-01    |proj g|=  2.60556D-03
#
# At iterate   12    f= -4.01135D-01    |proj g|=  1.69855D-02
#
# At iterate   13    f= -4.01136D-01    |proj g|=  9.17534D-03
#
# At iterate   14    f= -4.01137D-01    |proj g|=  8.34992D-03
#
# At iterate   15    f= -4.01140D-01    |proj g|=  2.20771D-02
#
# At iterate   16    f= -4.01145D-01    |proj g|=  3.03671D-02
#
# At iterate   17    f= -4.01149D-01    |proj g|=  2.13359D-02
#
# At iterate   18    f= -4.01151D-01    |proj g|=  4.44949D-03
#
# At iterate   19    f= -4.01151D-01    |proj g|=  8.06971D-03
#
# At iterate   20    f= -4.01152D-01    |proj g|=  1.38630D-02
#
# At iterate   21    f= -4.01153D-01    |proj g|=  1.89732D-02
#
# At iterate   22    f= -4.01154D-01    |proj g|=  1.59632D-02
#
# At iterate   23    f= -4.01154D-01    |proj g|=  1.00752D-02
#
# At iterate   24    f= -4.01154D-01    |proj g|=  8.48650D-04
#
# At iterate   25    f= -4.01155D-01    |proj g|=  5.14831D-04
#
# At iterate   26    f= -4.01155D-01    |proj g|=  7.19192D-04
#
# At iterate   27    f= -4.01155D-01    |proj g|=  5.02223D-04
#
# At iterate   28    f= -4.01155D-01    |proj g|=  3.00404D-03
#
# At iterate   29    f= -4.01156D-01    |proj g|=  6.93041D-03
#
# At iterate   30    f= -4.01158D-01    |proj g|=  1.25124D-02
#
# At iterate   31    f= -4.01162D-01    |proj g|=  2.34269D-02
#
# At iterate   32    f= -4.01169D-01    |proj g|=  7.83792D-03
#
# At iterate   33    f= -4.01176D-01    |proj g|=  4.55539D-02
#
# At iterate   34    f= -4.01178D-01    |proj g|=  8.19156D-02
#
# At iterate   35    f= -4.01182D-01    |proj g|=  1.81834D-02
#
# At iterate   36    f= -4.01183D-01    |proj g|=  4.39487D-03
#
# At iterate   37    f= -4.01184D-01    |proj g|=  3.60101D-03
#
# At iterate   38    f= -4.01184D-01    |proj g|=  1.69361D-03
#
# At iterate   39    f= -4.01184D-01    |proj g|=  1.05734D-03
#
# At iterate   40    f= -4.01184D-01    |proj g|=  1.05350D-03
#
# At iterate   41    f= -4.01184D-01    |proj g|=  1.87567D-03
#
# At iterate   42    f= -4.01184D-01    |proj g|=  3.63089D-03
#
# At iterate   43    f= -4.01185D-01    |proj g|=  4.56373D-03
#
# At iterate   44    f= -4.01185D-01    |proj g|=  1.04427D-02
#
# At iterate   45    f= -4.01187D-01    |proj g|=  1.49474D-02
#
# At iterate   46    f= -4.01187D-01    |proj g|=  1.87311D-02
#
# At iterate   47    f= -4.01189D-01    |proj g|=  3.69190D-03
#
# At iterate   48    f= -4.01189D-01    |proj g|=  1.26737D-04
#
# At iterate   49    f= -4.01189D-01    |proj g|=  1.04088D-03
#
# At iterate   50    f= -4.01190D-01    |proj g|=  1.40902D-03
#
# At iterate   51    f= -4.01190D-01    |proj g|=  1.06206D-03
#
# At iterate   52    f= -4.01190D-01    |proj g|=  3.22167D-05
#
# At iterate   53    f= -4.01190D-01    |proj g|=  2.37236D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     9     53     64      1     0     0   2.372D-04  -4.012D-01
#   F = -0.40118972738303266
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH

# %%
model_simu=build_FDT_pol_model(free_energy_coef = 0.1*np.array([0,0,-4.5,0,0.1]), diff_coef=0.1*np.array([60.,0,-4.5,0,0.2]))
plot_one_result(vec_stepper_dt_3_save_5, model_simu=model_simu)
fig.savefig('../../../euler_like_dw_frict.png')

# %%
model_simu=build_FDT_pol_model(free_energy_coef = [0., 0., .1], diff_coef=[.5], mass_kBT=5.)
oh_const_diff_mkt_01 = one_simulation_estimation(dt = 1e-3, save_every=5,
                          model_simu=model_simu)
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -1.68953D+00    |proj g|=  2.48361D-03
#
# At iterate    1    f= -1.68953D+00    |proj g|=  2.25038D-05
#  This problem is unconstrained.
# At iterate    2    f= -1.68953D+00    |proj g|=  7.22068D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      2      4      1     0     0   7.221D-07  -1.690D+00
#   F =  -1.6895302407764992
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL

# %%
model_simu=build_FDT_pol_model(free_energy_coef = [0., 0., .1], diff_coef=[.5], mass_kBT=5.)
plot_one_result(oh_const_diff_mkt_01, model_simu=model_simu)
fig.savefig('../../../euler_like_oh_dw_frict.png')
# Out:
# /home/student/Documents/langevin/folie/folie/estimation/transitionDensity.py:25: RuntimeWarning: invalid value encountered in log
#   ll = -0.5 * ((xt.ravel() - E) ** 2 / V) - 0.5 * np.log(np.sqrt(2 * np.pi) * V)
# /home/student/Documents/langevin/folie/folie/estimation/transitionDensity.py:25: RuntimeWarning: invalid value encountered in log
#   ll = -0.5 * ((xt.ravel() - E) ** 2 / V) - 0.5 * np.log(np.sqrt(2 * np.pi) * V)
# /home/student/Documents/langevin/folie/folie/estimation/transitionDensity.py:25: RuntimeWarning: invalid value encountered in log
#   ll = -0.5 * ((xt.ravel() - E) ** 2 / V) - 0.5 * np.log(np.sqrt(2 * np.pi) * V)
# /home/student/Documents/langevin/folie/folie/estimation/transitionDensity.py:25: RuntimeWarning: invalid value encountered in log
#   ll = -0.5 * ((xt.ravel() - E) ** 2 / V) - 0.5 * np.log(np.sqrt(2 * np.pi) * V)
# /home/student/Documents/langevin/folie/folie/estimation/transitionDensity.py:25: RuntimeWarning: invalid value encountered in log
#   ll = -0.5 * ((xt.ravel() - E) ** 2 / V) - 0.5 * np.log(np.sqrt(2 * np.pi) * V)
# /home/student/Documents/langevin/folie/folie/estimation/transitionDensity.py:25: RuntimeWarning: invalid value encountered in log
#   ll = -0.5 * ((xt.ravel() - E) ** 2 / V) - 0.5 * np.log(np.sqrt(2 * np.pi) * V)
# /home/student/Documents/langevin/folie/folie/estimation/transitionDensity.py:25: RuntimeWarning: invalid value encountered in log
#   ll = -0.5 * ((xt.ravel() - E) ** 2 / V) - 0.5 * np.log(np.sqrt(2 * np.pi) * V)
# /home/student/Documents/langevin/folie/folie/estimation/transitionDensity.py:25: RuntimeWarning: invalid value encountered in log
#   ll = -0.5 * ((xt.ravel() - E) ** 2 / V) - 0.5 * np.log(np.sqrt(2 * np.pi) * V)
# /home/student/Documents/langevin/folie/folie/estimation/transitionDensity.py:25: RuntimeWarning: invalid value encountered in log
#   ll = -0.5 * ((xt.ravel() - E) ** 2 / V) - 0.5 * np.log(np.sqrt(2 * np.pi) * V)
# /home/student/Documents/langevin/folie/folie/estimation/transitionDensity.py:25: RuntimeWarning: invalid value encountered in log
#   ll = -0.5 * ((xt.ravel() - E) ** 2 / V) - 0.5 * np.log(np.sqrt(2 * np.pi) * V)

# %% [markdown]
# ### Hidden

# %% [markdown]
# #### Tests overdamped

# %% [markdown]
# Basic Euler Stepper works just fine for the OverdampedHidden model.

# %%
dim_h=1
dim_x=1

free_energy_coef = 0.1*np.array([0,0,4.5])#,0,0.1])
diff_coef = np.eye(dim_h+dim_x)*.5
diff_coef[1,1] = .1
# friction_coef = - np.random.rand(dim_x+dim_h, dim_h)*2.
friction_coef = [ [-.1], [-.3] ]

free_energy = np.polynomial.Polynomial(free_energy_coef)
force_coeff = - free_energy.deriv(1).coef
force_function = fl.functions.Polynomial(deg=len(force_coeff)-1,coefficients=np.asarray(force_coeff))
diff_function= fl.functions.Polynomial(deg=0,coefficients=np.asarray(diff_coef))
friction_function = fl.functions.Polynomial(deg=0,coefficients=np.asarray(friction_coef))

model = fl.OverdampedHidden(force_function, friction_function, diff_function, dim_h=dim_h)

# %%
dt = .5e-3
simulator = fl.Simulator(fl.simulations.stepper.EulerStepper(model), dt, keep_dim=1)

# %%
ntrajs=50
nsteps=5000
save_every = 1
X0 = np.zeros((dim_x+dim_h)*ntrajs)
data = simulator.run(nsteps, X0, save_every)

# %%
data[0]
# Out:
# {'x': array([[-4.77e-02],
#         [-1.20e-02],
#         [3.02e-03],
#         ...,
#         [-1.12e+00],
#         [-1.11e+00],
#         [-1.11e+00]]),
#  'dt': 0.0005}

# %%
for trj in data:
    plt.plot(trj["x"])

# %%
mu0 = np.zeros(dim_h)
sig0 = np.identity(dim_h)

Eul_est.transition.e_step(1., data[0], model.coefficients, mu0, sig0)
# Out:
# /home/student/Documents/langevin/folie/folie/estimation/_kalman_python.py:87: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (Array(float64, 2, 'A', False, aligned=True), Array(float64, 1, 'C', False, aligned=True))
#   muf[i, ...], Sigf[i, ...], muh[i - 1, ...], Sigh[i - 1, ...] = filter_kalman(muf[i - 1, ...], Sigf[i - 1, ...], Xtplus[i - 1], mutilde[i - 1], frict[i - 1, ...], diffusion[i - 1, ...], dim_x, dim_h)
# /home/student/Documents/langevin/folie/folie/estimation/_kalman_python.py:87: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (Array(float64, 2, 'A', False, aligned=True), Array(float64, 2, 'C', False, aligned=True))
#   muf[i, ...], Sigf[i, ...], muh[i - 1, ...], Sigh[i - 1, ...] = filter_kalman(muf[i - 1, ...], Sigf[i - 1, ...], Xtplus[i - 1], mutilde[i - 1], frict[i - 1, ...], diffusion[i - 1, ...], dim_x, dim_h)
# /home/student/Documents/langevin/folie/folie/estimation/_kalman_python.py:87: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (Array(float64, 2, 'F', False, aligned=True), Array(float64, 2, 'A', False, aligned=True))
#   muf[i, ...], Sigf[i, ...], muh[i - 1, ...], Sigh[i - 1, ...] = filter_kalman(muf[i - 1, ...], Sigf[i - 1, ...], Xtplus[i - 1], mutilde[i - 1], frict[i - 1, ...], diffusion[i - 1, ...], dim_x, dim_h)
# /home/student/Documents/langevin/folie/folie/estimation/_kalman_python.py:96: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (Array(float64, 2, 'A', False, aligned=True), Array(float64, 1, 'A', False, aligned=True))
#   mus[i, ...], Sigs[i, ...], muh[i, ...], Sigh[i, ...] = smoothing_rauch(muf[i, ...], Sigf[i, ...], mus[i + 1, ...], Sigs[i + 1, ...], Xtplus[i], mutilde[i], frict[i, ...], diffusion[i, ...], dim_x, dim_h)
# /home/student/Documents/langevin/folie/folie/estimation/_kalman_python.py:96: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (Array(float64, 2, 'C', False, aligned=True), Array(float64, 2, 'A', False, aligned=True))
#   mus[i, ...], Sigs[i, ...], muh[i, ...], Sigh[i, ...] = smoothing_rauch(muf[i, ...], Sigf[i, ...], mus[i + 1, ...], Sigs[i + 1, ...], Xtplus[i], mutilde[i], frict[i, ...], diffusion[i, ...], dim_x, dim_h)
# (array([7.42e-03, 9.40e-04]),
#  array([[9.98e-01, -1.92e-04],
#         [-1.92e-04, 1.00e+00]]))

# %%
data[1]
# Out:
# {'x': array([[1.97e-02, 4.25e-01, -8.95e-02],
#         [6.05e-02, 4.01e-01, 1.31e+00],
#         [1.82e-02, 1.05e+00, -1.70e+00],
#         ...,
#         [1.55e+00, -6.46e-01, -3.95e-01],
#         [1.54e+00, 1.38e-01, -8.95e-01],
#         [1.50e+00, -2.53e-01, -1.40e+00]]),
#  'dt': 0.0005,
#  'xt': array([[6.05e-02, -4.42e-01, 3.48e-01],
#         [1.82e-02, 2.35e-01, -9.64e-01],
#         [8.90e-03, -3.17e-01, -5.07e-01],
#         ...,
#         [1.54e+00, -5.32e-02, 6.91e-01],
#         [1.50e+00, -8.14e-02, -3.72e-01],
#         [1.49e+00, -9.43e-01, 2.80e-01]]),
#  'bias': array([[0.00e+00, 0.00e+00, 0.00e+00]]),
#  'sig_h': array([[[0.00e+00, 0.00e+00, 0.00e+00, 0.00e+00],
#          [0.00e+00, 0.00e+00, 0.00e+00, 0.00e+00],
#          [0.00e+00, 0.00e+00, 0.00e+00, 0.00e+00],
#          [0.00e+00, 0.00e+00, 0.00e+00, 0.00e+00]],
#
#         [[0.00e+00, 0.00e+00, 0.00e+00, 0.00e+00],
#          [0.00e+00, 0.00e+00, 0.00e+00, 0.00e+00],
#          [0.00e+00, 0.00e+00, 0.00e+00, 0.00e+00],
#          [0.00e+00, 0.00e+00, 0.00e+00, 0.00e+00]],
#
#         [[0.00e+00, 0.00e+00, 0.00e+00, 0.00e+00],
#          [0.00e+00, 0.00e+00, 0.00e+00, 0.00e+00],
#          [0.00e+00, 0.00e+00, 0.00e+00, 0.00e+00],
#          [0.00e+00, 0.00e+00, 0.00e+00, 0.00e+00]],
#
#         ...,
#
#         [[0.00e+00, 0.00e+00, 0.00e+00, 0.00e+00],
#          [0.00e+00, 0.00e+00, 0.00e+00, 0.00e+00],
#          [0.00e+00, 0.00e+00, 0.00e+00, 0.00e+00],
#          [0.00e+00, 0.00e+00, 0.00e+00, 0.00e+00]],
#
#         [[0.00e+00, 0.00e+00, 0.00e+00, 0.00e+00],
#          [0.00e+00, 0.00e+00, 0.00e+00, 0.00e+00],
#          [0.00e+00, 0.00e+00, 0.00e+00, 0.00e+00],
#          [0.00e+00, 0.00e+00, 0.00e+00, 0.00e+00]],
#
#         [[0.00e+00, 0.00e+00, 0.00e+00, 0.00e+00],
#          [0.00e+00, 0.00e+00, 0.00e+00, 0.00e+00],
#          [0.00e+00, 0.00e+00, 0.00e+00, 0.00e+00],
#          [0.00e+00, 0.00e+00, 0.00e+00, 0.00e+00]]])}

# %%
Eul_est = fl.EMEstimator(fl.EulerDensity(deepcopy(model)), n_jobs=10, verbose=2)
Eul_est.fit(data)
# Out:
# Initialization 0
# Initialization converged: True at step 2 	 time lapse 99.80343s	 ll 2.33875
# ----------------Current parameters values------------------
# [8.10e-02 3.30e-01 -2.59e-02 1.66e+00 7.13e-02 -2.00e+03 5.04e-01 3.69e-02
#  3.69e-02 9.96e+02]
# Fit converged: True Init: 0 at step 1 	 time lapse 99.80379s	 ll 2.33875
# ----------------Fitted parameters values------------------
# [8.10e-02 3.30e-01 -2.59e-02 1.66e+00 7.13e-02 -2.00e+03 5.04e-01 3.69e-02
#  3.69e-02 9.96e+02]
# EMEstimator-139804934991936:[{'max_iter': 100,
#                              'n_init': 1,
#                              'no_stop': False,
#                              'tol': 1e-05,
#                              'transition': <folie.estimation.overdamped_transitionDensity.EulerDensity object at 0x7f26df7cf400>,
#                              'verbose': 2,
#                              'verbose_interval': 10,
#                              'warm_start': False}]
# /home/student/Documents/langevin/folie/folie/estimation/_kalman_python.py:87: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (Array(float64, 2, 'A', False, aligned=True), Array(float64, 1, 'C', False, aligned=True))
#   muf[i, ...], Sigf[i, ...], muh[i - 1, ...], Sigh[i - 1, ...] = filter_kalman(muf[i - 1, ...], Sigf[i - 1, ...], Xtplus[i - 1], mutilde[i - 1], frict[i - 1, ...], diffusion[i - 1, ...], dim_x, dim_h)
# /home/student/Documents/langevin/folie/folie/estimation/_kalman_python.py:87: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (Array(float64, 2, 'A', False, aligned=True), Array(float64, 2, 'C', False, aligned=True))
#   muf[i, ...], Sigf[i, ...], muh[i - 1, ...], Sigh[i - 1, ...] = filter_kalman(muf[i - 1, ...], Sigf[i - 1, ...], Xtplus[i - 1], mutilde[i - 1], frict[i - 1, ...], diffusion[i - 1, ...], dim_x, dim_h)
# /home/student/Documents/langevin/folie/folie/estimation/_kalman_python.py:87: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (Array(float64, 2, 'F', False, aligned=True), Array(float64, 2, 'A', False, aligned=True))
#   muf[i, ...], Sigf[i, ...], muh[i - 1, ...], Sigh[i - 1, ...] = filter_kalman(muf[i - 1, ...], Sigf[i - 1, ...], Xtplus[i - 1], mutilde[i - 1], frict[i - 1, ...], diffusion[i - 1, ...], dim_x, dim_h)
# /home/student/Documents/langevin/folie/folie/estimation/_kalman_python.py:96: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (Array(float64, 2, 'A', False, aligned=True), Array(float64, 1, 'A', False, aligned=True))
#   mus[i, ...], Sigs[i, ...], muh[i, ...], Sigh[i, ...] = smoothing_rauch(muf[i, ...], Sigf[i, ...], mus[i + 1, ...], Sigs[i + 1, ...], Xtplus[i], mutilde[i], frict[i, ...], diffusion[i, ...], dim_x, dim_h)
# /home/student/Documents/langevin/folie/folie/estimation/_kalman_python.py:96: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (Array(float64, 2, 'C', False, aligned=True), Array(float64, 2, 'A', False, aligned=True))
#   mus[i, ...], Sigs[i, ...], muh[i, ...], Sigh[i, ...] = smoothing_rauch(muf[i, ...], Sigf[i, ...], mus[i + 1, ...], Sigs[i + 1, ...], Xtplus[i], mutilde[i], frict[i, ...], diffusion[i, ...], dim_x, dim_h)
# /home/student/Documents/langevin/folie/folie/estimation/_kalman_python.py:87: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (Array(float64, 2, 'A', False, aligned=True), Array(float64, 1, 'C', False, aligned=True))
#   muf[i, ...], Sigf[i, ...], muh[i - 1, ...], Sigh[i - 1, ...] = filter_kalman(muf[i - 1, ...], Sigf[i - 1, ...], Xtplus[i - 1], mutilde[i - 1], frict[i - 1, ...], diffusion[i - 1, ...], dim_x, dim_h)
# /home/student/Documents/langevin/folie/folie/estimation/_kalman_python.py:87: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (Array(float64, 2, 'A', False, aligned=True), Array(float64, 2, 'C', False, aligned=True))
#   muf[i, ...], Sigf[i, ...], muh[i - 1, ...], Sigh[i - 1, ...] = filter_kalman(muf[i - 1, ...], Sigf[i - 1, ...], Xtplus[i - 1], mutilde[i - 1], frict[i - 1, ...], diffusion[i - 1, ...], dim_x, dim_h)
# /home/student/Documents/langevin/folie/folie/estimation/_kalman_python.py:87: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (Array(float64, 2, 'F', False, aligned=True), Array(float64, 2, 'A', False, aligned=True))
#   muf[i, ...], Sigf[i, ...], muh[i - 1, ...], Sigh[i - 1, ...] = filter_kalman(muf[i - 1, ...], Sigf[i - 1, ...], Xtplus[i - 1], mutilde[i - 1], frict[i - 1, ...], diffusion[i - 1, ...], dim_x, dim_h)
# /home/student/Documents/langevin/folie/folie/estimation/_kalman_python.py:96: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (Array(float64, 2, 'A', False, aligned=True), Array(float64, 1, 'A', False, aligned=True))
#   mus[i, ...], Sigs[i, ...], muh[i, ...], Sigh[i, ...] = smoothing_rauch(muf[i, ...], Sigf[i, ...], mus[i + 1, ...], Sigs[i + 1, ...], Xtplus[i], mutilde[i], frict[i, ...], diffusion[i, ...], dim_x, dim_h)
# /home/student/Documents/langevin/folie/folie/estimation/_kalman_python.py:96: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (Array(float64, 2, 'C', False, aligned=True), Array(float64, 2, 'A', False, aligned=True))
#   mus[i, ...], Sigs[i, ...], muh[i, ...], Sigh[i, ...] = smoothing_rauch(muf[i, ...], Sigf[i, ...], mus[i + 1, ...], Sigs[i + 1, ...], Xtplus[i], mutilde[i], frict[i, ...], diffusion[i, ...], dim_x, dim_h)
# /home/student/Documents/langevin/folie/folie/estimation/_kalman_python.py:87: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (Array(float64, 2, 'A', False, aligned=True), Array(float64, 1, 'C', False, aligned=True))
#   muf[i, ...], Sigf[i, ...], muh[i - 1, ...], Sigh[i - 1, ...] = filter_kalman(muf[i - 1, ...], Sigf[i - 1, ...], Xtplus[i - 1], mutilde[i - 1], frict[i - 1, ...], diffusion[i - 1, ...], dim_x, dim_h)
# /home/student/Documents/langevin/folie/folie/estimation/_kalman_python.py:87: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (Array(float64, 2, 'A', False, aligned=True), Array(float64, 2, 'C', False, aligned=True))
#   muf[i, ...], Sigf[i, ...], muh[i - 1, ...], Sigh[i - 1, ...] = filter_kalman(muf[i - 1, ...], Sigf[i - 1, ...], Xtplus[i - 1], mutilde[i - 1], frict[i - 1, ...], diffusion[i - 1, ...], dim_x, dim_h)
# /home/student/Documents/langevin/folie/folie/estimation/_kalman_python.py:87: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (Array(float64, 2, 'F', False, aligned=True), Array(float64, 2, 'A', False, aligned=True))
#   muf[i, ...], Sigf[i, ...], muh[i - 1, ...], Sigh[i - 1, ...] = filter_kalman(muf[i - 1, ...], Sigf[i - 1, ...], Xtplus[i - 1], mutilde[i - 1], frict[i - 1, ...], diffusion[i - 1, ...], dim_x, dim_h)
# /home/student/Documents/langevin/folie/folie/estimation/_kalman_python.py:96: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (Array(float64, 2, 'A', False, aligned=True), Array(float64, 1, 'A', False, aligned=True))
#   mus[i, ...], Sigs[i, ...], muh[i, ...], Sigh[i, ...] = smoothing_rauch(muf[i, ...], Sigf[i, ...], mus[i + 1, ...], Sigs[i + 1, ...], Xtplus[i], mutilde[i], frict[i, ...], diffusion[i, ...], dim_x, dim_h)
# /home/student/Documents/langevin/folie/folie/estimation/_kalman_python.py:96: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (Array(float64, 2, 'C', False, aligned=True), Array(float64, 2, 'A', False, aligned=True))
#   mus[i, ...], Sigs[i, ...], muh[i, ...], Sigh[i, ...] = smoothing_rauch(muf[i, ...], Sigf[i, ...], mus[i + 1, ...], Sigs[i + 1, ...], Xtplus[i], mutilde[i], frict[i, ...], diffusion[i, ...], dim_x, dim_h)
# /home/student/Documents/langevin/folie/folie/estimation/_kalman_python.py:87: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (Array(float64, 2, 'A', False, aligned=True), Array(float64, 1, 'C', False, aligned=True))
#   muf[i, ...], Sigf[i, ...], muh[i - 1, ...], Sigh[i - 1, ...] = filter_kalman(muf[i - 1, ...], Sigf[i - 1, ...], Xtplus[i - 1], mutilde[i - 1], frict[i - 1, ...], diffusion[i - 1, ...], dim_x, dim_h)
# /home/student/Documents/langevin/folie/folie/estimation/_kalman_python.py:87: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (Array(float64, 2, 'A', False, aligned=True), Array(float64, 2, 'C', False, aligned=True))
#   muf[i, ...], Sigf[i, ...], muh[i - 1, ...], Sigh[i - 1, ...] = filter_kalman(muf[i - 1, ...], Sigf[i - 1, ...], Xtplus[i - 1], mutilde[i - 1], frict[i - 1, ...], diffusion[i - 1, ...], dim_x, dim_h)
# /home/student/Documents/langevin/folie/folie/estimation/_kalman_python.py:87: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (Array(float64, 2, 'F', False, aligned=True), Array(float64, 2, 'A', False, aligned=True))
#   muf[i, ...], Sigf[i, ...], muh[i - 1, ...], Sigh[i - 1, ...] = filter_kalman(muf[i - 1, ...], Sigf[i - 1, ...], Xtplus[i - 1], mutilde[i - 1], frict[i - 1, ...], diffusion[i - 1, ...], dim_x, dim_h)
# /home/student/Documents/langevin/folie/folie/estimation/_kalman_python.py:96: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (Array(float64, 2, 'A', False, aligned=True), Array(float64, 1, 'A', False, aligned=True))
#   mus[i, ...], Sigs[i, ...], muh[i, ...], Sigh[i, ...] = smoothing_rauch(muf[i, ...], Sigf[i, ...], mus[i + 1, ...], Sigs[i + 1, ...], Xtplus[i], mutilde[i], frict[i, ...], diffusion[i, ...], dim_x, dim_h)
# /home/student/Documents/langevin/folie/folie/estimation/_kalman_python.py:96: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (Array(float64, 2, 'C', False, aligned=True), Array(float64, 2, 'A', False, aligned=True))
#   mus[i, ...], Sigs[i, ...], muh[i, ...], Sigh[i, ...] = smoothing_rauch(muf[i, ...], Sigf[i, ...], mus[i + 1, ...], Sigs[i + 1, ...], Xtplus[i], mutilde[i], frict[i, ...], diffusion[i, ...], dim_x, dim_h)
# /home/student/Documents/langevin/folie/folie/estimation/_kalman_python.py:87: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (Array(float64, 2, 'A', False, aligned=True), Array(float64, 1, 'C', False, aligned=True))
#   muf[i, ...], Sigf[i, ...], muh[i - 1, ...], Sigh[i - 1, ...] = filter_kalman(muf[i - 1, ...], Sigf[i - 1, ...], Xtplus[i - 1], mutilde[i - 1], frict[i - 1, ...], diffusion[i - 1, ...], dim_x, dim_h)
# /home/student/Documents/langevin/folie/folie/estimation/_kalman_python.py:87: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (Array(float64, 2, 'A', False, aligned=True), Array(float64, 2, 'C', False, aligned=True))
#   muf[i, ...], Sigf[i, ...], muh[i - 1, ...], Sigh[i - 1, ...] = filter_kalman(muf[i - 1, ...], Sigf[i - 1, ...], Xtplus[i - 1], mutilde[i - 1], frict[i - 1, ...], diffusion[i - 1, ...], dim_x, dim_h)
# /home/student/Documents/langevin/folie/folie/estimation/_kalman_python.py:87: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (Array(float64, 2, 'F', False, aligned=True), Array(float64, 2, 'A', False, aligned=True))
#   muf[i, ...], Sigf[i, ...], muh[i - 1, ...], Sigh[i - 1, ...] = filter_kalman(muf[i - 1, ...], Sigf[i - 1, ...], Xtplus[i - 1], mutilde[i - 1], frict[i - 1, ...], diffusion[i - 1, ...], dim_x, dim_h)
# /home/student/Documents/langevin/folie/folie/estimation/_kalman_python.py:96: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (Array(float64, 2, 'A', False, aligned=True), Array(float64, 1, 'A', False, aligned=True))
#   mus[i, ...], Sigs[i, ...], muh[i, ...], Sigh[i, ...] = smoothing_rauch(muf[i, ...], Sigf[i, ...], mus[i + 1, ...], Sigs[i + 1, ...], Xtplus[i], mutilde[i], frict[i, ...], diffusion[i, ...], dim_x, dim_h)
# /home/student/Documents/langevin/folie/folie/estimation/_kalman_python.py:96: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (Array(float64, 2, 'C', False, aligned=True), Array(float64, 2, 'A', False, aligned=True))
#   mus[i, ...], Sigs[i, ...], muh[i, ...], Sigh[i, ...] = smoothing_rauch(muf[i, ...], Sigf[i, ...], mus[i + 1, ...], Sigs[i + 1, ...], Xtplus[i], mutilde[i], frict[i, ...], diffusion[i, ...], dim_x, dim_h)
# /home/student/Documents/langevin/folie/folie/estimation/_kalman_python.py:87: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (Array(float64, 2, 'A', False, aligned=True), Array(float64, 1, 'C', False, aligned=True))
#   muf[i, ...], Sigf[i, ...], muh[i - 1, ...], Sigh[i - 1, ...] = filter_kalman(muf[i - 1, ...], Sigf[i - 1, ...], Xtplus[i - 1], mutilde[i - 1], frict[i - 1, ...], diffusion[i - 1, ...], dim_x, dim_h)
# /home/student/Documents/langevin/folie/folie/estimation/_kalman_python.py:87: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (Array(float64, 2, 'A', False, aligned=True), Array(float64, 2, 'C', False, aligned=True))
#   muf[i, ...], Sigf[i, ...], muh[i - 1, ...], Sigh[i - 1, ...] = filter_kalman(muf[i - 1, ...], Sigf[i - 1, ...], Xtplus[i - 1], mutilde[i - 1], frict[i - 1, ...], diffusion[i - 1, ...], dim_x, dim_h)
# /home/student/Documents/langevin/folie/folie/estimation/_kalman_python.py:87: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (Array(float64, 2, 'F', False, aligned=True), Array(float64, 2, 'A', False, aligned=True))
#   muf[i, ...], Sigf[i, ...], muh[i - 1, ...], Sigh[i - 1, ...] = filter_kalman(muf[i - 1, ...], Sigf[i - 1, ...], Xtplus[i - 1], mutilde[i - 1], frict[i - 1, ...], diffusion[i - 1, ...], dim_x, dim_h)
# /home/student/Documents/langevin/folie/folie/estimation/_kalman_python.py:96: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (Array(float64, 2, 'A', False, aligned=True), Array(float64, 1, 'A', False, aligned=True))
#   mus[i, ...], Sigs[i, ...], muh[i, ...], Sigh[i, ...] = smoothing_rauch(muf[i, ...], Sigf[i, ...], mus[i + 1, ...], Sigs[i + 1, ...], Xtplus[i], mutilde[i], frict[i, ...], diffusion[i, ...], dim_x, dim_h)
# /home/student/Documents/langevin/folie/folie/estimation/_kalman_python.py:96: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (Array(float64, 2, 'C', False, aligned=True), Array(float64, 2, 'A', False, aligned=True))
#   mus[i, ...], Sigs[i, ...], muh[i, ...], Sigh[i, ...] = smoothing_rauch(muf[i, ...], Sigf[i, ...], mus[i + 1, ...], Sigs[i + 1, ...], Xtplus[i], mutilde[i], frict[i, ...], diffusion[i, ...], dim_x, dim_h)
# /home/student/Documents/langevin/folie/folie/estimation/_kalman_python.py:87: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (Array(float64, 2, 'A', False, aligned=True), Array(float64, 1, 'C', False, aligned=True))
#   muf[i, ...], Sigf[i, ...], muh[i - 1, ...], Sigh[i - 1, ...] = filter_kalman(muf[i - 1, ...], Sigf[i - 1, ...], Xtplus[i - 1], mutilde[i - 1], frict[i - 1, ...], diffusion[i - 1, ...], dim_x, dim_h)
# /home/student/Documents/langevin/folie/folie/estimation/_kalman_python.py:87: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (Array(float64, 2, 'A', False, aligned=True), Array(float64, 2, 'C', False, aligned=True))
#   muf[i, ...], Sigf[i, ...], muh[i - 1, ...], Sigh[i - 1, ...] = filter_kalman(muf[i - 1, ...], Sigf[i - 1, ...], Xtplus[i - 1], mutilde[i - 1], frict[i - 1, ...], diffusion[i - 1, ...], dim_x, dim_h)
# /home/student/Documents/langevin/folie/folie/estimation/_kalman_python.py:87: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (Array(float64, 2, 'F', False, aligned=True), Array(float64, 2, 'A', False, aligned=True))
#   muf[i, ...], Sigf[i, ...], muh[i - 1, ...], Sigh[i - 1, ...] = filter_kalman(muf[i - 1, ...], Sigf[i - 1, ...], Xtplus[i - 1], mutilde[i - 1], frict[i - 1, ...], diffusion[i - 1, ...], dim_x, dim_h)
# /home/student/Documents/langevin/folie/folie/estimation/_kalman_python.py:96: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (Array(float64, 2, 'A', False, aligned=True), Array(float64, 1, 'A', False, aligned=True))
#   mus[i, ...], Sigs[i, ...], muh[i, ...], Sigh[i, ...] = smoothing_rauch(muf[i, ...], Sigf[i, ...], mus[i + 1, ...], Sigs[i + 1, ...], Xtplus[i], mutilde[i], frict[i, ...], diffusion[i, ...], dim_x, dim_h)
# /home/student/Documents/langevin/folie/folie/estimation/_kalman_python.py:96: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (Array(float64, 2, 'C', False, aligned=True), Array(float64, 2, 'A', False, aligned=True))
#   mus[i, ...], Sigs[i, ...], muh[i, ...], Sigh[i, ...] = smoothing_rauch(muf[i, ...], Sigf[i, ...], mus[i + 1, ...], Sigs[i + 1, ...], Xtplus[i], mutilde[i], frict[i, ...], diffusion[i, ...], dim_x, dim_h)
# /home/student/Documents/langevin/folie/folie/estimation/_kalman_python.py:87: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (Array(float64, 2, 'A', False, aligned=True), Array(float64, 1, 'C', False, aligned=True))
#   muf[i, ...], Sigf[i, ...], muh[i - 1, ...], Sigh[i - 1, ...] = filter_kalman(muf[i - 1, ...], Sigf[i - 1, ...], Xtplus[i - 1], mutilde[i - 1], frict[i - 1, ...], diffusion[i - 1, ...], dim_x, dim_h)
# /home/student/Documents/langevin/folie/folie/estimation/_kalman_python.py:87: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (Array(float64, 2, 'A', False, aligned=True), Array(float64, 2, 'C', False, aligned=True))
#   muf[i, ...], Sigf[i, ...], muh[i - 1, ...], Sigh[i - 1, ...] = filter_kalman(muf[i - 1, ...], Sigf[i - 1, ...], Xtplus[i - 1], mutilde[i - 1], frict[i - 1, ...], diffusion[i - 1, ...], dim_x, dim_h)
# /home/student/Documents/langevin/folie/folie/estimation/_kalman_python.py:87: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (Array(float64, 2, 'F', False, aligned=True), Array(float64, 2, 'A', False, aligned=True))
#   muf[i, ...], Sigf[i, ...], muh[i - 1, ...], Sigh[i - 1, ...] = filter_kalman(muf[i - 1, ...], Sigf[i - 1, ...], Xtplus[i - 1], mutilde[i - 1], frict[i - 1, ...], diffusion[i - 1, ...], dim_x, dim_h)
# /home/student/Documents/langevin/folie/folie/estimation/_kalman_python.py:96: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (Array(float64, 2, 'A', False, aligned=True), Array(float64, 1, 'A', False, aligned=True))
#   mus[i, ...], Sigs[i, ...], muh[i, ...], Sigh[i, ...] = smoothing_rauch(muf[i, ...], Sigf[i, ...], mus[i + 1, ...], Sigs[i + 1, ...], Xtplus[i], mutilde[i], frict[i, ...], diffusion[i, ...], dim_x, dim_h)
# /home/student/Documents/langevin/folie/folie/estimation/_kalman_python.py:96: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (Array(float64, 2, 'C', False, aligned=True), Array(float64, 2, 'A', False, aligned=True))
#   mus[i, ...], Sigs[i, ...], muh[i, ...], Sigh[i, ...] = smoothing_rauch(muf[i, ...], Sigf[i, ...], mus[i + 1, ...], Sigs[i + 1, ...], Xtplus[i], mutilde[i], frict[i, ...], diffusion[i, ...], dim_x, dim_h)
# /home/student/Documents/langevin/folie/folie/estimation/_kalman_python.py:87: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (Array(float64, 2, 'A', False, aligned=True), Array(float64, 1, 'C', False, aligned=True))
#   muf[i, ...], Sigf[i, ...], muh[i - 1, ...], Sigh[i - 1, ...] = filter_kalman(muf[i - 1, ...], Sigf[i - 1, ...], Xtplus[i - 1], mutilde[i - 1], frict[i - 1, ...], diffusion[i - 1, ...], dim_x, dim_h)
# /home/student/Documents/langevin/folie/folie/estimation/_kalman_python.py:87: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (Array(float64, 2, 'A', False, aligned=True), Array(float64, 2, 'C', False, aligned=True))
#   muf[i, ...], Sigf[i, ...], muh[i - 1, ...], Sigh[i - 1, ...] = filter_kalman(muf[i - 1, ...], Sigf[i - 1, ...], Xtplus[i - 1], mutilde[i - 1], frict[i - 1, ...], diffusion[i - 1, ...], dim_x, dim_h)
# /home/student/Documents/langevin/folie/folie/estimation/_kalman_python.py:87: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (Array(float64, 2, 'F', False, aligned=True), Array(float64, 2, 'A', False, aligned=True))
#   muf[i, ...], Sigf[i, ...], muh[i - 1, ...], Sigh[i - 1, ...] = filter_kalman(muf[i - 1, ...], Sigf[i - 1, ...], Xtplus[i - 1], mutilde[i - 1], frict[i - 1, ...], diffusion[i - 1, ...], dim_x, dim_h)
# /home/student/Documents/langevin/folie/folie/estimation/_kalman_python.py:96: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (Array(float64, 2, 'A', False, aligned=True), Array(float64, 1, 'A', False, aligned=True))
#   mus[i, ...], Sigs[i, ...], muh[i, ...], Sigh[i, ...] = smoothing_rauch(muf[i, ...], Sigf[i, ...], mus[i + 1, ...], Sigs[i + 1, ...], Xtplus[i], mutilde[i], frict[i, ...], diffusion[i, ...], dim_x, dim_h)
# /home/student/Documents/langevin/folie/folie/estimation/_kalman_python.py:96: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (Array(float64, 2, 'C', False, aligned=True), Array(float64, 2, 'A', False, aligned=True))
#   mus[i, ...], Sigs[i, ...], muh[i, ...], Sigh[i, ...] = smoothing_rauch(muf[i, ...], Sigf[i, ...], mus[i + 1, ...], Sigs[i + 1, ...], Xtplus[i], mutilde[i], frict[i, ...], diffusion[i, ...], dim_x, dim_h)
# /home/student/Documents/langevin/folie/folie/estimation/_kalman_python.py:87: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (Array(float64, 2, 'A', False, aligned=True), Array(float64, 1, 'C', False, aligned=True))
#   muf[i, ...], Sigf[i, ...], muh[i - 1, ...], Sigh[i - 1, ...] = filter_kalman(muf[i - 1, ...], Sigf[i - 1, ...], Xtplus[i - 1], mutilde[i - 1], frict[i - 1, ...], diffusion[i - 1, ...], dim_x, dim_h)
# /home/student/Documents/langevin/folie/folie/estimation/_kalman_python.py:87: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (Array(float64, 2, 'A', False, aligned=True), Array(float64, 2, 'C', False, aligned=True))
#   muf[i, ...], Sigf[i, ...], muh[i - 1, ...], Sigh[i - 1, ...] = filter_kalman(muf[i - 1, ...], Sigf[i - 1, ...], Xtplus[i - 1], mutilde[i - 1], frict[i - 1, ...], diffusion[i - 1, ...], dim_x, dim_h)
# /home/student/Documents/langevin/folie/folie/estimation/_kalman_python.py:87: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (Array(float64, 2, 'F', False, aligned=True), Array(float64, 2, 'A', False, aligned=True))
#   muf[i, ...], Sigf[i, ...], muh[i - 1, ...], Sigh[i - 1, ...] = filter_kalman(muf[i - 1, ...], Sigf[i - 1, ...], Xtplus[i - 1], mutilde[i - 1], frict[i - 1, ...], diffusion[i - 1, ...], dim_x, dim_h)
# /home/student/Documents/langevin/folie/folie/estimation/_kalman_python.py:96: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (Array(float64, 2, 'A', False, aligned=True), Array(float64, 1, 'A', False, aligned=True))
#   mus[i, ...], Sigs[i, ...], muh[i, ...], Sigh[i, ...] = smoothing_rauch(muf[i, ...], Sigf[i, ...], mus[i + 1, ...], Sigs[i + 1, ...], Xtplus[i], mutilde[i], frict[i, ...], diffusion[i, ...], dim_x, dim_h)
# /home/student/Documents/langevin/folie/folie/estimation/_kalman_python.py:96: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (Array(float64, 2, 'C', False, aligned=True), Array(float64, 2, 'A', False, aligned=True))
#   mus[i, ...], Sigs[i, ...], muh[i, ...], Sigh[i, ...] = smoothing_rauch(muf[i, ...], Sigf[i, ...], mus[i + 1, ...], Sigs[i + 1, ...], Xtplus[i], mutilde[i], frict[i, ...], diffusion[i, ...], dim_x, dim_h)

# %%
res2 = Eul_est.fetch_model()

# %%
model.pos_drift.coefficients
# Out:
# array([-0.00e+00, -9.00e-01, -0.00e+00, -9.00e-01, -0.00e+00, -9.00e-01])

# %%
model.pos_drift.output_size_
# Out:
# 3

# %%
model.pos_drift(xarg),
# Out:
# (array([[9.00e-01, -9.00e-01, 9.00e-01],
#         [8.91e-01, -9.00e-01, 8.91e-01],
#         [8.82e-01, -9.00e-01, 8.82e-01],
#         [8.73e-01, -9.00e-01, 8.73e-01],
#         [8.64e-01, -9.00e-01, 8.64e-01],
#         [8.55e-01, -9.00e-01, 8.55e-01],
#         [8.46e-01, -9.00e-01, 8.46e-01],
#         [8.37e-01, -9.00e-01, 8.37e-01],
#         [8.28e-01, -9.00e-01, 8.28e-01],
#         [8.19e-01, -9.00e-01, 8.19e-01],
#         [8.10e-01, -9.00e-01, 8.10e-01],
#         [8.01e-01, -9.00e-01, 8.01e-01],
#         [7.91e-01, -9.00e-01, 7.91e-01],
#         [7.82e-01, -9.00e-01, 7.82e-01],
#         [7.73e-01, -9.00e-01, 7.73e-01],
#         [7.64e-01, -9.00e-01, 7.64e-01],
#         [7.55e-01, -9.00e-01, 7.55e-01],
#         [7.46e-01, -9.00e-01, 7.46e-01],
#         [7.37e-01, -9.00e-01, 7.37e-01],
#         [7.28e-01, -9.00e-01, 7.28e-01],
#         [7.19e-01, -9.00e-01, 7.19e-01],
#         [7.10e-01, -9.00e-01, 7.10e-01],
#         [7.01e-01, -9.00e-01, 7.01e-01],
#         [6.92e-01, -9.00e-01, 6.92e-01],
#         [6.83e-01, -9.00e-01, 6.83e-01],
#         [6.74e-01, -9.00e-01, 6.74e-01],
#         [6.65e-01, -9.00e-01, 6.65e-01],
#         [6.56e-01, -9.00e-01, 6.56e-01],
#         [6.47e-01, -9.00e-01, 6.47e-01],
#         [6.38e-01, -9.00e-01, 6.38e-01],
#         [6.29e-01, -9.00e-01, 6.29e-01],
#         [6.20e-01, -9.00e-01, 6.20e-01],
#         [6.11e-01, -9.00e-01, 6.11e-01],
#         [6.02e-01, -9.00e-01, 6.02e-01],
#         [5.92e-01, -9.00e-01, 5.92e-01],
#         [5.83e-01, -9.00e-01, 5.83e-01],
#         [5.74e-01, -9.00e-01, 5.74e-01],
#         [5.65e-01, -9.00e-01, 5.65e-01],
#         [5.56e-01, -9.00e-01, 5.56e-01],
#         [5.47e-01, -9.00e-01, 5.47e-01],
#         [5.38e-01, -9.00e-01, 5.38e-01],
#         [5.29e-01, -9.00e-01, 5.29e-01],
#         [5.20e-01, -9.00e-01, 5.20e-01],
#         [5.11e-01, -9.00e-01, 5.11e-01],
#         [5.02e-01, -9.00e-01, 5.02e-01],
#         [4.93e-01, -9.00e-01, 4.93e-01],
#         [4.84e-01, -9.00e-01, 4.84e-01],
#         [4.75e-01, -9.00e-01, 4.75e-01],
#         [4.66e-01, -9.00e-01, 4.66e-01],
#         [4.57e-01, -9.00e-01, 4.57e-01],
#         [4.48e-01, -9.00e-01, 4.48e-01],
#         [4.39e-01, -9.00e-01, 4.39e-01],
#         [4.30e-01, -9.00e-01, 4.30e-01],
#         [4.21e-01, -9.00e-01, 4.21e-01],
#         [4.12e-01, -9.00e-01, 4.12e-01],
#         [4.03e-01, -9.00e-01, 4.03e-01],
#         [3.93e-01, -9.00e-01, 3.93e-01],
#         [3.84e-01, -9.00e-01, 3.84e-01],
#         [3.75e-01, -9.00e-01, 3.75e-01],
#         [3.66e-01, -9.00e-01, 3.66e-01],
#         [3.57e-01, -9.00e-01, 3.57e-01],
#         [3.48e-01, -9.00e-01, 3.48e-01],
#         [3.39e-01, -9.00e-01, 3.39e-01],
#         [3.30e-01, -9.00e-01, 3.30e-01],
#         [3.21e-01, -9.00e-01, 3.21e-01],
#         [3.12e-01, -9.00e-01, 3.12e-01],
#         [3.03e-01, -9.00e-01, 3.03e-01],
#         [2.94e-01, -9.00e-01, 2.94e-01],
#         [2.85e-01, -9.00e-01, 2.85e-01],
#         [2.76e-01, -9.00e-01, 2.76e-01],
#         [2.67e-01, -9.00e-01, 2.67e-01],
#         [2.58e-01, -9.00e-01, 2.58e-01],
#         [2.49e-01, -9.00e-01, 2.49e-01],
#         [2.40e-01, -9.00e-01, 2.40e-01],
#         [2.31e-01, -9.00e-01, 2.31e-01],
#         [2.22e-01, -9.00e-01, 2.22e-01],
#         [2.13e-01, -9.00e-01, 2.13e-01],
#         [2.04e-01, -9.00e-01, 2.04e-01],
#         [1.94e-01, -9.00e-01, 1.94e-01],
#         [1.85e-01, -9.00e-01, 1.85e-01],
#         [1.76e-01, -9.00e-01, 1.76e-01],
#         [1.67e-01, -9.00e-01, 1.67e-01],
#         [1.58e-01, -9.00e-01, 1.58e-01],
#         [1.49e-01, -9.00e-01, 1.49e-01],
#         [1.40e-01, -9.00e-01, 1.40e-01],
#         [1.31e-01, -9.00e-01, 1.31e-01],
#         [1.22e-01, -9.00e-01, 1.22e-01],
#         [1.13e-01, -9.00e-01, 1.13e-01],
#         [1.04e-01, -9.00e-01, 1.04e-01],
#         [9.50e-02, -9.00e-01, 9.50e-02],
#         [8.59e-02, -9.00e-01, 8.59e-02],
#         [7.69e-02, -9.00e-01, 7.69e-02],
#         [6.78e-02, -9.00e-01, 6.78e-02],
#         [5.88e-02, -9.00e-01, 5.88e-02],
#         [4.97e-02, -9.00e-01, 4.97e-02],
#         [4.07e-02, -9.00e-01, 4.07e-02],
#         [3.17e-02, -9.00e-01, 3.17e-02],
#         [2.26e-02, -9.00e-01, 2.26e-02],
#         [1.36e-02, -9.00e-01, 1.36e-02],
#         [4.52e-03, -9.00e-01, 4.52e-03],
#         [-4.52e-03, -9.00e-01, -4.52e-03],
#         [-1.36e-02, -9.00e-01, -1.36e-02],
#         [-2.26e-02, -9.00e-01, -2.26e-02],
#         [-3.17e-02, -9.00e-01, -3.17e-02],
#         [-4.07e-02, -9.00e-01, -4.07e-02],
#         [-4.97e-02, -9.00e-01, -4.97e-02],
#         [-5.88e-02, -9.00e-01, -5.88e-02],
#         [-6.78e-02, -9.00e-01, -6.78e-02],
#         [-7.69e-02, -9.00e-01, -7.69e-02],
#         [-8.59e-02, -9.00e-01, -8.59e-02],
#         [-9.50e-02, -9.00e-01, -9.50e-02],
#         [-1.04e-01, -9.00e-01, -1.04e-01],
#         [-1.13e-01, -9.00e-01, -1.13e-01],
#         [-1.22e-01, -9.00e-01, -1.22e-01],
#         [-1.31e-01, -9.00e-01, -1.31e-01],
#         [-1.40e-01, -9.00e-01, -1.40e-01],
#         [-1.49e-01, -9.00e-01, -1.49e-01],
#         [-1.58e-01, -9.00e-01, -1.58e-01],
#         [-1.67e-01, -9.00e-01, -1.67e-01],
#         [-1.76e-01, -9.00e-01, -1.76e-01],
#         [-1.85e-01, -9.00e-01, -1.85e-01],
#         [-1.94e-01, -9.00e-01, -1.94e-01],
#         [-2.04e-01, -9.00e-01, -2.04e-01],
#         [-2.13e-01, -9.00e-01, -2.13e-01],
#         [-2.22e-01, -9.00e-01, -2.22e-01],
#         [-2.31e-01, -9.00e-01, -2.31e-01],
#         [-2.40e-01, -9.00e-01, -2.40e-01],
#         [-2.49e-01, -9.00e-01, -2.49e-01],
#         [-2.58e-01, -9.00e-01, -2.58e-01],
#         [-2.67e-01, -9.00e-01, -2.67e-01],
#         [-2.76e-01, -9.00e-01, -2.76e-01],
#         [-2.85e-01, -9.00e-01, -2.85e-01],
#         [-2.94e-01, -9.00e-01, -2.94e-01],
#         [-3.03e-01, -9.00e-01, -3.03e-01],
#         [-3.12e-01, -9.00e-01, -3.12e-01],
#         [-3.21e-01, -9.00e-01, -3.21e-01],
#         [-3.30e-01, -9.00e-01, -3.30e-01],
#         [-3.39e-01, -9.00e-01, -3.39e-01],
#         [-3.48e-01, -9.00e-01, -3.48e-01],
#         [-3.57e-01, -9.00e-01, -3.57e-01],
#         [-3.66e-01, -9.00e-01, -3.66e-01],
#         [-3.75e-01, -9.00e-01, -3.75e-01],
#         [-3.84e-01, -9.00e-01, -3.84e-01],
#         [-3.93e-01, -9.00e-01, -3.93e-01],
#         [-4.03e-01, -9.00e-01, -4.03e-01],
#         [-4.12e-01, -9.00e-01, -4.12e-01],
#         [-4.21e-01, -9.00e-01, -4.21e-01],
#         [-4.30e-01, -9.00e-01, -4.30e-01],
#         [-4.39e-01, -9.00e-01, -4.39e-01],
#         [-4.48e-01, -9.00e-01, -4.48e-01],
#         [-4.57e-01, -9.00e-01, -4.57e-01],
#         [-4.66e-01, -9.00e-01, -4.66e-01],
#         [-4.75e-01, -9.00e-01, -4.75e-01],
#         [-4.84e-01, -9.00e-01, -4.84e-01],
#         [-4.93e-01, -9.00e-01, -4.93e-01],
#         [-5.02e-01, -9.00e-01, -5.02e-01],
#         [-5.11e-01, -9.00e-01, -5.11e-01],
#         [-5.20e-01, -9.00e-01, -5.20e-01],
#         [-5.29e-01, -9.00e-01, -5.29e-01],
#         [-5.38e-01, -9.00e-01, -5.38e-01],
#         [-5.47e-01, -9.00e-01, -5.47e-01],
#         [-5.56e-01, -9.00e-01, -5.56e-01],
#         [-5.65e-01, -9.00e-01, -5.65e-01],
#         [-5.74e-01, -9.00e-01, -5.74e-01],
#         [-5.83e-01, -9.00e-01, -5.83e-01],
#         [-5.92e-01, -9.00e-01, -5.92e-01],
#         [-6.02e-01, -9.00e-01, -6.02e-01],
#         [-6.11e-01, -9.00e-01, -6.11e-01],
#         [-6.20e-01, -9.00e-01, -6.20e-01],
#         [-6.29e-01, -9.00e-01, -6.29e-01],
#         [-6.38e-01, -9.00e-01, -6.38e-01],
#         [-6.47e-01, -9.00e-01, -6.47e-01],
#         [-6.56e-01, -9.00e-01, -6.56e-01],
#         [-6.65e-01, -9.00e-01, -6.65e-01],
#         [-6.74e-01, -9.00e-01, -6.74e-01],
#         [-6.83e-01, -9.00e-01, -6.83e-01],
#         [-6.92e-01, -9.00e-01, -6.92e-01],
#         [-7.01e-01, -9.00e-01, -7.01e-01],
#         [-7.10e-01, -9.00e-01, -7.10e-01],
#         [-7.19e-01, -9.00e-01, -7.19e-01],
#         [-7.28e-01, -9.00e-01, -7.28e-01],
#         [-7.37e-01, -9.00e-01, -7.37e-01],
#         [-7.46e-01, -9.00e-01, -7.46e-01],
#         [-7.55e-01, -9.00e-01, -7.55e-01],
#         [-7.64e-01, -9.00e-01, -7.64e-01],
#         [-7.73e-01, -9.00e-01, -7.73e-01],
#         [-7.82e-01, -9.00e-01, -7.82e-01],
#         [-7.91e-01, -9.00e-01, -7.91e-01],
#         [-8.01e-01, -9.00e-01, -8.01e-01],
#         [-8.10e-01, -9.00e-01, -8.10e-01],
#         [-8.19e-01, -9.00e-01, -8.19e-01],
#         [-8.28e-01, -9.00e-01, -8.28e-01],
#         [-8.37e-01, -9.00e-01, -8.37e-01],
#         [-8.46e-01, -9.00e-01, -8.46e-01],
#         [-8.55e-01, -9.00e-01, -8.55e-01],
#         [-8.64e-01, -9.00e-01, -8.64e-01],
#         [-8.73e-01, -9.00e-01, -8.73e-01],
#         [-8.82e-01, -9.00e-01, -8.82e-01],
#         [-8.91e-01, -9.00e-01, -8.91e-01],
#         [-9.00e-01, -9.00e-01, -9.00e-01]]),)

# %%
xarg = np.repeat(np.linspace(-1,1,200).reshape(-1,1), 2, axis=-1)
plt.plot(xarg, model.pos_drift(xarg), alpha=.2)#[:,0])
# plt.plot(xarg, res.pos_drift(xarg)[:,0])
# plt.plot(xarg, res2.pos_drift(xarg)[:,0])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[146], line 2
#       1 xarg = np.repeat(np.linspace(-1,1,200).reshape(-1,1), 2, axis=-1)
# ----> 2 plt.plot(xarg, model.pos_drift(xarg), alpha=.2)#[:,0])
#       3 # plt.plot(xarg, res.pos_drift(xarg)[:,0])
#       4 # plt.plot(xarg, res2.pos_drift(xarg)[:,0])
#
# File ~/Documents/langevin/langevenv/lib/python3.8/site-packages/matplotlib/pyplot.py:2812, in plot(scalex, scaley, data, *args, **kwargs)
#    2810 @_copy_docstring_and_deprecators(Axes.plot)
#    2811 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2812     return gca().plot(
#    2813         *args, scalex=scalex, scaley=scaley,
#    2814         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~/Documents/langevin/langevenv/lib/python3.8/site-packages/matplotlib/axes/_axes.py:1688, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1445 """
#    1446 Plot y versus x as lines and/or markers.
#    1447
#    (...)
#    1685 (``'green'``) or hex strings (``'#008000'``).
#    1686 """
#    1687 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1688 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1689 for line in lines:
#    1690     self.add_line(line)
#
# File ~/Documents/langevin/langevenv/lib/python3.8/site-packages/matplotlib/axes/_base.py:311, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     309     this += args[0],
#     310     args = args[1:]
# --> 311 yield from self._plot_args(
#     312     this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File ~/Documents/langevin/langevenv/lib/python3.8/site-packages/matplotlib/axes/_base.py:522, in _process_plot_var_args._plot_args(self, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     520 ncx, ncy = x.shape[1], y.shape[1]
#     521 if ncx > 1 and ncy > 1 and ncx != ncy:
# --> 522     raise ValueError(f"x has {ncx} columns but y has {ncy} columns")
#     523 if ncx == 0 or ncy == 0:
#     524     return []
#
# ValueError: x has 2 columns but y has 3 columns

# %%
res.diffusion(xarg)[0]
# Out:
# array([[4.93e-01, -1.26e-01, 6.35e-02],
#        [-1.26e-01, 1.01e+03, 6.24e-01],
#        [6.35e-02, 6.24e-01, 9.93e+02]])

# %%
plt.matshow(np.log(res.diffusion(xarg)[0])/np.log(10))
plt.colorbar()
# Out:
# /tmp/ipykernel_7247/2639516239.py:1: RuntimeWarning: invalid value encountered in log
#   plt.matshow(np.log(res.diffusion(xarg)[0])/np.log(10))

# %%
plt.matshow(np.log(res2.diffusion(xarg)[0])/np.log(10))
plt.colorbar()
# Out:
# /tmp/ipykernel_7247/3876646262.py:1: RuntimeWarning: invalid value encountered in log
#   plt.matshow(np.log(res2.diffusion(xarg)[0])/np.log(10))

# %%
plt.matshow(np.log(model.diffusion(xarg)[0])/np.log(10))
plt.colorbar()
# Out:
# /tmp/ipykernel_7247/2387389652.py:1: RuntimeWarning: divide by zero encountered in log
#   plt.matshow(np.log(model.diffusion(xarg)[0])/np.log(10))

# %%
plt.matshow(model.friction(xarg)[0])
plt.colorbar()

# %%
plt.matshow(res2.friction(xarg)[0])
plt.colorbar()

# %%
plt.matshow(res.friction(xarg)[0])
plt.colorbar()

# %%
res.diffusion(xarg).shape
# Out:
# (200, 3, 3)

# %%
real_shit = fl.estimation.mle.EstimatedResult(model.coefficients, log_like =- fl.EMEstimator(fl.EulerDensity(model))._log_likelihood_negative(model.coefficients, data), sample_size=1)

# %%
print(Eul_est.results_)
# Out:
# coefficients      | [7.10e-01 1.83e+01 2.02e+01 4.41e-01 3.29e+01 -1.07e+01 1.40e-01 2.53e-01
#  -2.00e+03 -1.44e+01 -1.31e+01 -2.01e+03 4.93e-01 -1.26e-01 6.35e-02
#  -1.26e-01 1.01e+03 6.24e-01 6.35e-02 6.24e-01 9.93e+02]
# sample size | 19989
# likelihood  | 1.8481023398897336
# AIC         | 38.30379532022053
# BIC         | 204.2654807460641

# %%
print(real_shit)
# Out:
# coefficients      | [-0.00e+00 -9.00e-01 -0.00e+00 -9.00e-01 -0.00e+00 -9.00e-01 -1.75e+00
#  -2.20e-01 -9.60e-02 -6.60e-01 -9.54e-01 -7.13e-03 5.00e-01 0.00e+00
#  0.00e+00 0.00e+00 5.00e-01 0.00e+00 0.00e+00 0.00e+00 5.00e-01]
# sample size | 1
# likelihood  | -68.3117572718748
# AIC         | 178.6235145437496
# BIC         | 136.6235145437496

# %%
from inspect import signature
cls = fl.EMEstimator
init = getattr(cls.__init__, "deprecated_original", cls.__init__)
init_sign = signature(init)

# %%
for p in init_sign.parameters.values():
    print(p, p.kind)
# Out:
# self POSITIONAL_OR_KEYWORD
# transition POSITIONAL_OR_KEYWORD
# *args VAR_POSITIONAL
# tol=1e-05 KEYWORD_ONLY
# max_iter=100 KEYWORD_ONLY
# n_init=1 KEYWORD_ONLY
# warm_start=False KEYWORD_ONLY
# no_stop=False KEYWORD_ONLY
# verbose=0 KEYWORD_ONLY
# verbose_interval=10 KEYWORD_ONLY
# **kwargs VAR_KEYWORD

# %%
res.coefficients
# Out:
# array([7.10e-01, 1.83e+01, 2.02e+01, 4.41e-01, 3.29e+01, -1.07e+01,
#        1.40e-01, 2.53e-01, -2.00e+03, -1.44e+01, -1.31e+01, -2.01e+03,
#        4.93e-01, -1.26e-01, 6.35e-02, -1.26e-01, 1.01e+03, 6.24e-01,
#        6.35e-02, 6.24e-01, 9.93e+02])

# %%
model.coefficients
# Out:
# array([-0.00e+00, -9.00e-01, -0.00e+00, -9.00e-01, -0.00e+00, -9.00e-01,
#        -1.75e+00, -2.20e-01, -9.60e-02, -6.60e-01, -9.54e-01, -7.13e-03,
#        5.00e-01, 0.00e+00, 0.00e+00, 0.00e+00, 5.00e-01, 0.00e+00,
#        0.00e+00, 0.00e+00, 5.00e-01])

# %%
trj["x"].shape
# Out:
# (1999, 5)

# %% [markdown]
# #### UnderdampedHidden

# %% [markdown]
# Had to tweak a bit the implementation + add a GLE stepper bcs I don't see how I could unify Underdamped and UnderdampedHidden dim / dim_x attribute treatment.

# %%
dim_h=1
dim_x=1

free_energy_coef = 0.1*np.array([0,0,-4.5,0,0.1])
diff_coef = np.eye(dim_h+dim_x)*2.
diff_coef[1,1] = 10.
# friction_coef = np.random.rand(dim_x+dim_h, dim_x+dim_h)*30.
friction_coef = [ [1., 1.], [1., 10.] ]
# friction_coef[

free_energy = np.polynomial.Polynomial(free_energy_coef)
force_coeff = - free_energy.deriv(1).coef
force_function = fl.functions.Polynomial(deg=len(force_coeff)-1,coefficients=np.asarray(force_coeff))
diff_function= fl.functions.Polynomial(deg=0,coefficients=np.asarray(diff_coef))
friction_function = fl.functions.Polynomial(deg=0,coefficients=np.asarray(friction_coef))

model = fl.models.hidden.UnderdampedHidden(force_function, friction_function, diff_function, dim_h=dim_h)

# %%
dt = 5e-3
simulator = fl.simulations.UnderdampedSimulator(fl.simulations.stepper.GLEEulerStepper(model), dt)
ntrajs=10
nsteps=15000
save_every = 1
X0 = np.zeros((dim_x+dim_x+dim_h)*ntrajs)
data = simulator.run(nsteps, X0, save_every)

# %%
for trj in data[1:2]:
    plt.plot(trj["v"])

# %%
for trj in data[1:2]:
    plt.plot(trj["x"])

# %%
dim_h=1
diff_coef = np.eye(dim_h+dim_x)*.5
diff_coef[1,1] = .5
friction_coef = np.random.rand(dim_x+dim_h, dim_x+dim_h)*30.
# friction_coef = np.eye(dim_h+dim_x)*.5
ntrajs=10
nsteps=5000
X0 = np.zeros((dim_x+dim_x+dim_h)*ntrajs)

model_simu = build_pol_model(diff_coef=diff_coef, friction_coef=friction_coef, model='UnderdampedHidden', dim_h=dim_h)
test_underdamped_propagator_on_hidden = one_simulation_estimation(dt=5e-3, ntrajs=ntrajs, nsteps=nsteps, model_simu=model_simu, return_data=True,
                                                                  exact_vels=True, stepper=fl.simulations.stepper.GLEEulerStepper,
                                                                 X0 = X0, do_Euler=False, do_KM=True, keep_dim=1+dim_h)

# %%
plt.bar(np.arange(len(model_simu.coefficients)), (- model_simu.coefficients + test_underdamped_propagator_on_hidden.KM_est.model.coefficients) / model_simu.coefficients)
# Out:
# /tmp/ipykernel_7247/3697918274.py:1: RuntimeWarning: divide by zero encountered in divide
#   plt.bar(np.arange(len(model_simu.coefficients)), (- model_simu.coefficients + test_underdamped_propagator_on_hidden.KM_est.model.coefficients) / model_simu.coefficients)
# <BarContainer object of 12 artists>

# %%
model_simu.coefficients
# Out:
# array([-0.00e+00, 9.00e-01, -0.00e+00, -4.00e-02, 2.67e+01, 1.41e+01,
#        1.83e+01, 1.82e+01, 5.00e-01, 0.00e+00, 0.00e+00, 5.00e-01])

# %%
test_underdamped_propagator_on_hidden.KM_est.model.coefficients
# Out:
# array([1.91e-01, 4.78e-01, -1.35e-01, 2.19e-01, 2.70e+01, 1.46e+01,
#        1.72e+01, 1.78e+01, 5.03e-01, 1.68e-03, 1.68e-03, 5.00e-01])

# %%
data = test_underdamped_propagator_on_hidden.data

# %%
KM_est = fl.UnderdampedKramersMoyalEstimator(model_simu)

# %%
trj = KM_est.preprocess_traj(data[0])

# %%
KM_est.model.drift(trj["x"], trj["v"]).shape
# Out:
# (4997, 3)

# %%
for key in trj:
    if key != 'dt':
        print(key, trj[key].shape)
# Out:
# x (4997, 1)
# v (4997, 3)
# u (4997, 1)
# a (4997, 3)
# vt (4997, 3)
# xt (4997, 1)
# bias (1, 1)

# %%
data[0]
# Out:
# {'x': array([[0.00e+00],
#         [-1.97e-04],
#         [-5.03e-04],
#         ...,
#         [-4.61e+00],
#         [-4.60e+00],
#         [-4.60e+00]]),
#  'dt': 0.005,
#  'v': array([[-3.94e-02],
#         [-6.12e-02],
#         [-9.93e-02],
#         ...,
#         [7.88e-01],
#         [8.17e-01],
#         [6.97e-01]])}

# %%
for trj in data:
    plt.plot(trj["v"])

# %%
for trj in data:
    plt.plot(trj["x"])

# %%
fl.Und

# %%
print(model.pos_drift)#.coefficients
# Out:
# Polynomial-139633008493568:[{'coefficients': array([-0.00e+00, 9.00e-01, -0.00e+00, -4.00e-02]),
#                             'deg': None,
#                             'domain': <folie.domains.Domain object at 0x7efed7dec3d0>,
#                             'output_shape': None,
#                             'polynom': Polynomial([1.00e+00], domain=[-1,  1], window=[-1,  1], symbol='x')}]

# %% [markdown]
# ### wtf just a factor of 7/4 seems to be enough correction ???

# %% [markdown]
# ### ANALYTICAL GRADIENT IS IMPORTANT, MINIMIZATION W/O PROVIDING ANY JAC CAN GO REALLY WEIRD SOMETIMES.

# %% [markdown]
# ### older things that helped me understand stuff

# %%
model_simu.drift.coefficients
# Out:
# array([-0.00e+00, 9.00e-01, -0.00e+00, -4.00e-02, 1.00e+00, 0.00e+00,
#        4.00e-02])

# %%
a.drift.coefficients
# Out:
# array([0.00e+00, -9.00e-01, 0.00e+00, 4.00e-02, 1.00e+00, 0.00e+00,
#        4.00e-02])

# %%
realvels.friction.coefficients
# Out:
# array([ 0.12767103, -0.02351669,  0.10219171])

# %%
cor_finvels.friction.coefficients
# Out:
# array([1.14265003, 0.02479672, 0.04343084])

# %%
cor_parabdif.coefficients
# Out:
# array([-0.05829245,  0.90847421,  0.00319497, -0.04017104,  1.01652497,
#         0.89697714, -0.00250346,  0.04658942])

# %%
model_simu.coefficients
# Out:
# array([-0.  ,  0.9 , -0.  , -0.04,  1.  ,  0.2 ,  0.  ,  0.1 ])

# %%
nocor_parabdif.diffusion.coefficients * 12/5
# Out:
# array([ 0.20393691, -0.00164378,  0.09965663])

# %% [markdown]
# La correction de David avec le bruit fonctionne sur Kramers-Moyal si on lui donne la bonne diffusion.

# %%
cor.coefficients
# Out:
# array([ 0.07713298,  0.97505872, -0.00671887, -0.04253659,  0.9553153 ,
#         1.99703766])

# %%
nocor.coefficients
# Out:
# array([-0.0214287 , -0.57986358,  0.40737005,  0.83130958])

# %%
noise_c.coefficients
# Out:
# array([-0.16441595, -0.49639618,  1.04216185,  1.99458745])

# %%
realV.coefficients
# Out:
# array([ 0.02919677, -0.55929211,  1.08206536,  2.00083638])

# %%
v=0
for trj in constant_gamma_diff_data:
    v += np.var(trj["v"]) - np.var(trj["u"])
print(v/len(constant_gamma_diff_data))
# Out:
# 0.0014977983760633214

# %%
noise_corr.coefficients
# Out:
# array([ 0.02606362, -0.46703346,  0.98207309,  1.99855995])

# %%
___.coefficients
# Out:
# array([-0.1262876 , -0.58940756,  2.03136504,  0.26841136,  0.82749314])

# %%
__.coefficients
# Out:
# array([-0.13967513, -0.62915976,  2.09518321,  0.27692715,  0.82841982])

# %%
OH_newfinvec_fr2_2.coefficients
# Out:
# array([-0.04447017, -0.51874653,  1.3802768 ,  1.32857665])

# %%
OH_newfinvec_fr2.coefficients
# Out:
# array([ 0.02869547, -0.54770322,  1.26912785,  1.33287836])

# %%
model_simu.coefficients
# Out:
# array([ 0. , -0.5,  1. ,  2. ])

# %%
OH_newfinvec.coefficients
# Out:
# array([ 0.01972557, -0.53645486,  0.6628127 ,  1.33174509])

# %%
OH_finvec_fr1.coefficients
# Out:
# array([ 0.04348002, -0.53115911,  0.405522  ,  0.83197564])

# %%
OH_finvec.coefficients
# Out:
# array([-0.09872867, -0.63405519,  0.80471249,  0.83108023])

# %%
OH_realvec.coefficients
# Out:
# array([-0.12500531, -0.42664999,  1.96152145,  1.99795029])

# %%
diff2fric2realvoldacc.coefficients
# Out:
# array([ 1.01894059e-01,  7.74123406e-01,  2.49690202e-04, -3.43432713e-02,
#         1.85467296e+00,  1.99399033e+00])

# %%
diff2fric2finvoldacc.coefficients
# Out:
# array([-5.72055006e-02,  4.03153634e-01,  8.97371295e-04, -2.20946137e-02,
#         6.04906541e-02,  1.33188852e+00])

# %% [markdown]
# Current issue: the finite difference acceleration that we have ($a_n = \frac{u_{n+1} - u_n}{\tau}$) gives us the right correction for the diffusion but does weird shit with the drift.

# %%
# KM_res.remove_bias()
xfa = np.linspace(-6,6,100)
fig, axs = plt.subplots(1,3, figsize=(12,5))
axs[0].plot(xfa, force_function(xfa.reshape(-1, 1)), label='Model' )
axs[0].plot(xfa, diff2fric5finv.pos_drift(xfa.reshape(-1, 1)), label='KM', ls='--')
axs[0].plot(xfa, diff2fric1finv.pos_drift(xfa.reshape(-1, 1)), label='KM', ls='--')
axs[0].plot(xfa, diff2fric2finv.pos_drift(xfa.reshape(-1, 1)), label='KM', ls='--')
axs[0].plot(xfa, diff2fric2realv.pos_drift(xfa.reshape(-1, 1)), label='KM', ls='--')
# axs[0].plot(xfa, VEC_res.pos_drift(xfa.reshape(-1, 1)), label='VEC', ls='-.' )
#axs[0].plot(xfa, trainforce(xfa.reshape(-1, 1)), label='KM' )

axs[1].plot(xfa, diff_function(xfa.reshape(-1, 1)), label='Model')
axs[1].plot(xfa, diff2fric5finv.diffusion(xfa.reshape(-1, 1)), label='KM',ls= '--')
axs[1].plot(xfa, diff2fric1finv.diffusion(xfa.reshape(-1, 1)), label='KM',ls= '--')
axs[1].plot(xfa, diff2fric2finv.diffusion(xfa.reshape(-1, 1)), label='KM',ls= '--')
axs[1].plot(xfa, diff2fric2realv.diffusion(xfa.reshape(-1, 1)), label='KM',ls= '--')
# axs[1].plot(xfa, VEC_res.diffusion(xfa.reshape(-1, 1)), label='VEC',ls= '-.')

axs[2].plot(xfa, friction_function(xfa.reshape(-1, 1)), label='Model')
axs[2].plot(xfa, diff2fric5finv.friction(xfa.reshape(-1, 1)), label='KM',ls= '-.')
axs[2].plot(xfa, diff2fric1finv.friction(xfa.reshape(-1, 1)), label='KM',ls= '--')
axs[2].plot(xfa, diff2fric2finv.friction(xfa.reshape(-1, 1)), label='KM',ls= '--')
axs[2].plot(xfa, diff2fric2realv.friction(xfa.reshape(-1, 1)), label='KM',ls= '--')
# axs[2].plot(xfa, VEC_res.friction(xfa.reshape(-1, 1)), label='VEC',ls= '-.')

axs[0].set_title('Force')
axs[1].set_title('Diffusion')
axs[2].set_title('Friction')
for ax in axs:
    ax.legend()

# %%
model_simu.coefficients
# Out:
# array([-0.  ,  0.9 , -0.  , -0.04,  2.  ,  2.  ])

# %%
2.0297/5
# Out:
# 0.40594

# %%
diff2fric5finv.coefficients
# Out:
# array([ 0.11352466,  0.2860146 , -0.00555683, -0.01686389,  2.02973015,
#         0.83004429])

# %%
diff2fric1finv.coefficients
# Out:
# array([-0.11600768,  0.74379258,  0.0010922 , -0.03566715,  0.45817496,
#         0.83441072])

# %%
diff2fric2finv.coefficients
# Out:
# array([ 0.09650498,  0.59486056, -0.00256618, -0.0294658 ,  0.90183177,
#         0.83072385])

# %%
diff2fric2realv.coefficients
# Out:
# array([-1.86740233e-03,  9.51410346e-01, -2.65525091e-03, -4.21012297e-02,
#         2.02423653e+00,  1.99514731e+00])

# %% [markdown]
# #### BILAN FINAL pour la diffusion :
# - 1st problem: the computation of the acceleration was the same irrespective of the choice of velocities (real or finite difference), so it was not possible to see any finite difference effect.
# - 2d problem: the corrective multiplicative factor was not the same as what David found because my acceleration was computed as a centered difference instead of the simpler $\Delta v / \tau$, which yields the infamous $12/5$ factor.

# %%
np.mean([(trj["u"] - np.roll(trj["u"], 1, axis=0))[1:-1].mean() for trj in constant_gamma_diff_data])
# Out:
# 2.3561858702686164e-05

# %%
np.mean([(trj["vt"] - trj["v"]).mean() for trj in constant_gamma_diff_data])
# Out:
# 2.4434430680808383e-05

# %%
5/12
# Out:
# 0.4166666666666667

# %%
KM_res_diff_1_f_newwwacc.coefficients
# Out:
# array([-0.08728954,  0.8089149 ,  0.0080084 , -0.03710753,  0.51043522,
#         0.41538242])

# %%
KM_res_diff_1_r_newwwacc.drift.coefficients
# Out:
# array([ 5.35879456e-02,  8.74872725e-01,  8.41043286e-04, -3.89335848e-02,
#         9.84889445e-01])

# %%
KM_res_diff_1_r_newacc.drift.coefficients
# Out:
# array([-0.03992378,  0.50123627,  0.00269073, -0.02667145, -0.6752492 ])

# %%
KM_res_diff_1_f_newacc.drift.coefficients
# Out:
# array([-2.54413361e-02,  8.16174015e-01,  2.89210637e-04, -3.73777920e-02,
#         5.38854744e-01])

# %%
7/13
# Out:
# 0.5384615384615384

# %%
model_simu.drift.coefficients
# Out:
# array([-0.  ,  0.9 , -0.  , -0.04,  1.  ])

# %%
print("Diffusion coefficient:", f"{model_simu.diffusion.coefficients[0]:.4f}")
print("Real velocities KM:",f"{KM_res_diff_1_r_newacc.diffusion.coefficients[0]:.4f}")
print("Finite diff velocities KM:",f"{KM_res_diff_1_f_newacc.diffusion.coefficients[0]:.4f}")
print("Corrected finite diff velocities KM:", f"{KM_res_diff_1_f_newacc.diffusion.coefficients[0] * 12 / 5:.4f}")
# Out:
# Diffusion coefficient: 1.0000
# Real velocities KM: 0.9998
# Finite diff velocities KM: 0.4162
# Corrected finite diff velocities KM: 0.9988

# %% [markdown]
# #### Finally ! If we compute the acceleration as $\frac{v_n - v_{n-1}}{\tau}$ we arrive at exactly the correct diffusion (while retaining consistent coefficients everywhere) !

# %%
print('Real diff :', 1)
print(KM_res_diff_1_r.diffusion.coefficients)
print(KM_res_diff_1_f.diffusion.coefficients)
# Out:
# Real diff : 1
# [1.00080101]
# [0.66653483]

# %% [markdown]
# #### Correction of the acceleration : before it used to be computed only by finite differences, so it was not possible to see any difference

# %%
print(KM_res_diff_1_findiff.diffusion.coefficients)
print(KM_res_diff_1_realvelnewac.diffusion.coefficients)
# Out:
# [0.66701331]
# [0.5004679]

# %% [markdown]
# uncorrected acc

# %%
print('Real diff :', 1)
print(KM_res_diff_1_real_vels.diffusion.coefficients)
print(KM_res_diff_1_finite_diff_nocorr.diffusion.coefficients)
# Out:
# Real diff : 1
# [0.66779618]
# [0.66780299]

# %%
print('Real diff :', .5)
print(KM_res_real_vels.diffusion.coefficients)
print(KM_res_finite_diff_nocorr.diffusion.coefficients)
# Out:
# Real diff : 0.5
# [0.33385006]
# [0.33387023]

# %% [markdown]
# - I see absolutely NO EFFECT of finite difference velocities on the Kramers Moyal estimator...
# - When we fit diffusion vs. acc_sq * dt / 2, diffusion coefficient is exactly 2/3 of the ground truth.

# %%
print('Real diff :', 1)
print(KM_res_diff_1_real_vels_new_factor.diffusion.coefficients)
print(KM_res_diff_1_finite_diff_nocorr_new_factor.diffusion.coefficients)
# Out:
# Real diff : 1
# [0.99860517]
# [0.99861932]

# %% [markdown]
# As a result, if we multiply y by 3/2 we get exactly the right result.

# %%
print(KM_res_corr_dt_3_2.diffusion.coefficients)
print(KM_res_corr_dt_3_2_diff_1.diffusion.coefficients)
print(KM_res_real_vels_diff_1.diffusion.coefficients)
print(KM_res_corr_diff_8.diffusion.coefficients)
# Out:
# [0.49954582]
# [1.00052511]
# [5.33606417]
# [8.00396769]

# %%
trj = constant_gamma_diff_data[0]
print(np.mean(np.concatenate([trj["a"] - KM_res_nocorr_dt_11.drift(trj["x"], trj["v"])], axis=0)))

# %%
print(np.mean(np.concatenate([trj["v"] for trj in constant_gamma_diff_data], axis=0)))
# Out:
# 0.011075983559302572

# %%
print(KM_res_corr_dt_11.diffusion.coefficients)
print(KM_res_nocorr_dt_11.diffusion.coefficients)
# Out:
# [0.36453228]
# [0.33415459]

# %%
print(KM_res_corr_dt.diffusion.coefficients)
print(KM_res_nocorr_dt.diffusion.coefficients)
# Out:
# [0.79813766]
# [0.33255736]

# %%
print(KM_res_no_corr.diffusion.coefficients)
print(KM_res.diffusion.coefficients)
print(KM_res_real_vels.diffusion.coefficients)
# Out:
# [0.66629377]
# [1.59910505]
# [0.66569388]

# %%
# KM_res.remove_bias()
xfa = np.linspace(-6,6,100)
fig, axs = plt.subplots(1,3, figsize=(12,5))
axs[0].plot(xfa, force_function(xfa.reshape(-1, 1)), label='Model' )
axs[0].plot(xfa, KM_res.pos_drift(xfa.reshape(-1, 1)), label='KM', ls='--')
# axs[0].plot(xfa, VEC_res.pos_drift(xfa.reshape(-1, 1)), label='VEC', ls='-.' )
#axs[0].plot(xfa, trainforce(xfa.reshape(-1, 1)), label='KM' )

axs[1].plot(xfa, diff_function(xfa.reshape(-1, 1)), label='Model')
axs[1].plot(xfa, KM_res.diffusion(xfa.reshape(-1, 1)), label='KM',ls= '--')
# axs[1].plot(xfa, VEC_res.diffusion(xfa.reshape(-1, 1)), label='VEC',ls= '-.')

axs[2].plot(xfa, friction_function(xfa.reshape(-1, 1)), label='Model')
axs[2].plot(xfa, KM_res.friction(xfa.reshape(-1, 1)), label='KM',ls= '--')
# axs[2].plot(xfa, VEC_res.friction(xfa.reshape(-1, 1)), label='VEC',ls= '-.')

axs[0].set_title('Force')
axs[1].set_title('Diffusion')
axs[2].set_title('Friction')
for ax in axs:
    ax.legend()

# %% [markdown]
# Ca a convergé mais la valeur des coeffs est complètement FOFOLLE Mdrrrr... to be continued.

# %%
dir(VEC_estimator)
# Out:
# ['__abstractmethods__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_init_prev_time',
#  '_initialize_parameters',
#  '_iter_prev_time',
#  '_log_likelihood_negative',
#  '_log_likelihood_negative_with_jac',
#  '_loop_over_trajs',
#  '_loop_over_trajs_parallel',
#  '_loop_over_trajs_serial',
#  '_model',
#  '_print_verbose_msg_fit_end',
#  '_print_verbose_msg_init_beg',
#  '_print_verbose_msg_init_end',
#  '_print_verbose_msg_iter_end',
#  'converged_',
#  'fetch_model',
#  'fit',
#  'fit_fetch',
#  'get_params',
#  'has_model',
#  'logL',
#  'max_iter',
#  'model',
#  'n_init',
#  'n_jobs',
#  'no_stop',
#  'set_params',
#  'tol',
#  'transition',
#  'verbose',
#  'verbose_interval',
#  'warm_start']

# %% [markdown]
# ### Our analytical gradient is NOT exactly correct!!!

# %%
trj = underdamped_data[0]
x = trj["x"]
v = trj["v"]

eps_val = 1e-8
for k in range(10):
    print(f"Coeff {k}"+(k<4)*" Force"+(3<k<7)*" Friction" + (k>6)*" Diffusion")
    eps = np.zeros(10)
    eps[k] = eps_val / 2
    coeffs_p = np.ones(10) + eps
    coeffs_m = np.ones(10) - eps
    ll_p = VEC_estimator.transition(weight=1., trj=trj, coefficients = coeffs_p)[0]
    ll_m = VEC_estimator.transition(weight=1., trj=trj, coefficients = coeffs_m)[0]
    
    print((ll_p - ll_m) / eps_val)  # finite-difference gradient
    print(VEC_estimator.transition(weight=1., trj=trj, coefficients = np.ones(10))[1][k])  # analytic gradient
# Out:
# Coeff 0 Force
# 16.40582922846079
# 16.43281844280442
# Coeff 1 Force
# 72.20078259706497
# 72.23049252388864
# Coeff 2 Force
# 359.4555892050266
# 359.44003077603537
# Coeff 3 Force
# 1849.3563402444124
# 1849.34187984152
# Coeff 4 Friction
# 10.00880729407072
# 10.016255132102005
# Coeff 5 Friction
# 26.135239750146866
# 26.14306598455723
# Coeff 6 Friction
# 121.98579497635365
# 121.97744648717257
# Coeff 7 Diffusion
# 3522.1280995756388
# 3522.1264859144853
# Coeff 8 Diffusion
# 2349.569695070386
# 2349.5673262702253
# Coeff 9 Diffusion
# 5135.696846991777
# 5135.696371022889

# %%
trainforce =fl.functions.Polynomial(deg=3,coefficients=np.asarray([1,1,1,1]))
deg_diff = 0
traindiff = fl.functions.Polynomial(deg=deg_diff,coefficients=np.ones(deg_diff+1)*.1)
deg_frict = 0
trainfriction = fl.functions.Polynomial(deg=deg_frict,coefficients=np.ones(deg_frict+1)*.1)
trainmodel = fl.models.Underdamped(trainforce, friction=trainfriction, diffusion=traindiff, has_bias=None)

VEC_estimator_1D_2 = fl.LikelihoodEstimator(fl.VECDensity(deepcopy(trainmodel), use_jac=True),n_jobs=1)

trj = constant_gamma_diff_data[0]
x = trj["x"]
v = trj["v"]

eps_val = 1e-5
for k in range(6):
    print(f"Coeff {k}"+(k<4)*" Force"+(3<k<7)*" Friction" + (k>6)*" Diffusion")
    eps = np.zeros(6)
    eps[k] = eps_val / 2
    coeffs_p = np.ones(6) + eps
    coeffs_m = np.ones(6) - eps
    ll_p = VEC_estimator_1D_2.transition(weight=1., trj=trj, coefficients = coeffs_p)[0]
    ll_m = VEC_estimator_1D_2.transition(weight=1., trj=trj, coefficients = coeffs_m)[0]
    
    print((ll_p - ll_m) / eps_val)  # finite-difference gradient
    print(VEC_estimator_1D_2.transition(weight=1., trj=trj, coefficients = np.ones(6))[1][k])  # analytic gradient
# Out:
# Coeff 0 Force
# 774.7079536784439
# 774.7081298557849
# Coeff 1 Force
# 3783.7096839211877
# 3783.7099753604703
# Coeff 2 Force
# 18819.192904629745
# 18819.19276881356
# Coeff 3 Force
# 94821.09814416616
# 94821.09818208845
# Coeff 4 Friction
# -48.50672557950019
# -48.50683406159418
# Coeff 5 Friction
# -51688.072370598085
# -51688.07236805605

# %% [markdown]
# #### Reproducing the test_likelihood example

# %%
trj = np.loadtxt("../datasets/example_2d.trj")
data = fl.Trajectories(dt=trj[1,0]-trj[0,0])
data.append(trj[:,1:2])
fun_lin = fl.functions.Linear(coefficients=np.ones(1))
fun_cst = fl.functions.Constant(coefficients=np.ones(1))
model = fl.models.Underdamped(fun_lin, fun_cst, fun_cst, dim=1)
transition = fl.VECDensity(model)
transition.preprocess_traj(data[0])
c0 = np.ones(len(model.coefficients))*.3
loglikelihood = transition(data.weights[0], data[0], c0)

# %%
finite_diff_jac = scipy.optimize.approx_fprime(c0, lambda p: transition(data.weights[0], data[0], p)[0], epsilon=1e-05)
np.testing.assert_allclose(loglikelihood[1], finite_diff_jac, rtol=1e-05)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[49], line 2
#       1 finite_diff_jac = scipy.optimize.approx_fprime(c0, lambda p: transition(data.weights[0], data[0], p)[0], epsilon=1e-05)
# ----> 2 np.testing.assert_allclose(loglikelihood[1], finite_diff_jac, rtol=1e-05)
#
#     [... skipping hidden 1 frame]
#
# File /opt/anaconda3/lib/python3.8/contextlib.py:75, in ContextDecorator.__call__.<locals>.inner(*args, **kwds)
#      72 @wraps(func)
#      73 def inner(*args, **kwds):
#      74     with self._recreate_cm():
# ---> 75         return func(*args, **kwds)
#
# File ~/.local/lib/python3.8/site-packages/numpy/testing/_private/utils.py:862, in assert_array_compare(comparison, x, y, err_msg, verbose, header, precision, equal_nan, equal_inf, strict)
#     858         err_msg += '\n' + '\n'.join(remarks)
#     859         msg = build_err_msg([ox, oy], err_msg,
#     860                             verbose=verbose, header=header,
#     861                             names=('x', 'y'), precision=precision)
# --> 862         raise AssertionError(msg)
#     863 except ValueError:
#     864     import traceback
#
# AssertionError:
# Not equal to tolerance rtol=1e-05, atol=0
#
# Mismatched elements: 3 / 3 (100%)
# Max absolute difference: 3534.62470054
# Max relative difference: 154.51290975
#  x: array([ 8.795652e-02, -3.665987e-02, -3.557501e+03])
#  y: array([ 4.106310e-03, -5.351775e-03, -2.287592e+01])

# %% [markdown]
# ### Testing underdamped_gaussian

# %%
function_to_test = fl.estimation.transitionDensity.underdamped_gaussian_likelihood_derivative_ND

# %%
n = 1
thetas = np.array([100.])
n_coeffs = len(thetas)
theta = thetas[0]
def args_of_gaussian(theta):
    Xt = np.ones((n,2))*3
    E = np.array([2 * theta**2 + 1, 3 * theta + 2]).reshape((n,2))
    V = 4 * theta * np.eye(2).reshape((n,2,2))
    jacE = np.array([4*theta,3]).reshape((n, 2, n_coeffs))
    jacV = 4 * np.eye(2).reshape((n,2,2,n_coeffs))
    return Xt, E, V, jacE, jacV

gradient = function_to_test(*args_of_gaussian(theta))[1]
finite_diffs = []
for eps in [10**-k for k in np.linspace(3,6,100)]:
    # eps = 7e-4
    finite_diff = ( function_to_test(*args_of_gaussian(theta+eps))[0] - function_to_test(*args_of_gaussian(theta-eps))[0] ) / 2 / eps
    finite_diffs.append(finite_diff)

eps = 10**-3.4
finite_diff = ( function_to_test(*args_of_gaussian(theta+eps))[0] - function_to_test(*args_of_gaussian(theta-eps))[0] ) / 2 / eps

print('Gradient:', gradient)
print('Finite diff:', finite_diff)
# Out:
# Gradient: [[-15000.1349375]]
# Finite diff: [-15000.13493753]

# %%
plt.plot(np.linspace(3,6,100), np.abs(finite_diffs - gradient), 'x')
#plt.xlim(3, 4)
#plt.ylim(0, 3e-6)

# %% [markdown]
# ### Systematic tests #1
#
# Do not execute the cells below again as they correspond to a former version of underdamped_transitionDensity

# %%
coeff=0.1*np.array([0,0,-4.5,0,0.1]) # coefficients of the free energy
free_energy = np.polynomial.Polynomial(coeff)
force_coeff=np.array([-coeff[1],-2*coeff[2],-3*coeff[3],-4*coeff[4]]) #coefficients of the free energy
force_function = fl.functions.Polynomial(deg=3,coefficients=force_coeff)
diff_function= fl.functions.Polynomial(deg=2,coefficients=np.asarray([0.5, 0, .01]))
friction_function = fl.functions.Polynomial(deg=2,coefficients=np.asarray([1., 0, .01]))

# %%
# Define model to simulate and type of simulator to use
dt=1e-3
model_simu = fl.models.underdamped.Underdamped(force_function,friction_function, diffusion=diff_function)
simulator = fl.simulations.UnderdampedSimulator(fl.simulations.VECStepper(model_simu), dt)

# %%
vec_density = fl.VECDensity(model_simu)

# %%
model_simu.coefficients
# Out:
# array([-0.  ,  0.9 , -0.  , -0.04,  1.  ,  0.  ,  0.01,  0.5 ,  0.  ,
#         0.01])

# %%
trj = constant_gamma_diff_data[1]

trj["u"] = trj["v"].copy()
vec_density.preprocess_traj(trj)
x = trj["x"]
v = trj["v"]
model_test = model_simu
n = len(model_test.coefficients)
eps_val = 1e-5
j=50
for k in range(n):
    print(f"Coeff {k}"+(k<4)*" Force"+(3<k<7)*" Friction" + (k>6)*" Diffusion")
    eps = np.zeros(n)
    eps[k] = eps_val / 2
    coeffs_p = np.ones(n) + eps
    coeffs_m = np.ones(n) - eps
    ll_p = vec_density(weight=1., trj=trj, coefficients = coeffs_p)[0]
    ll_m = vec_density(weight=1., trj=trj, coefficients = coeffs_m)[0]
    E_p = vec_density(weight=1., trj=trj, coefficients = coeffs_p)[2]['E']
    E_m = vec_density(weight=1., trj=trj, coefficients = coeffs_m)[2]['E']
    M_p = vec_density(weight=1., trj=trj, coefficients = coeffs_p)[2]['M']
    M_m = vec_density(weight=1., trj=trj, coefficients = coeffs_m)[2]['M']

    print('LL')
    print((ll_p - ll_m) / eps_val)
    print(vec_density(weight=1., trj=trj, coefficients = np.ones(n))[1][k])
    print('E')
    print(np.sum((E_p - E_m) / eps_val, axis=0))  # finite-difference gradient
    print(np.sum(vec_density(weight=1., trj=trj, coefficients = np.ones(n))[3]['E'][:,:,k], axis=0))  # analytic gradient
    print('M')
    print(np.sum((M_p - M_m) / eps_val, axis=0))  # finite-difference gradient
    print(np.sum(vec_density(weight=1., trj=trj, coefficients = np.ones(n))[3]['M'][:,:,:,k], axis=0))  # analytic gradient
# Out:
# Coeff 0 Force
# LL
# -15.608768444508312
# -15.608797698992657
# E
# [7.47141453e-03 1.49163446e+01]
# [7.47141563e-03 1.49163446e+01]
# M
# [[ 0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00 -2.45451646e-05]]
# [[ 0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00 -2.45451252e-05]]
# Coeff 1 Force
# LL
# 88.07867707218973
# 88.078729014245
# E
# [-2.20321032e-02 -4.39413277e+01]
# [-2.20321059e-02 -4.39413277e+01]
# M
# [[0.         0.        ]
#  [0.         0.00022145]]
# [[0.         0.        ]
#  [0.         0.00022145]]
# Coeff 2 Force
# LL
# -435.32243289519096
# -435.3224715401234
# E
# [9.52952237e-02 1.89989321e+02]
# [9.52952206e-02 1.89989321e+02]
# M
# [[ 0.          0.        ]
#  [ 0.         -0.00155467]]
# [[ 0.          0.        ]
#  [ 0.         -0.00155467]]
# Coeff 3 Force
# LL
# 2161.881493520923
# 2161.8814566523683
# E
# [-4.50731064e-01 -8.98458513e+02]
# [-4.50731067e-01 -8.98458513e+02]
# M
# [[0.        0.       ]
#  [0.        0.0101016]]
# [[0.        0.       ]
#  [0.        0.0101016]]
# Coeff 4 Friction
# LL
# 10.933034354820846
# 10.933069180744102
# E
# [2.22078643e-03 4.55393138e+00]
# [2.22078705e-03 4.55393137e+00]
# M
# [[ 0.00000000e+00 -1.62506218e-04]
#  [-1.62506218e-04 -3.16692679e-01]]
# [[ 0.00000000e+00 -1.62506218e-04]
#  [-1.62506218e-04 -3.16692679e-01]]
# Coeff 5 Friction
# LL
# -44.87410769797861
# -44.874093621242885
# E
# [-5.01992974e-03 -1.06076247e+01]
# [-5.01993355e-03 -1.06076247e+01]
# M
# [[0.00000000e+00 7.60134601e-04]
#  [7.60134601e-04 1.47859813e+00]]
# [[0.00000000e+00 7.60134601e-04]
#  [7.60134601e-04 1.47859813e+00]]
# Coeff 6 Friction
# LL
# 215.53331462200728
# 215.53328107404394
# E
# [1.54310042e-02 3.37395186e+01]
# [1.54310052e-02 3.37395186e+01]
# M
# [[ 0.00000000e+00 -3.72259900e-03]
#  [-3.72259900e-03 -7.23290973e+00]]
# [[ 0.00000000e+00 -3.72259900e-03]
#  [-3.72259900e-03 -7.23290973e+00]]
# Coeff 7 Diffusion
# LL
# 3384.243574691936
# 3384.2435733935527
# E
# [0.00000000e+00 2.45444082e-05]
# [0.00000000e+00 2.45451252e-05]
# M
# [[9.99800000e-06 1.48344938e-02]
#  [1.48344938e-02 2.96734618e+01]]
# [[9.99800000e-06 1.48344938e-02]
#  [1.48344938e-02 2.96734618e+01]]
# Coeff 8 Diffusion
# LL
# -4069.9539415072645
# -4069.953942499948
# E
# [ 0.         -0.00011311]
# [ 0.         -0.00011311]
# M
# [[-2.95441252e-05 -4.35574555e-02]
#  [-4.35574555e-02 -8.71389249e+01]]
# [[-2.95441252e-05 -4.35574555e-02]
#  [-4.35574555e-02 -8.71389249e+01]]
# Coeff 9 Diffusion
# LL
# 10978.329929639585
# 10978.329931491628
# E
# [0.         0.00054115]
# [0.         0.00054115]
# M
# [[1.27883604e-04 1.88108708e-01]
#  [1.88108708e-01 3.76339518e+02]]
# [[1.27883604e-04 1.88108708e-01]
#  [1.88108708e-01 3.76339518e+02]]

# %% [markdown]
# #### From this simple test, it seems that jacE and jacM are actually correct (i.e. the analytical gradients coincide with the ones estimated by finite difference.) But this example is not one where we can see significant discrepancies between LL finite diff and analytical gradients, so probably no significant?

# %% [markdown]
# ### Systematic testing of every single term

# %%
def inv_M(*args, **kwargs):
    M = get_M(*args, **kwargs)
    return np.linalg.inv(M)  # TODO: Use linalg.solve instead of inv ?
def inv_ME(xt, *args, **kwargs):
    E = get_E(*args, **kwargs)
    return np.einsum("tij,tj-> ti", inv_M(*args, **kwargs), xt - E)
def first_term(xt, *args, **kwargs):
    E = get_E(*args, **kwargs)
    return -0.5 * np.einsum("ti,ti-> t", xt - E, inv_ME(xt,*args, **kwargs))
def second_term(*args, **kwargs):
    return - 0.5 * np.log(np.sqrt(2 * np.pi) * np.linalg.det(get_M(*args, **kwargs)))
def ll_min_prob(xt, *args, **kwargs):
    return -np.sum(np.maximum(vec_density._min_prob, first_term(xt, *args, **kwargs) + second_term(*args, **kwargs)))
def ll(xt, *args, **kwargs):
    return -np.sum(first_term(xt, *args, **kwargs) + second_term(*args, **kwargs))
def l_jac_E(k, xt, *args, **kwargs):
    return np.sum(np.einsum("ti,tic-> tc", inv_ME(xt, *args, **kwargs), get_jacE(*args, **kwargs)), axis=0)[k]
def l_jac_M(k, xt, *args, **kwargs):
    return np.sum(0.5 * np.einsum("ti,tijc,tj-> tc", inv_ME(xt, *args, **kwargs), get_jacM(*args, **kwargs), inv_ME(xt, *args, **kwargs)) 
                  - 0.5 * np.einsum("tijc,tji->tc", get_jacM(*args, **kwargs), inv_M(*args, **kwargs)), axis=0)[k]

def get_E(*args, **kwargs):
    return vec_density(*args, **kwargs)[2]['E']
def get_M(*args, **kwargs):
    return vec_density(*args, **kwargs)[2]['M']
def get_jacE(weight, trj, coefficients):
    return vec_density(weight, trj, coefficients)[3]['E']
def get_jacM(weight, trj, coefficients):
    return vec_density(weight, trj, coefficients)[3]['M']
def get_E_sum(*args, **kwargs):
    return np.sum(vec_density(*args, **kwargs)[2]['E'], axis=0)
def get_M_sum(*args, **kwargs):
    return np.sum(vec_density(*args, **kwargs)[2]['M'], axis=0)
def get_jacE_sum(weight, trj, coefficients):
    return np.sum(vec_density(weight, trj, coefficients)[3]['E'], axis=0)
def get_jacM_sum(weight, trj, coefficients):
    return np.sum(vec_density(weight, trj, coefficients)[3]['M'], axis=0)
    

def compute_finite_difference(function, k, n, *args, eps_val=1e-5,):
    eps = np.zeros(n)
    eps[k] = eps_val / 2
    coeffs_p = np.ones(n) + eps
    coeffs_m = np.ones(n) - eps
    func_p = function(*args, coefficients=coeffs_p)
    func_m = function(*args, coefficients=coeffs_m)
    return ( func_p - func_m ) / eps_val

# %%
trj = np.loadtxt("../datasets/example_2d.trj")
data = fl.Trajectories(dt=trj[1,0]-trj[0,0])
data.append(trj[:,1:2])
fun_lin = fl.functions.Linear(coefficients=np.ones(1))
fun_cst = fl.functions.Constant(coefficients=np.ones(1))
model = fl.models.Underdamped(fun_lin, fun_cst, fun_cst, dim=1)
vec_density = fl.VECDensity(model)
trj = data[0]
vec_density.preprocess_traj(data[0])
Xt = np.einsum("i...-> ...i", [trj["xt"],trj["vt"]]).squeeze(axis=1)
n = len(model.coefficients)

eps_val = 1e-5
args = 1. , trj

for k in range(n):
    print(f"Coeff {k}"+(k<2)*" Force"+(2<k<4)*" Friction" + (k>3)*" Diffusion")
    eps = np.zeros(n)
    eps[k] = eps_val / 2
    coeffs_p = np.ones(n) + eps
    coeffs_m = np.ones(n) - eps
    ll_p = vec_density(weight=1., trj=trj, coefficients = coeffs_p)[0]
    ll_m = vec_density(weight=1., trj=trj, coefficients = coeffs_m)[0]
    # E_p = vec_density(weight=1., trj=trj, coefficients = coeffs_p)[2]['E']
    # E_m = vec_density(weight=1., trj=trj, coefficients = coeffs_m)[2]['E']
    # M_p = vec_density(weight=1., trj=trj, coefficients = coeffs_p)[2]['M']
    # M_m = vec_density(weight=1., trj=trj, coefficients = coeffs_m)[2]['M']

    print('Finite diffs:')
    print('    From calling the transition density:')
    print('    ', (ll_p - ll_m) / eps_val)
    print('    With modular functions, including _min_prob compaison:')
    print('    ',compute_finite_difference(ll_min_prob, k, n, Xt, *args))
    print('    With modular functions, without _min_prob compaison:')
    print('    ',compute_finite_difference(ll, k, n, Xt, *args))
    print('Gradient:')
    print(vec_density(weight=1., trj=trj, coefficients = np.ones(n))[1][k])
    # print('E')
    # print(np.sum((E_p - E_m) / eps_val, axis=0))  # finite-difference gradient
    # print(np.sum(vec_density(weight=1., trj=trj, coefficients = np.ones(n))[3]['E'][:,:,k], axis=0))  # analytic gradient
    # print('M')
    # print(np.sum((M_p - M_m) / eps_val, axis=0))  # finite-difference gradient
    # print(np.sum(vec_density(weight=1., trj=trj, coefficients = np.ones(n))[3]['M'][:,:,:,k], axis=0))  # analytic gradient
# Out:
# Coeff 0 Force
# Finite diffs:
#     From calling the transition density:
#      679.3662905693054
#     With modular functions, including _min_prob compaison:
#      679.3662905693054
#     With modular functions, without _min_prob compaison:
#      2789.448201656341
# Gradient:
# 2789.444869882954
# Coeff 1 Force
# Finite diffs:
#     From calling the transition density:
#      -559.0817891061306
#     With modular functions, including _min_prob compaison:
#      -559.0817891061306
#     With modular functions, without _min_prob compaison:
#      795.9220558404921
# Gradient:
# 795.9201356710121
# Coeff 2
# Finite diffs:
#     From calling the transition density:
#      -1108804.750163108
#     With modular functions, including _min_prob compaison:
#      -1108804.750163108
#     With modular functions, without _min_prob compaison:
#      -31948295.18795013
# Gradient:
# -31948295.18419298

# %% [markdown]
# # WOW EVERYTHING WAS ACTUALLY _MIN_PROB'S FAULT

# %% [markdown]
# #### lol

# %% [markdown]
# In the `__call__` method of `VECDensity` the log likelihood is actually computed as:
#
# `-np.sum(np.maximum(self._min_prob, like))` where `like` is the log likelihood from the propagator, where as the jacobian stems directly from the propagator without any filtering. As a result, as probabilities get very small, most terms don't coincide !! Hence the observed discrepancy (and why we need to take a trajectory with very weird velocities to observe it.)

# %%
trj = np.loadtxt("../datasets/example_2d.trj")
data = fl.Trajectories(dt=trj[1,0]-trj[0,0])
data.append(trj[:,1:2])
fun_lin = fl.functions.Linear(coefficients=np.ones(1))
fun_cst = fl.functions.Constant(coefficients=np.ones(1))
model = fl.models.Underdamped(fun_lin, fun_cst, fun_cst, dim=1)
vec_density = fl.VECDensity(model)
# data[0]["u"] = data[0]["v"].copy()
trj = data[0]
vec_density.preprocess_traj(data[0])
n = len(model.coefficients)
c0 = np.ones(n)*.3
loglikelihood = vec_density(data.weights[0], data[0], c0)

eps_val = 1e-5
j=50
for k in range(n):
    print(f"Coeff {k}"+(k<2)*" Force"+(2<k<4)*" Friction" + (k>3)*" Diffusion")
    eps = np.zeros(n)
    eps[k] = eps_val / 2
    coeffs_p = np.ones(n) + eps
    coeffs_m = np.ones(n) - eps
    ll_p = vec_density(weight=1., trj=trj, coefficients = coeffs_p)[0]
    ll_m = vec_density(weight=1., trj=trj, coefficients = coeffs_m)[0]
    E_p = vec_density(weight=1., trj=trj, coefficients = coeffs_p)[2]['E']
    E_m = vec_density(weight=1., trj=trj, coefficients = coeffs_m)[2]['E']
    M_p = vec_density(weight=1., trj=trj, coefficients = coeffs_p)[2]['M']
    M_m = vec_density(weight=1., trj=trj, coefficients = coeffs_m)[2]['M']

    print('LL')
    print((ll_p - ll_m) / eps_val)
    print(vec_density(weight=1., trj=trj, coefficients = np.ones(n))[1][k])
    print('E')
    print(np.sum((E_p - E_m) / eps_val, axis=0))  # finite-difference gradient
    print(np.sum(vec_density(weight=1., trj=trj, coefficients = np.ones(n))[3]['E'][:,:,k], axis=0))  # analytic gradient
    print('M')
    print(np.sum((M_p - M_m) / eps_val, axis=0))  # finite-difference gradient
    print(np.sum(vec_density(weight=1., trj=trj, coefficients = np.ones(n))[3]['M'][:,:,:,k], axis=0))  # analytic gradient
# Out:
# Coeff 0 Force
# LL
# 679.3662905693054
# 2789.444869882954
# E
# [1.03706259e-01 2.07378027e+02]
# [1.03706258e-01 2.07378027e+02]
# M
# [[0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 6.66634232e-05]]
# [[0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 6.66646667e-05]]
# Coeff 1 Force
# LL
# -559.0817891061306
# 795.9201356710121
# E
# [ 7.47957252e-07 -3.30453521e-02]
# [ 7.44651071e-07 -3.30453273e-02]
# M
# [[ 0.00000000e+00 -9.99970004e-05]
#  [-9.99970004e-05 -1.99727341e-01]]
# [[ 0.00000000e+00 -9.99970000e-05]
#  [-9.99970000e-05 -1.99727341e-01]]
# Coeff 2
# LL
# -1108804.750163108
# -31948295.18419298
# E
# [0. 0.]
# [0. 0.]
# M
# [[6.66646667e-05 9.98970030e-02]
#  [9.98970030e-02 1.99794206e+02]]
# [[6.66646667e-05 9.98970030e-02]
#  [9.98970030e-02 1.99794206e+02]]

# %% [markdown]
# #### We are using float64 BUT it is known that the precision of the numerical derivative reaches a maximum for an intermediate value of $\epsilon$
# That explains the discrepancies between finite difference and gradient when one takes $\epsilon \leq 10^{-6}$

# %%
trainforce =fl.functions.Polynomial(deg=3,coefficients=np.asarray([1,1,1,1]))
traindiff = fl.functions.Polynomial(deg=0,coefficients=np.asarray([0.1]))
trainmodel=fl.models.Overdamped(drift = deepcopy(trainforce),diffusion=deepcopy(traindiff), has_bias=None)

KM_estimator_ov = fl.KramersMoyalEstimator(deepcopy(trainmodel), n_jobs=4)
Eul_estimator = fl.LikelihoodEstimator(fl.EulerDensity(deepcopy(trainmodel)),n_jobs=4)

# %%
(trainforce.polynom.basis(2).deriv(2)(x)[..., None] * np.eye(1)[None, : , :]).shape
# Out:
# (14997, 1, 1)

# %%
Eul_estimator.transition(1., underdamped_data[0], np.ones(5))
# Out:
# l_jac_E (14997, 4)
# l_jac_V (14997, 1)
# concat (14997, 5)
# (array(-4275.90733416),
#  array([   482.89974704,   2304.94949106,  11358.13961316,  56825.59207069,
#         -27935.17090062]))

# %%
VEC_estimator.transition(1., underdamped_data[0], np.ones(10))
# Out:
# jac_mu (14997, 10)
# jac_mux (14997, 10)
# jac_gamma (14997, 10)
# jac_gammax (14997, 10)
# jac_c (14997, 10)
# jac_cx (14997, 10)
# jacE (14997, 2, 10)
# jacM (14997, 2, 2, 10)
# (array(-167456.71616071),
#  array([[ 3.82076124e-02, -1.10315821e-05,  2.99683071e-09, ...,
#          -4.69546243e-01,  1.01516900e-04, -2.19456317e-08],
#         [ 1.76364691e-02, -1.04686370e-05,  5.36538683e-09, ...,
#           5.31539438e-01, -2.42011800e-04,  1.06694896e-07],
#         [ 1.21355848e-02, -5.42106764e-06,  2.20834378e-09, ...,
#           6.28811422e-01, -5.72149547e-04,  4.51863174e-07],
#         ...,
#         [-7.82286742e-05, -3.29431167e-04, -1.38726790e-03, ...,
#           4.77557145e-02,  2.00646668e-01,  8.43021198e-01],
#         [ 9.71630238e-04,  4.08357652e-03,  1.71624915e-02, ...,
#           4.70634870e-02,  1.97817064e-01,  8.31463780e-01],
#         [ 2.85208544e-03,  1.19910596e-02,  5.04141632e-02, ...,
#           3.95545838e-02,  1.66324204e-01,  6.99381297e-01]]))

# %%
KM_res.pos_drift.coefficients
# Out:
# array([ 0.83507208, -0.90772395,  0.59848248, -0.10026958])

# %%
KM_res.coefficients_drift
# Out:
# array([ 0.83507208, -0.90772395,  0.59848248, -0.10026958,  0.44316362,
#        -0.51815351,  0.10066141])

# %%
trainforce =fl.functions.Polynomial(deg=3,coefficients=np.asarray([1,1,1,1]))

# %%
dir(trainmodel.friction)
# Out:
# ['__abstractmethods__',
#  '__add__',
#  '__call__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__metaclass__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_coefficients',
#  '_sklearn_auto_wrap_output_keys',
#  'coefficients',
#  'copy',
#  'degree',
#  'domain',
#  'fit',
#  'fit_transform',
#  'get_params',
#  'grad_coeffs',
#  'grad_x',
#  'hessian_x',
#  'n_functions_features_',
#  'output_shape_',
#  'output_size_',
#  'polynom',
#  'resize',
#  'set_output',
#  'set_params',
#  'shape',
#  'size',
#  'transform',
#  'transform_d2x',
#  'transform_dcoeffs',
#  'transform_dx']

# %%
type(trainmodel._drift)
# Out:
# method

# %%
type(trainmodel.diffusion)
# Out:
# folie.functions.polynomial.Polynomial

# %%
type(trainmodel.pos_drift)
# Out:
# folie.functions.polynomial.Polynomial

# %%
type(trainmodel.drift)
# Out:
# folie.functions.base.ModelOverlay

# %%
trainmodel.drift
# Out:
# ModelOverlay-140540528006768:[{'function_name': '_drift',
#                               'model': Underdamped-140540528006192:[{'diffusion': Polynomial-140540528006384:[{'coefficients': array([0.1, 0.1, 0.1]),
#                                                                                      'deg': None,
#                                                                                      'domain': <folie.domains.Domain object at 0x7fd2243f95b0>,
#                                                                                      'output_shape': None,
#                                                                                      'polynom': Polynomial([1.], domain=[-1,  1], window=[-1,  1], symbol='x')}],
#                                                           'dim': 1,
#                                                           'force': None,
#                                                           'friction': Polynomial-140540528006480:[{'coefficients': array([0.1, 0.1, 0.1]),
#                                                                                      'deg': None,
#                                                                                      'domain': <folie.domains.Domain object at 0x7fd2243f9640>,
#                                                                                      'output_shape': None,
#                                                                                      'polynom': Polynomial([1.], domain=[-1,  1], window=[-1,  1], symbol='x')}]}],
#                               'output_shape': None}]

# %%
type(trainmodel.drift.grad_x)
# Out:
# method

# %%
trainmodel._drift_dcoeffs(x,v)
# Out:
# array([[ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.],
#        [ 1.,  2.,  4.,  8., -2., -4., -8.]])

# %%
x = np.ones((100,1))*2.
v = x.copy()
trainforce.grad_x(x,v)
# Out:
# array([[17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.],
#        [17.]])

# %%
VEC_res.friction

# %%
# KM_res.remove_bias()
xfa = np.linspace(-6,6,100)
fig, axs = plt.subplots(1,3, figsize=(12,5))
axs[0].plot(xfa, KM_res.pos_drift(xfa.reshape(-1, 1)), label='KM', ls='--')
#axs[0].plot(xfa, VEC_res.pos_drift(xfa.reshape(-1, 1)), label='VEC', ls='-.' )
axs[0].plot(xfa, force_function(xfa.reshape(-1, 1)), label='Model' )
#axs[0].plot(xfa, trainforce(xfa.reshape(-1, 1)), label='KM' )

axs[1].plot(xfa, KM_res.diffusion(xfa.reshape(-1, 1)), label='KM',ls= '--')
#axs[1].plot(xfa, VEC_res.diffusion(xfa.reshape(-1, 1)), label='VEC',ls= '-.')
axs[1].plot(xfa, diff_function(xfa.reshape(-1, 1)), label='Model')

axs[2].plot(xfa, KM_res.friction(xfa.reshape(-1, 1)), label='KM',ls= '--')
#axs[2].plot(xfa, VEC_res.friction(xfa.reshape(-1, 1)), label='VEC',ls= '-.')
axs[2].plot(xfa, friction_function(xfa.reshape(-1, 1)), label='Model')

for ax in axs:
    ax.legend()

# %%
KM_res.diffusion

# %%
KM_res.friction(np.ones((1,1))*6)

# %%
def E(x,v, dt=dt):
    # <q>
    x_exp = x + v * dt + mu * dt**2 / 2 # + (mu_x * v - mu * gamma) * dt**3 / 6
    # <v>
    v_exp = v + mu * dt + (mu_x * v - mu * gamma) * dt**2 / 2 # + (mu_xx * v**2 - mu_x * gamma * v - 2 * mu * gamma_x * v + mu * mu_x + mu * gamma**2 - 2 * c * gamma_x) * dt**3 / 6
    return np.einsum("i...-> ...i", [x_exp, v_exp])

def M(c=.5,gamma=1., dt=dt):
    # Second-order cumulants
    Mxx = 2/3 * c * dt**3
    Mvv = 2 * c * dt + (- 2 * c * gamma) * dt**2 #+ (c_xx * v**2 - 2 * c_x * gamma * v - 4 * c * gamma_x * v + c_x * mu + 2 * c * mu_x + 4 * c * gamma**2) * dt**3 / 3
    Mxv = c * dt**2# + (c_x * v - 3 * c * gamma) * dt**3 / 3
    return np.einsum("ij...-> ...ij", [[Mxx, Mxv], [Mxv, Mvv]])  # Diffusion matrix

def det_term_likelihood(M):
    return - 0.5 * np.log(np.sqrt(2 * np.pi) * np.linalg.det(M))

# %%
det_term_likelihood(M(c=-100000, gamma=-100000))
# Out:
# -0.6045587429275201

# %%
init_val = VEC_estimator._loop_over_trajs(VEC_estimator.transition, underdamped_data.weights, underdamped_data, np.ones(6))

# %%
good_val = VEC_estimator._loop_over_trajs(VEC_estimator.transition, underdamped_data.weights, underdamped_data, model_simu.coefficients)

# %%
VEC_res.coefficients
# Out:
# array([ 0.24552173,  0.62161693, -0.01411605, -0.02816259,  0.42108815,
#        -0.00140599])

# %%
KM_res.coefficients
# Out:
# array([ 0.24552477,  0.62161949, -0.01411765, -0.02816083,  0.42069163,
#         0.33390087])

# %%
model_simu.coefficients
# Out:
# array([-0.  ,  0.9 , -0.  , -0.04,  1.  ,  0.5 ])

# %%
val = VEC_estimator._loop_over_trajs(VEC_estimator.transition, underdamped_data.weights, underdamped_data, model_simu.coefficients - np.asarray([1,1,1,1,0,1])*100)
val
# Out:
# [-261.7751778412098]

# %%
model_simu.coefficients - np.asarray([0,0,0,0,0,1])
# Out:
# array([-0.  ,  0.9 , -0.  , -0.04,  1.  , -0.5 ])

# %%
init_val
# Out:
# [-11.13440580388474]

# %%
good_val
# Out:
# [-14.098485302230895]

# %%
xfa = np.linspace(-6,6,100)
fig, axs = plt.subplots(1,3, figsize=(12,5))
test_coeffs=force_coeff - np.asarray([1,1,1,1])*100
test_force_function = fl.functions.Polynomial(deg=3,coefficients=test_coeffs)
test_fe = fl.functions.Polynomial(deg=4,coefficients=np.asarray([0, -test_coeffs[0], -test_coeffs[1]/2, -test_coeffs[2]/3, -test_coeffs[3]/4]))


axs[0].plot(xfa, test_force_function(xfa.reshape(-1, 1)), label='Model' )
axs[1].plot(xfa, test_fe(xfa.reshape(-1, 1)), label='Model' )

# %%
#KM_res.remove_bias()
xfa = np.linspace(-6,6,100)
fig, axs = plt.subplots(1,3, figsize=(12,5))
axs[0].plot(xfa, KM_res.pos_drift(xfa.reshape(-1, 1)), label='KM', ls='--')
axs[0].plot(xfa, VEC_res.pos_drift(xfa.reshape(-1, 1)), label='VEC', ls='-.' )
axs[0].plot(xfa, force_function(xfa.reshape(-1, 1)), label='Model' )
#axs[0].plot(xfa, trainforce(xfa.reshape(-1, 1)), label='KM' )

axs[1].plot(xfa, KM_res.diffusion(xfa.reshape(-1, 1)), label='KM',ls= '--')
axs[1].plot(xfa, VEC_res.diffusion(xfa.reshape(-1, 1)), label='VEC',ls= '-.')
axs[1].plot(xfa, diff_function(xfa.reshape(-1, 1)), label='Model')

axs[2].plot(xfa, KM_res.friction(xfa.reshape(-1, 1)), label='KM',ls= '--')
axs[2].plot(xfa, VEC_res.friction(xfa.reshape(-1, 1)), label='VEC',ls= '-.')
axs[2].plot(xfa, friction_function(xfa.reshape(-1, 1)), label='Model')

for ax in axs:
    ax.legend()

# %%
force_function
# Out:
# Polynomial-140035556303008:[{'coefficients': array([-0.  ,  0.9 , -0.  , -0.04]),
#                             'deg': None,
#                             'domain': <folie.domains.Domain object at 0x7f5c9196e0d0>,
#                             'output_shape': None,
#                             'polynom': Polynomial([1.], domain=[-1,  1], window=[-1,  1], symbol='x')}]

# %%
KM_res.pos_drift
# Out:
# Polynomial-140035848500128:[{'coefficients': array([ 8.15843856e-02,  7.39307128e-01,  4.02038183e-04, -3.27237979e-02]),
#                             'deg': None,
#                             'domain': <folie.domains.Domain object at 0x7f5ca3017550>,
#                             'output_shape': None,
#                             'polynom': Polynomial([1.], domain=[-1,  1], window=[-1,  1], symbol='x')}]

# %%
VEC_res.pos_drift
# Out:
# Polynomial-140035848501472:[{'coefficients': array([ 8.15842159e-02,  7.39305262e-01,  3.99321025e-04, -3.27749994e-02]),
#                             'deg': None,
#                             'domain': <folie.domains.Domain object at 0x7f5ca3017a90>,
#                             'output_shape': None,
#                             'polynom': Polynomial([1.], domain=[-1,  1], window=[-1,  1], symbol='x')}]

# %%
# Define model to simulate and type of simulator to use
dt=1e-3
fitted_model_simu = KM_res
simulator = fl.simulations.UnderdampedSimulator(fl.simulations.VECStepper(fitted_model_simu), dt)

# %%
ntrajs=5
# Calculate Trajectory
time_steps=10000
fitted_underdamped_data = fl.data.Trajectories(dt=dt)
for k in range(ntrajs):
    fitted_underdamped_data.append(simulator.run(time_steps, [0., 0.1*(2*(k%2)-1)], 1))

# %%
fitted_underdamped_data[0]
# Out:
# {'x': array([[{'x': array([[-9.22426030e-05],
#                 [-1.95890302e-04],
#                 [-3.05391841e-04],
#                 ...,
#                 [ 5.33396719e+00],
#                 [ 5.33476805e+00],
#                 [ 5.33559295e+00]]), 'dt': 0.001, 'v': array([[-0.09072922],
#                 [-0.11616139],
#                 [-0.10941978],
#                 ...,
#                 [ 0.80201404],
#                 [ 0.81013699],
#                 [ 0.82377155]])}                                            ]],
#        dtype=object),
#  'dt': 0.001}

# %%
# Plot the trajecories
fig, axs = plt.subplots(1,1)
for n, trj in enumerate(fitted_underdamped_data):
    axs.plot(trj["x"][0][0]['x'])
    axs.set_title("Trajectory")
    axs.set_xlabel("$timestep$")

# %%
#KM_res.remove_bias()
xfa = np.linspace(-6,6,100)
fig, axs = plt.subplots(1,3, figsize=(12,5))
axs[0].plot(xfa, KM_res.pos_drift(xfa.reshape(-1, 1)), label='KM', ls='--')
axs[0].plot(xfa, VEC_res.pos_drift(xfa.reshape(-1, 1)), label='VEC', ls='-.' )
axs[0].plot(xfa, force_function(xfa.reshape(-1, 1)), label='Model' )
#axs[0].plot(xfa, trainforce(xfa.reshape(-1, 1)), label='KM' )

axs[1].plot(xfa, KM_res.diffusion(xfa.reshape(-1, 1)), label='KM',ls= '--')
axs[1].plot(xfa, VEC_res.diffusion(xfa.reshape(-1, 1)), label='VEC',ls= '-.')
axs[1].plot(xfa, diff_function(xfa.reshape(-1, 1)), label='Model')

axs[2].plot(xfa, KM_res.friction(xfa.reshape(-1, 1)), label='KM',ls= '--')
axs[2].plot(xfa, VEC_res.friction(xfa.reshape(-1, 1)), label='VEC',ls= '-.')
axs[2].plot(xfa, friction_function(xfa.reshape(-1, 1)), label='Model')

for ax in axs:
    ax.legend()

# %%
#KM_res.remove_bias()
xfa = np.linspace(-6,6,100)
fig, axs = plt.subplots(1,3, figsize=(12,5))
axs[0].plot(xfa, KM_res.pos_drift(xfa.reshape(-1, 1)), label='KM', ls='--')
axs[0].plot(xfa, VEC_res.pos_drift(xfa.reshape(-1, 1)), label='VEC', ls='-.' )
axs[0].plot(xfa, force_function(xfa.reshape(-1, 1)), label='Model' )
#axs[0].plot(xfa, trainforce(xfa.reshape(-1, 1)), label='KM' )

axs[1].plot(xfa, KM_res.diffusion(xfa.reshape(-1, 1)), label='KM',ls= '--')
axs[1].plot(xfa, VEC_res.diffusion(xfa.reshape(-1, 1)), label='VEC',ls= '-.')
axs[1].plot(xfa, diff_function(xfa.reshape(-1, 1)), label='Model')

axs[2].plot(xfa, KM_res.friction(xfa.reshape(-1, 1)), label='KM',ls= '--')
axs[2].plot(xfa, VEC_res.friction(xfa.reshape(-1, 1)), label='VEC',ls= '-.')
axs[2].plot(xfa, friction_function(xfa.reshape(-1, 1)), label='Model')

for ax in axs:
    ax.legend()

# %%
#KM_res.remove_bias()
xfa = np.linspace(-6,6,100)
fig, axs = plt.subplots(1,3, figsize=(12,5))
axs[0].plot(xfa, KM_res.pos_drift(xfa.reshape(-1, 1)), label='KM', ls='--')
axs[0].plot(xfa, VEC_res.pos_drift(xfa.reshape(-1, 1)), label='VEC', ls='-.' )
axs[0].plot(xfa, force_function(xfa.reshape(-1, 1)), label='Model' )
#axs[0].plot(xfa, trainforce(xfa.reshape(-1, 1)), label='KM' )

axs[1].plot(xfa, KM_res.diffusion(xfa.reshape(-1, 1)), label='KM',ls= '--')
axs[1].plot(xfa, VEC_res.diffusion(xfa.reshape(-1, 1)), label='VEC',ls= '-.')
axs[1].plot(xfa, diff_function(xfa.reshape(-1, 1)), label='Model')

axs[2].plot(xfa, KM_res.friction(xfa.reshape(-1, 1)), label='KM',ls= '--')
axs[2].plot(xfa, VEC_res.friction(xfa.reshape(-1, 1)), label='VEC',ls= '-.')
axs[2].plot(xfa, friction_function(xfa.reshape(-1, 1)), label='Model')

for ax in axs:
    ax.legend()

# %%
a = np.arange(16).reshape((4,4))
b = np.arange(16).reshape((4,4))
c = np.arange(16).reshape((4,4))
d = np.arange(16).reshape((4,4))

np.einsum('ij...-> ...ij',[[a,b], [c,d]])[3,2]

# %% [markdown]
# ### 2) Simulation

# %%
# Define model to simulate and type of simulator to use
dt=1e-3
model_simu_ov = fl.models.overdamped.Overdamped(force_function,diffusion=diff_function)
simulator_ov = fl.simulations.Simulator(fl.simulations.EulerStepper(model_simu_ov), dt)

# %%
ntraj=30
q0= np.empty(ntraj)
for i in range(len(q0)):
    q0[i]=0
# Calculate Trajectory
time_steps=10000
data = simulator_ov.run(time_steps, q0, 1)

# %%
# Plot the trajecories
fig, axs = plt.subplots(1,1)
for n, trj in enumerate(data):
    axs.plot(trj["x"])
    axs.set_title("Trajectory")
    axs.set_xlabel("$timestep$")

# %% [markdown]
# ### 3) Model Training

# %% [markdown]
# ####  3.1) Training using same functional form of true force and diffusion

# %%
# Parameters of the training

trainforce =fl.functions.Polynomial(deg=3,coefficients=np.asarray([1,1,1,1]))
traindiff = fl.functions.Polynomial(deg=0,coefficients=np.asarray([0.0]))
trainmodel=fl.models.Overdamped(drift = deepcopy(trainforce),diffusion=deepcopy(traindiff), has_bias=None)

KM_estimator_ov = fl.KramersMoyalEstimator(deepcopy(trainmodel), n_jobs=4)
Eul_estimator = fl.LikelihoodEstimator(fl.EulerDensity(deepcopy(trainmodel)),n_jobs=4)
Eln_estimator = fl.LikelihoodEstimator(fl.ElerianDensity(deepcopy(trainmodel)),n_jobs=4)
Ksl_estimator = fl.LikelihoodEstimator(fl.KesslerDensity(deepcopy(trainmodel)),n_jobs=4)
Drz_estimator = fl.LikelihoodEstimator(fl.DrozdovDensity(deepcopy(trainmodel)),n_jobs=4)

KM_res_ov=KM_estimator_ov.fit_fetch(data)
Eul_res=Eul_estimator.fit_fetch(data)
Eln_res=Eln_estimator.fit_fetch(data)
Ksl_res=Ksl_estimator.fit_fetch(data)
Drz_res=Drz_estimator.fit_fetch(data)

res_vec = [KM_res_ov,Eul_res,Eln_res,Ksl_res,Drz_res] # made a list of all the trained estimators

# %%
fig, axs = plt.subplots(1, 2, figsize=(14, 8))
axs[0].set_title("Force")
axs[0].set_xlabel("$x$")
axs[0].set_ylabel("$F(x)$")
axs[0].grid()

axs[1].set_title("Diffusion Coefficient")
axs[1].set_xlabel("$x$")
axs[1].set_ylabel("$D(x)$") 
axs[1].grid()
xfa = np.linspace(-7.0, 7.0, 75)

#Plot exact quantities 

axs[0].plot(xfa, model_simu_ov.pos_drift(xfa.reshape(-1, 1)), label="Exact")
axs[1].plot(xfa, model_simu_ov.diffusion(xfa.reshape(-1, 1)), label="Exact")
# #Plot inferred quantities 

names = ["KM","Euler", "Elerian", "Kessler", "Drozdov"]
markers = ["x", "1","2","3","|"]
for i in range(len(names)):
    res_vec[i].remove_bias()
    axs[0].plot(xfa, res_vec[i].pos_drift(xfa.reshape(-1, 1)), markers[i],label=names[i])
    axs[1].plot(xfa, res_vec[i].diffusion(xfa.reshape(-1, 1)), markers[i],label=names[i])
    print(names[i],res_vec[i].coefficients)
axs[0].legend()
axs[1].legend()
# Out:
# KM [ 9.16960714e-02  8.04856713e-01 -4.52703598e-04 -3.51187781e-02
#   4.98824228e-01]
# Euler [ 9.16960714e-02  8.04856713e-01 -4.52703598e-04 -3.51187781e-02
#   4.98824228e-01]
# Elerian [ 9.16960714e-02  8.04856713e-01 -4.52703598e-04 -3.51187781e-02
#   4.98824228e-01]
# Kessler [ 9.16959015e-02  8.04857042e-01 -4.49222659e-04 -3.51211841e-02
#   4.99245714e-01]
# Drozdov [ 9.16960603e-02  8.04856906e-01 -4.49542657e-04 -3.51212264e-02
#   4.99246227e-01]

# %% [markdown]
# ####  3.2) Training using splines

# %%
# Parameters of the training
n_knots= 5
domain = fl.MeshedDomain.create_from_range(np.linspace(data.stats.min , data.stats.max , n_knots).ravel())
trainmodel = fl.models.Overdamped(force=fl.functions.BSplinesFunction(domain), diffusion = fl.functions.Polynomial(deg=0,coefficients=np.asarray([0.0])), has_bias=None)

KM_estimator = fl.KramersMoyalEstimator(deepcopy(trainmodel), n_jobs=4)
Eul_estimator = fl.LikelihoodEstimator(fl.EulerDensity(deepcopy(trainmodel)),n_jobs=4)
Eln_estimator = fl.LikelihoodEstimator(fl.ElerianDensity(deepcopy(trainmodel)),n_jobs=4)
Ksl_estimator = fl.LikelihoodEstimator(fl.KesslerDensity(deepcopy(trainmodel)),n_jobs=4)
Drz_estimator = fl.LikelihoodEstimator(fl.DrozdovDensity(deepcopy(trainmodel)),n_jobs=4)

KM_res=Eul_estimator.fit_fetch(data)
Eul_res=Eul_estimator.fit_fetch(data)
Eln_res=Eln_estimator.fit_fetch(data)
Ksl_res=Ksl_estimator.fit_fetch(data)
Drz_res=Drz_estimator.fit_fetch(data)

res_vec = [KM_res,Eul_res,Eln_res,Ksl_res,Drz_res] # made a list of all the trained estimators

# %%
# Plot of OVerdamped( spline, constant)
fig, axs = plt.subplots(1, 2, figsize=(10, 6))
axs[0].set_title("Force")
axs[0].set_xlabel("$x$")
axs[0].set_ylabel("$F(x)$")
axs[0].grid()

axs[1].set_title("Diffusion Coefficient")
axs[1].set_xlabel("$x$")
axs[1].set_ylabel("$D(x)$") 
axs[1].grid()
fig.suptitle('B-spline Fitting with '+str(n_knots)+ ' knots')

xfa = np.linspace(-7.0, 7.0, 75)

#Plot exact quantities 

axs[0].plot(xfa, model_simu.pos_drift(xfa.reshape(-1, 1)), label="Exact")
axs[1].plot(xfa, model_simu.diffusion(xfa.reshape(-1, 1)), label="Exact")
#Plot inferred quantities 
names = ["KM","Euler", "Elerian", "Kessler", "Drozdov"]
markers = ["x", "1","2","3","|"]
for i in range(len(names)):
    res_vec[i].remove_bias()
    axs[0].plot(xfa, res_vec[i].pos_driftriftriftrift(xfa.reshape(-1, 1)), markers[i],label=names[i] )
    axs[1].plot(xfa, res_vec[i].diffusion(xfa.reshape(-1, 1)), markers[i],label=names[i])
    print(names[i],res_vec[i].coefficients)
axs[0].legend()
axs[1].legend()

# %% [markdown]
# Check if the methods are returning all the the same results

# %% [markdown]
# ## 1D BIASED Double Well Potential

# %% [markdown]
# ### 1) Model

# %% [markdown]
# Here we model the double well potential as a quartic function $V(q)= \sum_{i=0}^4 c_iq^i$ and choose a constant diffusion coefficient $D(q)=D$ : $\newline$
# The force parameter to pass to the simulator will then be : $F = - \frac{dV(q)}{dq}$   $\newline$
# Adiabaic bias used : $V_{bias}(q)=\frac{1}{2}k(q-q_0)^2  \longmapsto$ ABMD_Simulator $\newline$
# The center of the parabola, $q_0$, is choosen as : $max(q,q_0)$ at every iteration

# %%
coeff=0.1*np.array([0,0,-4.5,0,0.1]) # coefficients of the free energy
free_energy = np.polynomial.Polynomial(coeff)
force_coeff=np.array([-coeff[1],-2*coeff[2],-3*coeff[3],-4*coeff[4]]) #coefficients of the free energy
force_function = fl.functions.Polynomial(deg=3,coefficients=force_coeff)
diff_function= fl.functions.Polynomial(deg=0,coefficients=np.asarray([0.5]))

# %%
# Plot of Free Energy and Force
x_values = np.linspace(-7, 7, 100)
fig, axs = plt.subplots(1, 2)
axs[0].plot(x_values,free_energy(x_values))
axs[1].plot(x_values,force_function(x_values.reshape(len(x_values),1)))
axs[0].set_title("Potential")
axs[0].set_xlabel("$x$")
axs[0].set_ylabel("$V(x)$")
axs[0].grid()
axs[1].set_title("Force") 
axs[1].set_xlabel("$x$")
axs[1].set_ylabel("$F(x)$") 
axs[1].grid()

# %% [markdown]
# ### 2) Simulation

# %%
# Define model to simulate and type of simulator to use
dt=1e-3
biased_model_simu = fl.models.overdamped.Overdamped(force_function,diffusion=diff_function)
biased_simulator = fl.simulations.ABMD_Simulator(fl.simulations.EulerStepper(biased_model_simu), dt, k=10.0, xstop=6.0) 
ntraj=30
q0= np.empty(ntraj)
for i in range(len(q0)):
    q0[i]=-6.0
# Calculate Trajectory
time_steps=35000
biased_data = biased_simulator.run(time_steps, q0, 1)
xmax = np.concatenate(biased_simulator.xmax_hist, axis=1).T    # if you rerun simulator.run without reinializing the simulator object it will probably append the results making xmax twice as long

# %%
# Plot the trajecories
fig, axs = plt.subplots(1,2,figsize=(10,6))
for n, trj in enumerate(biased_data):
    axs[0].plot(trj["x"])
    axs[0].set_title("Trajectory")
    axs[0].set_xlabel("$timestep$")
    axs[0].set_ylabel("q(t)")
    axs[1].plot(xmax)
    axs[1].set_title("q_0")
    axs[1].set_xlabel("$timesteps$")

# %% [markdown]
# ### 3) Model Training

# %% [markdown]
# ####  3.1) Training using same functional form of true force and diffusion

# %%
# Parameters of the training

trainforce =fl.functions.Polynomial(deg=3,coefficients=np.asarray([1,1,1,1]))
traindiff = fl.functions.Polynomial(deg=0,coefficients=np.asarray([0.0]))
trainmodel=fl.models.Overdamped(force = deepcopy(trainforce),diffusion=deepcopy(traindiff), has_bias=True)

KM_estimator = fl.KramersMoyalEstimator(deepcopy(trainmodel), n_jobs=4)
Eul_estimator = fl.LikelihoodEstimator(fl.EulerDensity(deepcopy(trainmodel)),n_jobs=4)
Eln_estimator = fl.LikelihoodEstimator(fl.ElerianDensity(deepcopy(trainmodel)),n_jobs=4)
Ksl_estimator = fl.LikelihoodEstimator(fl.KesslerDensity(deepcopy(trainmodel)),n_jobs=4)
Drz_estimator = fl.LikelihoodEstimator(fl.DrozdovDensity(deepcopy(trainmodel)),n_jobs=4)

KM_res=KM_estimator.fit_fetch(biased_data)
Eul_res=Eul_estimator.fit_fetch(biased_data)
Eln_res=Eln_estimator.fit_fetch(biased_data)
Ksl_res=Ksl_estimator.fit_fetch(biased_data)
Drz_res=Drz_estimator.fit_fetch(biased_data)

res_vec = [KM_res,Eul_res,Eln_res,Ksl_res,Drz_res] # made a list of all the trained estimators

# %%
fig, axs = plt.subplots(1, 2, figsize=(14, 8))
axs[0].set_title("Force")
axs[0].set_xlabel("$x$")
axs[0].set_ylabel("$F(x)$")
axs[0].grid()

axs[1].set_title("Diffusion Coefficient")
axs[1].set_xlabel("$x$")
axs[1].set_ylabel("$D(x)$") 
axs[1].grid()
xfa = np.linspace(-7.0, 7.0, 75)

#Plot exact quantities 
biased_model_simu.remove_bias()
axs[0].plot(xfa, biased_model_simu.pos_drift(xfa.reshape(-1, 1)), label="Exact")
axs[1].plot(xfa, biased_model_simu.diffusion(xfa.reshape(-1, 1)), label="Exact")
# #Plot inferred quantities 

names = ["KM","Euler", "Elerian", "Kessler", "Drozdov"]
markers = ["x", "1","2","3","|"]
for i in range(len(names)):
    res_vec[i].remove_bias()
    axs[0].plot(xfa, res_vec[i].pos_driftriftriftrift(xfa.reshape(-1, 1)), markers[i],label=names[i] )
    axs[1].plot(xfa, res_vec[i].diffusion(xfa.reshape(-1, 1)), markers[i],label=names[i])
    print(names[i],res_vec[i].coefficients)
axs[0].legend()
axs[1].legend()

# %% [markdown]
# ####  3.2) Training using splines

# %%
# Parameters of the training
n_knots= 5
domain = fl.MeshedDomain.create_from_range(np.linspace(biased_data.stats.min , biased_data.stats.max , n_knots).ravel())
trainmodel = fl.models.Overdamped(force=fl.functions.BSplinesFunction(domain), diffusion = fl.functions.Polynomial(deg=0,coefficients=np.asarray([0.0])), has_bias=True)

KM_estimator = fl.KramersMoyalEstimator(deepcopy(trainmodel), n_jobs=4)
Eul_estimator = fl.LikelihoodEstimator(fl.EulerDensity(deepcopy(trainmodel)),n_jobs=4)
Eln_estimator = fl.LikelihoodEstimator(fl.ElerianDensity(deepcopy(trainmodel)),n_jobs=4)
Ksl_estimator = fl.LikelihoodEstimator(fl.KesslerDensity(deepcopy(trainmodel)),n_jobs=4)
Drz_estimator = fl.LikelihoodEstimator(fl.DrozdovDensity(deepcopy(trainmodel)),n_jobs=4)

KM_res=Eul_estimator.fit_fetch(biased_data)
Eul_res=Eul_estimator.fit_fetch(biased_data)
Eln_res=Eln_estimator.fit_fetch(biased_data)
Ksl_res=Ksl_estimator.fit_fetch(biased_data)
Drz_res=Drz_estimator.fit_fetch(biased_data)

res_vec = [KM_res,Eul_res,Eln_res,Ksl_res,Drz_res] # made a list of all the trained estimators

# %%
# Plot of OVerdamped( spline, constant)
fig, axs = plt.subplots(1, 2, figsize=(10, 6))
axs[0].set_title("Force")
axs[0].set_xlabel("$x$")
axs[0].set_ylabel("$F(x)$")
axs[0].grid()

axs[1].set_title("Diffusion Coefficient")
axs[1].set_xlabel("$x$")
axs[1].set_ylabel("$D(x)$") 
axs[1].grid()
fig.suptitle('B-spline Fitting with '+str(n_knots)+ ' knots')

xfa = np.linspace(-7.0, 7.0, 75)

#Plot exact quantities 
biased_model_simu.remove_bias()
axs[0].plot(xfa, biased_model_simu.drift(xfa.reshape(-1, 1)), label="Exact")
axs[1].plot(xfa, biased_model_simu.diffusion(xfa.reshape(-1, 1)), label="Exact")
#Plot inferred quantities 
names = ["KM","Euler", "Elerian", "Kessler", "Drozdov"]
markers = ["x", "1","2","3","|"]
for i in range(len(names)):
    res_vec[i].remove_bias()
    axs[0].plot(xfa, res_vec[i].drift(xfa.reshape(-1, 1)), markers[i],label=names[i] )
    axs[1].plot(xfa, res_vec[i].diffusion(xfa.reshape(-1, 1)), markers[i],label=names[i])
    print(names[i],res_vec[i].coefficients)
axs[0].legend()
axs[1].legend()

# %% [markdown]
# with zip

# %%
fig, axb = plt.subplots(1, 2, figsize=(10, 6))

n_knots= 4
domain = fl.MeshedDomain.create_from_range(np.linspace(biased_data.stats.min , biased_data.stats.max , n_knots).ravel())
bias_spline_trainmodel = fl.models.Overdamped(fl.functions.BSplinesFunction(domain), fl.functions.Polynomial(deg=0,coefficients=np.asarray([0.0])), has_bias=True)

name = "KM"
estimator = fl.KramersMoyalEstimator(deepcopy(bias_spline_trainmodel))
res = estimator.fit_fetch(biased_data)
print('has bias True',name,res.coefficients)
axb[0].plot(xfa, res.drift(xfa.reshape(-1, 1)), label=name)
axb[1].plot(xfa, res.diffusion(xfa.reshape(-1, 1)), label=name)


for name, marker, transitioncls in zip(
   ["Euler", "Elerian", "Kessler", "Drozdov"],
    ["+","1","2","3","|","x"],
   [
       fl.EulerDensity,
       fl.ElerianDensity,
       fl.KesslerDensity,
       fl.DrozdovDensity,
   ],
):
    estimator = fl.LikelihoodEstimator(transitioncls(deepcopy(bias_spline_trainmodel)), n_jobs=4)
    res = estimator.fit_fetch(biased_data)

    axb[0].plot(xfa, res.drift(xfa.reshape(-1, 1)),marker, label=name)
    axb[1].plot(xfa, res.diffusion(xfa.reshape(-1, 1)),marker, label=name)
    print('has bias true',name,res.coefficients)

axb[0].legend()
axb[1].legend()
plt.show()
